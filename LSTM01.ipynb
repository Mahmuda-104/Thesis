# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmuda-104/Thesis/blob/main/LSTM01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
from scipy.io import loadmat

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Data'

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')
for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []
for control_data_path in control_data:
    n_epochs = 35 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    control_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{control_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]

        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)

        control_arr.append(np.array(downsampled_data))

    Control30.append(np.array(control_arr))

Control30 = np.array(Control30)
print( Control30[0].shape)
# Out:
# (35, 60, 1000)

# %%
import os
import scipy.io
import numpy as np
from scipy import signal

fs_original = 500
fs_new = 250

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 35 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    concussed_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]

        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)

        concussed_arr.append(np.array(downsampled_data))

    Concussed52.append(np.array(concussed_arr))

Concussed52 = np.array(Concussed52)
print( Concussed52[0].shape)
# Out:
# (35, 60, 1000)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Step 1: Data Preparation
# Combine control and concussed data
data_combined = np.concatenate((Control30, Concussed52), axis=0)

# Create labels for binary classification
control_labels = np.zeros(Control30.shape[0])
concussed_labels = np.ones(Concussed52.shape[0])
labels_combined = np.concatenate((control_labels, concussed_labels))

# Step 2: Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(data_combined, labels_combined, test_size=0.2, random_state=42)

# Step 3: Normalize the data
scaler = MinMaxScaler()
x_train_normalized = scaler.fit_transform(x_train.reshape(x_train.shape[0], -1))
x_test_normalized = scaler.transform(x_test.reshape(x_test.shape[0], -1))

# Reshape the normalized data back to its original shape
x_train_normalized = x_train_normalized.reshape(x_train.shape)
x_test_normalized = x_test_normalized.reshape(x_test.shape)

# Verify the shapes of the training and testing sets
print("x_train shape:", x_train_normalized.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test_normalized.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (67, 35, 60, 1000)
# y_train shape: (67,)
# x_test shape: (17, 35, 60, 1000)
# y_test shape: (17,)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout, Reshape

# Reshape the data
x_train_reshaped = x_train.reshape(x_train.shape[0], -1)
x_test_reshaped = x_test.reshape(x_test.shape[0], -1)

# Standardize the data
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train_reshaped)
x_test_scaled = scaler.transform(x_test_reshaped)

# Convert the labels to categorical (one-hot encoding)
from keras.utils import to_categorical
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# Reshape the flattened data back to 3D shape
x_train_scaled = x_train_scaled.reshape(x_train.shape[0], x_train.shape[1], -1)
x_test_scaled = x_test_scaled.reshape(x_test.shape[0], x_test.shape[1], -1)

# Build the model architecture
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1], x_train_scaled.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=64, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=64, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=32))
model.add(Dropout(0.2))
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train_scaled, y_train_categorical, validation_data=(x_test_scaled, y_test_categorical), epochs=200, batch_size=256)

# Evaluate the model on the test set
loss, accuracy = model.evaluate(x_test_scaled, y_test_categorical)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 44s 44s/step - loss: 0.6934 - accuracy: 0.4925 - val_loss: 0.6549 - val_accuracy: 0.6471
# Epoch 2/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.5800 - accuracy: 0.8060 - val_loss: 0.6114 - val_accuracy: 0.5882
# Epoch 3/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.3792 - accuracy: 0.8806 - val_loss: 0.6715 - val_accuracy: 0.6471
# Epoch 4/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.2630 - accuracy: 0.9701 - val_loss: 0.7936 - val_accuracy: 0.6471
# Epoch 5/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.1788 - accuracy: 1.0000 - val_loss: 0.9444 - val_accuracy: 0.6471
# Epoch 6/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.1299 - accuracy: 1.0000 - val_loss: 1.1256 - val_accuracy: 0.6471
# Epoch 7/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.0855 - accuracy: 1.0000 - val_loss: 1.3056 - val_accuracy: 0.6471
# Epoch 8/200
# 1/1 [==============================] - 15s 15s/step - loss: 0.0504 - accuracy: 1.0000 - val_loss: 1.4742 - val_accuracy: 0.6471
# Epoch 9/200
# 1/1 [==============================] - 16s 16s/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 1.6257 - val_accuracy: 0.6471
# Epoch 10/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 1.7635 - val_accuracy: 0.6471
# Epoch 11/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 2.0233 - val_accuracy: 0.5882
# Epoch 12/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 2.1920 - val_accuracy: 0.5882
# Epoch 13/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 2.3026 - val_accuracy: 0.5882
# Epoch 14/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 2.3925 - val_accuracy: 0.5882
# Epoch 15/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 2.4708 - val_accuracy: 0.5882
# Epoch 16/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.5400 - val_accuracy: 0.5882
# Epoch 17/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 2.6011 - val_accuracy: 0.5882
# Epoch 18/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 2.6558 - val_accuracy: 0.5882
# Epoch 19/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.7051 - val_accuracy: 0.5882
# Epoch 20/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.7471 - val_accuracy: 0.5882
# Epoch 21/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.7778 - val_accuracy: 0.5882
# Epoch 22/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.7835 - val_accuracy: 0.5882
# Epoch 23/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.7190 - val_accuracy: 0.5882
# Epoch 24/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.4716 - val_accuracy: 0.6471
# Epoch 25/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.4899 - val_accuracy: 0.6471
# Epoch 26/200
# 1/1 [==============================] - 16s 16s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.5153 - val_accuracy: 0.6471
# Epoch 27/200
# 1/1 [==============================] - 15s 15s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.5391 - val_accuracy: 0.6471
# Epoch 28/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.5611 - val_accuracy: 0.6471
# Epoch 29/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.5817 - val_accuracy: 0.6471
# Epoch 30/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.6009 - val_accuracy: 0.6471
# Epoch 31/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.6190 - val_accuracy: 0.6471
# Epoch 32/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.6358 - val_accuracy: 0.6471
# Epoch 33/200
# 1/1 [==============================] - 15s 15s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.7721 - val_accuracy: 0.5882
# Epoch 34/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.1474 - val_accuracy: 0.5882
# Epoch 35/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.1732 - val_accuracy: 0.5882
# Epoch 36/200
# 1/1 [==============================] - 14s 14s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.1906 - val_accuracy: 0.5882
# Epoch 37/200
# 1/1 [==============================] - 13s 13s/step - loss: 8.3914e-04 - accuracy: 1.0000 - val_loss: 3.1976 - val_accuracy: 0.5882
# Epoch 38/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.8184 - val_accuracy: 0.6471
# Epoch 39/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.8298 - val_accuracy: 0.6471
# Epoch 40/200
# 1/1 [==============================] - 12s 12s/step - loss: 8.7418e-04 - accuracy: 1.0000 - val_loss: 2.8405 - val_accuracy: 0.6471
# Epoch 41/200
# 1/1 [==============================] - 12s 12s/step - loss: 7.8326e-04 - accuracy: 1.0000 - val_loss: 2.8506 - val_accuracy: 0.6471
# Epoch 42/200
# 1/1 [==============================] - 13s 13s/step - loss: 7.8582e-04 - accuracy: 1.0000 - val_loss: 2.8602 - val_accuracy: 0.6471
# Epoch 43/200
# 1/1 [==============================] - 13s 13s/step - loss: 8.2915e-04 - accuracy: 1.0000 - val_loss: 2.8690 - val_accuracy: 0.6471
# Epoch 44/200
# 1/1 [==============================] - 13s 13s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.8764 - val_accuracy: 0.6471
# Epoch 45/200
# 1/1 [==============================] - 13s 13s/step - loss: 8.6585e-04 - accuracy: 1.0000 - val_loss: 2.8816 - val_accuracy: 0.6471
# Epoch 46/200
# 1/1 [==============================] - 12s 12s/step - loss: 8.0980e-04 - accuracy: 1.0000 - val_loss: 2.8832 - val_accuracy: 0.6471
# Epoch 47/200
# 1/1 [==============================] - 12s 12s/step - loss: 8.3421e-04 - accuracy: 1.0000 - val_loss: 2.8773 - val_accuracy: 0.6471
# Epoch 48/200
# 1/1 [==============================] - 14s 14s/step - loss: 7.9628e-04 - accuracy: 1.0000 - val_loss: 2.8636 - val_accuracy: 0.6471
# Epoch 49/200
# 1/1 [==============================] - 14s 14s/step - loss: 8.4453e-04 - accuracy: 1.0000 - val_loss: 3.2339 - val_accuracy: 0.5882
# Epoch 50/200
# 1/1 [==============================] - 14s 14s/step - loss: 9.1034e-04 - accuracy: 1.0000 - val_loss: 3.2470 - val_accuracy: 0.5882
# Epoch 51/200
# 1/1 [==============================] - 14s 14s/step - loss: 5.7485e-04 - accuracy: 1.0000 - val_loss: 3.2452 - val_accuracy: 0.5882
# Epoch 52/200
# 1/1 [==============================] - 14s 14s/step - loss: 5.8533e-04 - accuracy: 1.0000 - val_loss: 3.2494 - val_accuracy: 0.5882
# Epoch 53/200
# 1/1 [==============================] - 13s 13s/step - loss: 8.0024e-04 - accuracy: 1.0000 - val_loss: 3.2492 - val_accuracy: 0.5882
# Epoch 54/200
# 1/1 [==============================] - 14s 14s/step - loss: 8.3868e-04 - accuracy: 1.0000 - val_loss: 3.2429 - val_accuracy: 0.5882
# Epoch 55/200
# 1/1 [==============================] - 14s 14s/step - loss: 4.8995e-04 - accuracy: 1.0000 - val_loss: 3.2324 - val_accuracy: 0.5882
# Epoch 56/200
# 1/1 [==============================] - 14s 14s/step - loss: 4.5915e-04 - accuracy: 1.0000 - val_loss: 3.2203 - val_accuracy: 0.5882
# Epoch 57/200
# 1/1 [==============================] - 14s 14s/step - loss: 8.3471e-04 - accuracy: 1.0000 - val_loss: 3.2089 - val_accuracy: 0.5882
# Epoch 58/200
# 1/1 [==============================] - 14s 14s/step - loss: 6.3956e-04 - accuracy: 1.0000 - val_loss: 3.1986 - val_accuracy: 0.5882
# Epoch 59/200
# 1/1 [==============================] - 15s 15s/step - loss: 6.5831e-04 - accuracy: 1.0000 - val_loss: 3.1892 - val_accuracy: 0.5882
# Epoch 60/200
# 1/1 [==============================] - 13s 13s/step - loss: 5.5267e-04 - accuracy: 1.0000 - val_loss: 3.1798 - val_accuracy: 0.5882
# Epoch 61/200
# 1/1 [==============================] - 14s 14s/step - loss: 9.4768e-04 - accuracy: 1.0000 - val_loss: 3.1718 - val_accuracy: 0.5882
# Epoch 62/200
# 1/1 [==============================] - 14s 14s/step - loss: 4.6248e-04 - accuracy: 1.0000 - val_loss: 3.1668 - val_accuracy: 0.5882
# Epoch 63/200
# 1/1 [==============================] - 14s 14s/step - loss: 7.2378e-04 - accuracy: 1.0000 - val_loss: 3.1639 - val_accuracy: 0.5882
# Epoch 64/200
# 1/1 [==============================] - 14s 14s/step - loss: 6.2380e-04 - accuracy: 1.0000 - val_loss: 3.1605 - val_accuracy: 0.5882
# Epoch 65/200
# 1/1 [==============================] - 13s 13s/step - loss: 7.3262e-04 - accuracy: 1.0000 - val_loss: 3.1269 - val_accuracy: 0.5882
# Epoch 66/200
# 1/1 [==============================] - 12s 12s/step - loss: 4.9440e-04 - accuracy: 1.0000 - val_loss: 2.6348 - val_accuracy: 0.6471
# Epoch 67/200
# 1/1 [==============================] - 12s 12s/step - loss: 5.0791e-04 - accuracy: 1.0000 - val_loss: 2.6343 - val_accuracy: 0.6471
# Epoch 68/200
# 1/1 [==============================] - 13s 13s/step - loss: 4.8839e-04 - accuracy: 1.0000 - val_loss: 2.6340 - val_accuracy: 0.6471
# Epoch 69/200
# 1/1 [==============================] - 12s 12s/step - loss: 6.3252e-04 - accuracy: 1.0000 - val_loss: 2.6333 - val_accuracy: 0.6471
# Epoch 70/200
# 1/1 [==============================] - 12s 12s/step - loss: 4.1435e-04 - accuracy: 1.0000 - val_loss: 2.6324 - val_accuracy: 0.6471
# Epoch 71/200
# 1/1 [==============================] - 12s 12s/step - loss: 6.1492e-04 - accuracy: 1.0000 - val_loss: 2.6312 - val_accuracy: 0.6471
# Epoch 72/200
# 1/1 [==============================] - 13s 13s/step - loss: 6.9753e-04 - accuracy: 1.0000 - val_loss: 2.6290 - val_accuracy: 0.6471
# Epoch 73/200
# 1/1 [==============================] - 12s 12s/step - loss: 4.7732e-04 - accuracy: 1.0000 - val_loss: 2.6255 - val_accuracy: 0.6471
# Epoch 74/200
# 1/1 [==============================] - 12s 12s/step - loss: 4.5682e-04 - accuracy: 1.0000 - val_loss: 2.6200 - val_accuracy: 0.6471
# Epoch 75/200
# 1/1 [==============================] - 13s 13s/step - loss: 6.1725e-04 - accuracy: 1.0000 - val_loss: 2.6124 - val_accuracy: 0.6471
# Epoch 76/200
# 1/1 [==============================] - 12s 12s/step - loss: 4.6533e-04 - accuracy: 1.0000 - val_loss: 2.6016 - val_accuracy: 0.6471
# Epoch 77/200
# 1/1 [==============================] - 15s 15s/step - loss: 4.6024e-04 - accuracy: 1.0000 - val_loss: 2.5875 - val_accuracy: 0.6471
# Epoch 78/200
# 1/1 [==============================] - 13s 13s/step - loss: 4.8553e-04 - accuracy: 1.0000 - val_loss: 2.5693 - val_accuracy: 0.6471
# Epoch 79/200
# 1/1 [==============================] - 13s 13s/step - loss: 6.7982e-04 - accuracy: 1.0000 - val_loss: 2.5477 - val_accuracy: 0.6471
# Epoch 80/200
# 1/1 [==============================] - 12s 12s/step - loss: 4.0829e-04 - accuracy: 1.0000 - val_loss: 2.5226 - val_accuracy: 0.6471
# Epoch 81/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.8369e-04 - accuracy: 1.0000 - val_loss: 2.4946 - val_accuracy: 0.6471
# Epoch 82/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.8476e-04 - accuracy: 1.0000 - val_loss: 2.4618 - val_accuracy: 0.6471
# Epoch 83/200
# 1/1 [==============================] - 13s 13s/step - loss: 4.9960e-04 - accuracy: 1.0000 - val_loss: 2.4142 - val_accuracy: 0.6471
# Epoch 84/200
# 1/1 [==============================] - 13s 13s/step - loss: 4.3000e-04 - accuracy: 1.0000 - val_loss: 2.3666 - val_accuracy: 0.6471
# Epoch 85/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.9289e-04 - accuracy: 1.0000 - val_loss: 2.3226 - val_accuracy: 0.6471
# Epoch 86/200
# 1/1 [==============================] - 14s 14s/step - loss: 4.5703e-04 - accuracy: 1.0000 - val_loss: 2.2846 - val_accuracy: 0.6471
# Epoch 87/200
# 1/1 [==============================] - 14s 14s/step - loss: 5.3100e-04 - accuracy: 1.0000 - val_loss: 2.2496 - val_accuracy: 0.6471
# Epoch 88/200
# 1/1 [==============================] - 13s 13s/step - loss: 4.9640e-04 - accuracy: 1.0000 - val_loss: 2.2190 - val_accuracy: 0.6471
# Epoch 89/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.2838e-04 - accuracy: 1.0000 - val_loss: 2.1951 - val_accuracy: 0.6471
# Epoch 90/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.7477e-04 - accuracy: 1.0000 - val_loss: 2.1775 - val_accuracy: 0.6471
# Epoch 91/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.5726e-04 - accuracy: 1.0000 - val_loss: 2.1659 - val_accuracy: 0.7059
# Epoch 92/200
# 1/1 [==============================] - 14s 14s/step - loss: 4.6441e-04 - accuracy: 1.0000 - val_loss: 2.1584 - val_accuracy: 0.7059
# Epoch 93/200
# 1/1 [==============================] - 14s 14s/step - loss: 4.3310e-04 - accuracy: 1.0000 - val_loss: 2.1540 - val_accuracy: 0.7059
# Epoch 94/200
# 1/1 [==============================] - 14s 14s/step - loss: 3.4579e-04 - accuracy: 1.0000 - val_loss: 2.1518 - val_accuracy: 0.7059
# Epoch 95/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.7019e-04 - accuracy: 1.0000 - val_loss: 2.1507 - val_accuracy: 0.7059
# Epoch 96/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.8624e-04 - accuracy: 1.0000 - val_loss: 2.1506 - val_accuracy: 0.7059
# Epoch 97/200
# 1/1 [==============================] - 11s 11s/step - loss: 4.3775e-04 - accuracy: 1.0000 - val_loss: 2.1510 - val_accuracy: 0.7059
# Epoch 98/200
# 1/1 [==============================] - 11s 11s/step - loss: 4.1123e-04 - accuracy: 1.0000 - val_loss: 2.1522 - val_accuracy: 0.7059
# Epoch 99/200
# 1/1 [==============================] - 12s 12s/step - loss: 4.8749e-04 - accuracy: 1.0000 - val_loss: 2.1538 - val_accuracy: 0.7059
# Epoch 100/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.6326e-04 - accuracy: 1.0000 - val_loss: 2.1558 - val_accuracy: 0.7059
# Epoch 101/200
# 1/1 [==============================] - 12s 12s/step - loss: 5.2486e-04 - accuracy: 1.0000 - val_loss: 2.1580 - val_accuracy: 0.7059
# Epoch 102/200
# 1/1 [==============================] - 13s 13s/step - loss: 4.4552e-04 - accuracy: 1.0000 - val_loss: 2.1605 - val_accuracy: 0.7059
# Epoch 103/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.8133e-04 - accuracy: 1.0000 - val_loss: 2.1632 - val_accuracy: 0.7059
# Epoch 104/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.9721e-04 - accuracy: 1.0000 - val_loss: 2.1658 - val_accuracy: 0.7059
# Epoch 105/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.6258e-04 - accuracy: 1.0000 - val_loss: 2.1687 - val_accuracy: 0.7059
# Epoch 106/200
# 1/1 [==============================] - 13s 13s/step - loss: 4.3344e-04 - accuracy: 1.0000 - val_loss: 2.1723 - val_accuracy: 0.7059
# Epoch 107/200
# 1/1 [==============================] - 12s 12s/step - loss: 4.1718e-04 - accuracy: 1.0000 - val_loss: 2.1772 - val_accuracy: 0.7059
# Epoch 108/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.8018e-04 - accuracy: 1.0000 - val_loss: 2.1826 - val_accuracy: 0.7059
# Epoch 109/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.5762e-04 - accuracy: 1.0000 - val_loss: 2.1885 - val_accuracy: 0.7059
# Epoch 110/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.1784e-04 - accuracy: 1.0000 - val_loss: 2.1952 - val_accuracy: 0.7059
# Epoch 111/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.3012e-04 - accuracy: 1.0000 - val_loss: 2.2025 - val_accuracy: 0.7059
# Epoch 112/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.9736e-04 - accuracy: 1.0000 - val_loss: 2.2104 - val_accuracy: 0.6471
# Epoch 113/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.4744e-04 - accuracy: 1.0000 - val_loss: 2.2190 - val_accuracy: 0.6471
# Epoch 114/200
# 1/1 [==============================] - 11s 11s/step - loss: 2.8808e-04 - accuracy: 1.0000 - val_loss: 2.2284 - val_accuracy: 0.6471
# Epoch 115/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.9046e-04 - accuracy: 1.0000 - val_loss: 2.2383 - val_accuracy: 0.6471
# Epoch 116/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.2357e-04 - accuracy: 1.0000 - val_loss: 2.2495 - val_accuracy: 0.6471
# Epoch 117/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.1940e-04 - accuracy: 1.0000 - val_loss: 2.2616 - val_accuracy: 0.6471
# Epoch 118/200
# 1/1 [==============================] - 11s 11s/step - loss: 3.6323e-04 - accuracy: 1.0000 - val_loss: 2.2774 - val_accuracy: 0.6471
# Epoch 119/200
# 1/1 [==============================] - 11s 11s/step - loss: 2.9092e-04 - accuracy: 1.0000 - val_loss: 2.2936 - val_accuracy: 0.6471
# Epoch 120/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.5799e-04 - accuracy: 1.0000 - val_loss: 2.3105 - val_accuracy: 0.6471
# Epoch 121/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.6234e-04 - accuracy: 1.0000 - val_loss: 2.3278 - val_accuracy: 0.6471
# Epoch 122/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.0798e-04 - accuracy: 1.0000 - val_loss: 2.3436 - val_accuracy: 0.6471
# Epoch 123/200
# 1/1 [==============================] - 12s 12s/step - loss: 5.5993e-04 - accuracy: 1.0000 - val_loss: 2.3596 - val_accuracy: 0.6471
# Epoch 124/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.4990e-04 - accuracy: 1.0000 - val_loss: 2.3751 - val_accuracy: 0.6471
# Epoch 125/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.2863e-04 - accuracy: 1.0000 - val_loss: 2.3898 - val_accuracy: 0.6471
# Epoch 126/200
# 1/1 [==============================] - 11s 11s/step - loss: 3.6462e-04 - accuracy: 1.0000 - val_loss: 2.4045 - val_accuracy: 0.6471
# Epoch 127/200
# 1/1 [==============================] - 11s 11s/step - loss: 3.3248e-04 - accuracy: 1.0000 - val_loss: 2.4183 - val_accuracy: 0.6471
# Epoch 128/200
# 1/1 [==============================] - 11s 11s/step - loss: 2.8014e-04 - accuracy: 1.0000 - val_loss: 2.4322 - val_accuracy: 0.6471
# Epoch 129/200
# 1/1 [==============================] - 13s 13s/step - loss: 4.5580e-04 - accuracy: 1.0000 - val_loss: 2.4457 - val_accuracy: 0.6471
# Epoch 130/200
# 1/1 [==============================] - 14s 14s/step - loss: 3.5818e-04 - accuracy: 1.0000 - val_loss: 2.4591 - val_accuracy: 0.6471
# Epoch 131/200
# 1/1 [==============================] - 12s 12s/step - loss: 3.6928e-04 - accuracy: 1.0000 - val_loss: 2.4724 - val_accuracy: 0.6471
# Epoch 132/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.2148e-04 - accuracy: 1.0000 - val_loss: 2.4873 - val_accuracy: 0.6471
# Epoch 133/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.9871e-04 - accuracy: 1.0000 - val_loss: 2.5016 - val_accuracy: 0.6471
# Epoch 134/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.8964e-04 - accuracy: 1.0000 - val_loss: 2.5154 - val_accuracy: 0.6471
# Epoch 135/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.5952e-04 - accuracy: 1.0000 - val_loss: 2.5293 - val_accuracy: 0.6471
# Epoch 136/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.0634e-04 - accuracy: 1.0000 - val_loss: 2.5426 - val_accuracy: 0.6471
# Epoch 137/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.3410e-04 - accuracy: 1.0000 - val_loss: 2.5551 - val_accuracy: 0.6471
# Epoch 138/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.7206e-04 - accuracy: 1.0000 - val_loss: 2.5668 - val_accuracy: 0.6471
# Epoch 139/200
# 1/1 [==============================] - 11s 11s/step - loss: 3.0174e-04 - accuracy: 1.0000 - val_loss: 2.5783 - val_accuracy: 0.6471
# Epoch 140/200
# 1/1 [==============================] - 10s 10s/step - loss: 2.1483e-04 - accuracy: 1.0000 - val_loss: 2.5884 - val_accuracy: 0.6471
# Epoch 141/200
# 1/1 [==============================] - 12s 12s/step - loss: 4.7261e-04 - accuracy: 1.0000 - val_loss: 2.5965 - val_accuracy: 0.6471
# Epoch 142/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.4543e-04 - accuracy: 1.0000 - val_loss: 2.6044 - val_accuracy: 0.6471
# Epoch 143/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.9944e-04 - accuracy: 1.0000 - val_loss: 2.6117 - val_accuracy: 0.6471
# Epoch 144/200
# 1/1 [==============================] - 12s 12s/step - loss: 1.9843e-04 - accuracy: 1.0000 - val_loss: 2.6186 - val_accuracy: 0.6471
# Epoch 145/200
# 1/1 [==============================] - 14s 14s/step - loss: 2.7883e-04 - accuracy: 1.0000 - val_loss: 2.6255 - val_accuracy: 0.6471
# Epoch 146/200
# 1/1 [==============================] - 14s 14s/step - loss: 2.0425e-04 - accuracy: 1.0000 - val_loss: 2.6321 - val_accuracy: 0.6471
# Epoch 147/200
# 1/1 [==============================] - 15s 15s/step - loss: 2.2517e-04 - accuracy: 1.0000 - val_loss: 2.6386 - val_accuracy: 0.6471
# Epoch 148/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.5724e-04 - accuracy: 1.0000 - val_loss: 2.6449 - val_accuracy: 0.6471
# Epoch 149/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.5328e-04 - accuracy: 1.0000 - val_loss: 2.6518 - val_accuracy: 0.6471
# Epoch 150/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.9802e-04 - accuracy: 1.0000 - val_loss: 2.6584 - val_accuracy: 0.6471
# Epoch 151/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.6099e-04 - accuracy: 1.0000 - val_loss: 2.6649 - val_accuracy: 0.6471
# Epoch 152/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.6681e-04 - accuracy: 1.0000 - val_loss: 2.6710 - val_accuracy: 0.6471
# Epoch 153/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.2988e-04 - accuracy: 1.0000 - val_loss: 2.6770 - val_accuracy: 0.6471
# Epoch 154/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.4764e-04 - accuracy: 1.0000 - val_loss: 2.6837 - val_accuracy: 0.6471
# Epoch 155/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.2322e-04 - accuracy: 1.0000 - val_loss: 2.6902 - val_accuracy: 0.6471
# Epoch 156/200
# 1/1 [==============================] - 14s 14s/step - loss: 2.3615e-04 - accuracy: 1.0000 - val_loss: 2.6964 - val_accuracy: 0.6471
# Epoch 157/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.1721e-04 - accuracy: 1.0000 - val_loss: 2.7022 - val_accuracy: 0.6471
# Epoch 158/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.8290e-04 - accuracy: 1.0000 - val_loss: 2.7079 - val_accuracy: 0.6471
# Epoch 159/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.9528e-04 - accuracy: 1.0000 - val_loss: 2.7133 - val_accuracy: 0.6471
# Epoch 160/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.2698e-04 - accuracy: 1.0000 - val_loss: 2.7187 - val_accuracy: 0.6471
# Epoch 161/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.7212e-04 - accuracy: 1.0000 - val_loss: 2.7236 - val_accuracy: 0.6471
# Epoch 162/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.8563e-04 - accuracy: 1.0000 - val_loss: 2.7284 - val_accuracy: 0.6471
# Epoch 163/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.9925e-04 - accuracy: 1.0000 - val_loss: 2.7335 - val_accuracy: 0.6471
# Epoch 164/200
# 1/1 [==============================] - 15s 15s/step - loss: 2.3740e-04 - accuracy: 1.0000 - val_loss: 2.7383 - val_accuracy: 0.6471
# Epoch 165/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.1431e-04 - accuracy: 1.0000 - val_loss: 2.7427 - val_accuracy: 0.6471
# Epoch 166/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.0350e-04 - accuracy: 1.0000 - val_loss: 2.7470 - val_accuracy: 0.6471
# Epoch 167/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.7350e-04 - accuracy: 1.0000 - val_loss: 2.7510 - val_accuracy: 0.6471
# Epoch 168/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.9572e-04 - accuracy: 1.0000 - val_loss: 2.7548 - val_accuracy: 0.6471
# Epoch 169/200
# 1/1 [==============================] - 13s 13s/step - loss: 3.4026e-04 - accuracy: 1.0000 - val_loss: 2.7586 - val_accuracy: 0.6471
# Epoch 170/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.9074e-04 - accuracy: 1.0000 - val_loss: 2.7624 - val_accuracy: 0.6471
# Epoch 171/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.0109e-04 - accuracy: 1.0000 - val_loss: 2.7659 - val_accuracy: 0.6471
# Epoch 172/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.2768e-04 - accuracy: 1.0000 - val_loss: 2.7693 - val_accuracy: 0.6471
# Epoch 173/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.2741e-04 - accuracy: 1.0000 - val_loss: 2.7726 - val_accuracy: 0.6471
# Epoch 174/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.8415e-04 - accuracy: 1.0000 - val_loss: 2.7758 - val_accuracy: 0.6471
# Epoch 175/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.8397e-04 - accuracy: 1.0000 - val_loss: 2.7789 - val_accuracy: 0.6471
# Epoch 176/200
# 1/1 [==============================] - 14s 14s/step - loss: 2.8315e-04 - accuracy: 1.0000 - val_loss: 2.7821 - val_accuracy: 0.6471
# Epoch 177/200
# 1/1 [==============================] - 14s 14s/step - loss: 2.2825e-04 - accuracy: 1.0000 - val_loss: 2.7852 - val_accuracy: 0.6471
# Epoch 178/200
# 1/1 [==============================] - 14s 14s/step - loss: 2.1280e-04 - accuracy: 1.0000 - val_loss: 2.7882 - val_accuracy: 0.6471
# Epoch 179/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.8966e-04 - accuracy: 1.0000 - val_loss: 2.7912 - val_accuracy: 0.6471
# Epoch 180/200
# 1/1 [==============================] - 15s 15s/step - loss: 1.5212e-04 - accuracy: 1.0000 - val_loss: 2.7940 - val_accuracy: 0.6471
# Epoch 181/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.9360e-04 - accuracy: 1.0000 - val_loss: 2.7967 - val_accuracy: 0.6471
# Epoch 182/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.9963e-04 - accuracy: 1.0000 - val_loss: 2.7994 - val_accuracy: 0.6471
# Epoch 183/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.6274e-04 - accuracy: 1.0000 - val_loss: 2.8021 - val_accuracy: 0.6471
# Epoch 184/200
# 1/1 [==============================] - 12s 12s/step - loss: 1.8888e-04 - accuracy: 1.0000 - val_loss: 2.8047 - val_accuracy: 0.6471
# Epoch 185/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.7715e-04 - accuracy: 1.0000 - val_loss: 2.8073 - val_accuracy: 0.6471
# Epoch 186/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.9122e-04 - accuracy: 1.0000 - val_loss: 2.8099 - val_accuracy: 0.6471
# Epoch 187/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.9954e-04 - accuracy: 1.0000 - val_loss: 2.8124 - val_accuracy: 0.6471
# Epoch 188/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.3951e-04 - accuracy: 1.0000 - val_loss: 2.8148 - val_accuracy: 0.6471
# Epoch 189/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.2864e-04 - accuracy: 1.0000 - val_loss: 2.8171 - val_accuracy: 0.6471
# Epoch 190/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.3123e-04 - accuracy: 1.0000 - val_loss: 2.8194 - val_accuracy: 0.6471
# Epoch 191/200
# 1/1 [==============================] - 14s 14s/step - loss: 2.3323e-04 - accuracy: 1.0000 - val_loss: 2.8217 - val_accuracy: 0.6471
# Epoch 192/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.7509e-04 - accuracy: 1.0000 - val_loss: 2.8239 - val_accuracy: 0.6471
# Epoch 193/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.6267e-04 - accuracy: 1.0000 - val_loss: 2.8261 - val_accuracy: 0.6471
# Epoch 194/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.8332e-04 - accuracy: 1.0000 - val_loss: 2.8282 - val_accuracy: 0.6471
# Epoch 195/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.5944e-04 - accuracy: 1.0000 - val_loss: 2.8303 - val_accuracy: 0.6471
# Epoch 196/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.5709e-04 - accuracy: 1.0000 - val_loss: 2.8325 - val_accuracy: 0.6471
# Epoch 197/200
# 1/1 [==============================] - 14s 14s/step - loss: 1.7939e-04 - accuracy: 1.0000 - val_loss: 2.8346 - val_accuracy: 0.6471
# Epoch 198/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.2093e-04 - accuracy: 1.0000 - val_loss: 2.8367 - val_accuracy: 0.6471
# Epoch 199/200
# 1/1 [==============================] - 13s 13s/step - loss: 2.0503e-04 - accuracy: 1.0000 - val_loss: 2.8388 - val_accuracy: 0.6471
# Epoch 200/200
# 1/1 [==============================] - 13s 13s/step - loss: 1.3859e-04 - accuracy: 1.0000 - val_loss: 2.8409 - val_accuracy: 0.6471
# 1/1 [==============================] - 2s 2s/step - loss: 2.8409 - accuracy: 0.6471
# Test loss: 2.840909242630005
# Test accuracy: 0.6470588445663452

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report


y_pred_probs = model.predict(x_test_scaled)

y_pred = np.argmax(y_pred_probs, axis=1)

y_test_single = np.argmax(y_test_categorical, axis=1)

cm = confusion_matrix(y_test_single, y_pred)

report = classification_report(y_test_single, y_pred)

print("Confusion Matrix:")
print(cm)
print("\nClassification Report:")
print(report)
# Out:
# 1/1 [==============================] - 3s 3s/step
# Confusion Matrix:
# [[3 3]
#  [3 8]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         6
#            1       0.73      0.73      0.73        11
#
#     accuracy                           0.65        17
#    macro avg       0.61      0.61      0.61        17
# weighted avg       0.65      0.65      0.65        17
