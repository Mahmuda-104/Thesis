# %%
import os
import scipy.io
import numpy as np
from scipy import signal

# Set the path to the root directory where the "Control" folder is located
data_path = "/kaggle/input/control1"

fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')

for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []

for control_data_path in control_data:
    n_epochs = 105#len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    control_arr = []
    
    for i in range(1, n_epochs+1):
        epoch_path = os.path.join(control_data_path, f"trial{i}.mat")
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        control_arr.append(np.array(downsampled_data))
        
    Control30.append(np.array(control_arr))

Control30 = np.array(Control30)
print(Control30[0].shape)
# Out:
# (105, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_control_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features
for i in range(len(Control30)):
    control_data = Control30[i]
    control_power = []
    for epoch in control_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)

            # alpha_power_normalized = (alpha_power - channel_min_value) / (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value )))
            # beta_power_normalized = (beta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value) ))
            # delta_power_normalized = (delta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value)))

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)
            values=np.array([alpha_power,beta_power,delta_power,entropy_values])
            rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value
            concatenated_data = np.concatenate((channel_data, rescaled_values))

            #concatenated_data = np.concatenate((channel_data, [alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values]))
            #print(alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values)
            epoch_power.append(concatenated_data.tolist())

        control_power.append(np.array(epoch_power))

    all_control_power.append(np.array(control_power))

all_control_power = np.array(all_control_power)
print(all_control_power.shape)
print(len(Control30))
# Out:
# (30, 105, 60, 1004)
# 30

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
data_path = "/kaggle/input/concussed1"
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 105 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    concussed_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
    Concussed52.append(np.array(concussed_arr))

Concussed52 = np.array(Concussed52)
print( Concussed52[0].shape)
# Out:
# (105, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler

from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_concussed_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features within the range of the minimum and maximum values of the corresponding channel
for i in range(len(Concussed52)):
    concussed_data = Concussed52[i]
    concussed_power = []
    for epoch in concussed_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)

            # alpha_power_normalized = (alpha_power - channel_min_value) / (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value )))
            # beta_power_normalized = (beta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value) ))
            # delta_power_normalized = (delta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value)))

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)
            values=np.array([alpha_power,beta_power,delta_power,entropy_values])
            rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value
            concatenated_data = np.concatenate((channel_data, rescaled_values))

            #concatenated_data = np.concatenate((channel_data, [alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values]))
            #print(alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values)
            epoch_power.append(concatenated_data.tolist())

        concussed_power.append(np.array(epoch_power))

    all_concussed_power.append(np.array(concussed_power))

all_concussed_power = np.array(all_concussed_power)
print(all_concussed_power.shape)
print(len(Concussed52))
# Out:
# (49, 105, 60, 1004)
# 49

# %%
dataset = np.concatenate((Control30, Concussed52), axis=0)
labels = np.concatenate((np.zeros(len(Control30)), np.ones(len(Concussed52))))

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(dataset, labels, test_size=0.15, random_state=42)
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
# Out:
# X_train shape: (67, 105, 60, 1000)
# y_train shape: (67,)
# X_val shape: (12, 105, 60, 1000)
# y_val shape: (12,)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

input_shape = (105, 60, 1000)  # Input shape of your EEG data

model = tf.keras.Sequential()
model.add(layers.Conv2D(32, kernel_size=(3, 3), strides=2, activation='relu', padding='same', input_shape=input_shape))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.6))
model.add(layers.Conv2D(64, kernel_size=(3, 3), strides=2, activation='relu', padding='same', kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.6))
model.add(layers.Conv2D(128, kernel_size=(3, 3), strides=2, activation='relu', padding='same', kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.6))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.6))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 53, 30, 32)        288032
#
#  batch_normalization_3 (Batc  (None, 53, 30, 32)       128
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 53, 30, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 27, 15, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 27, 15, 64)       256
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 27, 15, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 14, 8, 128)        73856
#
#  batch_normalization_5 (Batc  (None, 14, 8, 128)       512
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 14, 8, 128)        0
#
#  flatten_1 (Flatten)         (None, 14336)             0
#
#  dense_2 (Dense)             (None, 256)               3670272
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 4,051,809
# Trainable params: 4,051,361
# Non-trainable params: 448
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
callback_list = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True)

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# %%
from sklearn.model_selection import KFold
X =dataset
y = labels 
Epoch = 100
batchSize = 32

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True)

train_accuracies = []
val_accuracies = []

# cross-validation
for train_index, val_index in kf.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    history = model.fit(
    X_train,
    y_train,
    epochs=Epoch,
    batch_size=batchSize,
    validation_data=(X_val, y_val),
    callbacks=callback_list,
    verbose=1)

    # Evaluate the model on training and validation data
    train_loss, train_accuracy = model.evaluate(X_train, y_train)
    val_loss, val_accuracy = model.evaluate(X_val, y_val)

    train_accuracies.append(train_accuracy)
    val_accuracies.append(val_accuracy)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 10s 4s/step - loss: 1.0570 - accuracy: 0.6032 - val_loss: 2.1044 - val_accuracy: 0.6250
# Epoch 2/100
# 2/2 [==============================] - 5s 3s/step - loss: 1.4224 - accuracy: 0.5397 - val_loss: 1.9441 - val_accuracy: 0.6250
# Epoch 3/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7849 - accuracy: 0.6349 - val_loss: 1.8359 - val_accuracy: 0.6250
# Epoch 4/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.2969 - accuracy: 0.4603 - val_loss: 1.7638 - val_accuracy: 0.6250
# Epoch 5/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.3165 - accuracy: 0.6508 - val_loss: 1.7815 - val_accuracy: 0.6250
# Epoch 6/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.1720 - accuracy: 0.5397 - val_loss: 1.7477 - val_accuracy: 0.6250
# Epoch 7/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.0248 - accuracy: 0.6508 - val_loss: 1.7042 - val_accuracy: 0.6250
# Epoch 8/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.9707 - accuracy: 0.5556 - val_loss: 1.6367 - val_accuracy: 0.6250
# Epoch 9/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.9375 - accuracy: 0.6190 - val_loss: 1.6001 - val_accuracy: 0.6250
# Epoch 10/100
# 2/2 [==============================] - 4s 3s/step - loss: 1.6872 - accuracy: 0.4603 - val_loss: 1.5725 - val_accuracy: 0.6250
# Epoch 11/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7895 - accuracy: 0.6825 - val_loss: 1.5607 - val_accuracy: 0.6250
# Epoch 12/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.9605 - accuracy: 0.5873 - val_loss: 1.5088 - val_accuracy: 0.5625
# Epoch 13/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.9703 - accuracy: 0.6667 - val_loss: 1.4617 - val_accuracy: 0.6250
# Epoch 14/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.0077 - accuracy: 0.6349 - val_loss: 1.4613 - val_accuracy: 0.6250
# Epoch 15/100
# 2/2 [==============================] - 4s 3s/step - loss: 0.7377 - accuracy: 0.7143 - val_loss: 1.4474 - val_accuracy: 0.6250
# Epoch 16/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8145 - accuracy: 0.6190 - val_loss: 1.4270 - val_accuracy: 0.5625
# Epoch 17/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.0491 - accuracy: 0.5556 - val_loss: 1.3872 - val_accuracy: 0.6250
# Epoch 18/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.9876 - accuracy: 0.5873 - val_loss: 1.3722 - val_accuracy: 0.6250
# Epoch 19/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.9097 - accuracy: 0.6984 - val_loss: 1.3265 - val_accuracy: 0.6250
# Epoch 20/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8944 - accuracy: 0.6032 - val_loss: 1.2832 - val_accuracy: 0.5000
# Epoch 21/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8288 - accuracy: 0.6349 - val_loss: 1.2399 - val_accuracy: 0.5000
# Epoch 22/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7370 - accuracy: 0.7460 - val_loss: 1.2089 - val_accuracy: 0.5000
# Epoch 23/100
# 2/2 [==============================] - 5s 3s/step - loss: 1.2545 - accuracy: 0.6825 - val_loss: 1.2506 - val_accuracy: 0.5625
# Epoch 24/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8003 - accuracy: 0.7143 - val_loss: 1.3498 - val_accuracy: 0.5000
# Epoch 25/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.9071 - accuracy: 0.5714 - val_loss: 1.4206 - val_accuracy: 0.5625
# Epoch 26/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7424 - accuracy: 0.6667 - val_loss: 1.4759 - val_accuracy: 0.5625
# Epoch 27/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8525 - accuracy: 0.7143 - val_loss: 1.5171 - val_accuracy: 0.5625
# Epoch 28/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8216 - accuracy: 0.6032 - val_loss: 1.5289 - val_accuracy: 0.5000
# Epoch 29/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8631 - accuracy: 0.6349 - val_loss: 1.5087 - val_accuracy: 0.5625
# Epoch 30/100
# 2/2 [==============================] - 4s 3s/step - loss: 0.7732 - accuracy: 0.6984 - val_loss: 1.4928 - val_accuracy: 0.5625
# Epoch 31/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7693 - accuracy: 0.7302 - val_loss: 1.4718 - val_accuracy: 0.5625
# Epoch 32/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7395 - accuracy: 0.7460 - val_loss: 1.4551 - val_accuracy: 0.5625
# 2/2 [==============================] - 2s 462ms/step - loss: 0.6405 - accuracy: 0.9365
# 1/1 [==============================] - 1s 619ms/step - loss: 1.2089 - accuracy: 0.5000
# Epoch 1/100
# 2/2 [==============================] - 6s 3s/step - loss: 0.8500 - accuracy: 0.6667 - val_loss: 0.6047 - val_accuracy: 0.9375
# Epoch 2/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8239 - accuracy: 0.6508 - val_loss: 0.6094 - val_accuracy: 0.9375
# Epoch 3/100
# 2/2 [==============================] - 4s 3s/step - loss: 1.1910 - accuracy: 0.7460 - val_loss: 0.6192 - val_accuracy: 0.8750
# Epoch 4/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.4312 - accuracy: 0.6349 - val_loss: 0.6387 - val_accuracy: 0.7500
# Epoch 5/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.3877 - accuracy: 0.6984 - val_loss: 0.6596 - val_accuracy: 0.7500
# Epoch 6/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.6886 - accuracy: 0.8095 - val_loss: 0.6694 - val_accuracy: 0.6875
# Epoch 7/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8854 - accuracy: 0.6825 - val_loss: 0.6978 - val_accuracy: 0.6875
# Epoch 8/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8997 - accuracy: 0.6825 - val_loss: 0.7078 - val_accuracy: 0.6875
# Epoch 9/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7109 - accuracy: 0.7302 - val_loss: 0.7077 - val_accuracy: 0.6875
# Epoch 10/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.9504 - accuracy: 0.6349 - val_loss: 0.7136 - val_accuracy: 0.6250
# Epoch 11/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.8667 - accuracy: 0.7302 - val_loss: 0.7027 - val_accuracy: 0.6875
# 2/2 [==============================] - 2s 449ms/step - loss: 0.7784 - accuracy: 0.8571
# 1/1 [==============================] - 1s 613ms/step - loss: 0.6047 - accuracy: 0.9375
# Epoch 1/100
# 2/2 [==============================] - 7s 3s/step - loss: 1.0768 - accuracy: 0.5556 - val_loss: 0.6589 - val_accuracy: 1.0000
# Epoch 2/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.2976 - accuracy: 0.7302 - val_loss: 0.6601 - val_accuracy: 1.0000
# Epoch 3/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.1697 - accuracy: 0.6667 - val_loss: 0.6618 - val_accuracy: 1.0000
# Epoch 4/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8964 - accuracy: 0.7143 - val_loss: 0.6663 - val_accuracy: 0.9375
# Epoch 5/100
# 2/2 [==============================] - 5s 3s/step - loss: 0.7489 - accuracy: 0.6667 - val_loss: 0.6738 - val_accuracy: 0.9375
# Epoch 6/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.4178 - accuracy: 0.6984 - val_loss: 0.6781 - val_accuracy: 0.9375
# Epoch 7/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7488 - accuracy: 0.6667 - val_loss: 0.6824 - val_accuracy: 0.8125
# Epoch 8/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8556 - accuracy: 0.6508 - val_loss: 0.6863 - val_accuracy: 0.7500
# Epoch 9/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8639 - accuracy: 0.5397 - val_loss: 0.6845 - val_accuracy: 0.7500
# Epoch 10/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.0375 - accuracy: 0.6508 - val_loss: 0.6813 - val_accuracy: 0.7500
# Epoch 11/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8982 - accuracy: 0.6825 - val_loss: 0.6820 - val_accuracy: 0.7500
# 2/2 [==============================] - 2s 467ms/step - loss: 0.7187 - accuracy: 0.8254
# 1/1 [==============================] - 1s 612ms/step - loss: 0.6589 - accuracy: 1.0000
# Epoch 1/100
# 2/2 [==============================] - 6s 3s/step - loss: 1.0159 - accuracy: 0.5873 - val_loss: 0.5900 - val_accuracy: 1.0000
# Epoch 2/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.3324 - accuracy: 0.6032 - val_loss: 0.5901 - val_accuracy: 1.0000
# Epoch 3/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.9725 - accuracy: 0.5238 - val_loss: 0.5931 - val_accuracy: 1.0000
# Epoch 4/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.0493 - accuracy: 0.7143 - val_loss: 0.5967 - val_accuracy: 1.0000
# Epoch 5/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.2211 - accuracy: 0.5556 - val_loss: 0.6030 - val_accuracy: 1.0000
# Epoch 6/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.0190 - accuracy: 0.6667 - val_loss: 0.6070 - val_accuracy: 1.0000
# Epoch 7/100
# 2/2 [==============================] - 5s 2s/step - loss: 1.4615 - accuracy: 0.5079 - val_loss: 0.6060 - val_accuracy: 1.0000
# Epoch 8/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.2313 - accuracy: 0.6190 - val_loss: 0.6028 - val_accuracy: 1.0000
# Epoch 9/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8805 - accuracy: 0.6349 - val_loss: 0.6064 - val_accuracy: 1.0000
# Epoch 10/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8021 - accuracy: 0.6190 - val_loss: 0.6160 - val_accuracy: 1.0000
# Epoch 11/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7500 - accuracy: 0.6190 - val_loss: 0.6237 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 461ms/step - loss: 0.7062 - accuracy: 0.8254
# 1/1 [==============================] - 1s 617ms/step - loss: 0.5900 - accuracy: 1.0000
# Epoch 1/100
# 2/2 [==============================] - 7s 3s/step - loss: 1.0717 - accuracy: 0.5938 - val_loss: 0.6790 - val_accuracy: 0.8667
# Epoch 2/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.8797 - accuracy: 0.5781 - val_loss: 0.6759 - val_accuracy: 0.8667
# Epoch 3/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.0494 - accuracy: 0.5312 - val_loss: 0.6728 - val_accuracy: 0.8000
# Epoch 4/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8878 - accuracy: 0.6562 - val_loss: 0.6703 - val_accuracy: 0.8667
# Epoch 5/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.6398 - accuracy: 0.7188 - val_loss: 0.6697 - val_accuracy: 1.0000
# Epoch 6/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8097 - accuracy: 0.6406 - val_loss: 0.6679 - val_accuracy: 1.0000
# Epoch 7/100
# 2/2 [==============================] - 4s 3s/step - loss: 0.8020 - accuracy: 0.6406 - val_loss: 0.6673 - val_accuracy: 1.0000
# Epoch 8/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7966 - accuracy: 0.7031 - val_loss: 0.6661 - val_accuracy: 0.9333
# Epoch 9/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.9785 - accuracy: 0.5938 - val_loss: 0.6668 - val_accuracy: 0.9333
# Epoch 10/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.9765 - accuracy: 0.6250 - val_loss: 0.6686 - val_accuracy: 0.9333
# Epoch 11/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.8977 - accuracy: 0.6250 - val_loss: 0.6700 - val_accuracy: 0.8667
# Epoch 12/100
# 2/2 [==============================] - 4s 3s/step - loss: 0.7851 - accuracy: 0.7188 - val_loss: 0.6732 - val_accuracy: 1.0000
# Epoch 13/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7063 - accuracy: 0.7031 - val_loss: 0.6778 - val_accuracy: 1.0000
# Epoch 14/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.6516 - accuracy: 0.7500 - val_loss: 0.6803 - val_accuracy: 1.0000
# Epoch 15/100
# 2/2 [==============================] - 5s 2s/step - loss: 0.9032 - accuracy: 0.6562 - val_loss: 0.6829 - val_accuracy: 1.0000
# Epoch 16/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.7800 - accuracy: 0.7188 - val_loss: 0.6885 - val_accuracy: 0.9333
# Epoch 17/100
# 2/2 [==============================] - 4s 2s/step - loss: 0.6977 - accuracy: 0.7344 - val_loss: 0.6943 - val_accuracy: 0.9333
# Epoch 18/100
# 2/2 [==============================] - 4s 3s/step - loss: 0.6433 - accuracy: 0.6875 - val_loss: 0.6984 - val_accuracy: 0.8667
# 2/2 [==============================] - 2s 486ms/step - loss: 0.6196 - accuracy: 0.9688
# 1/1 [==============================] - 1s 600ms/step - loss: 0.6661 - accuracy: 0.9333

# %%
# Calculate the average accuracies
avg_train_accuracy = np.mean(train_accuracies)
avg_val_accuracy = np.mean(val_accuracies)

print('Average Training Accuracy:', avg_train_accuracy)
print('Average Validation Accuracy:', avg_val_accuracy)
# Out:
# Average Training Accuracy: 0.8826388955116272
# Average Validation Accuracy: 0.8741666674613953

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Get predicted probabilities for the test set
y_pred_probs = model.predict(X_test)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)

# Convert one-hot encoded labels to their original form
y_test_original = np.argmax(y_test, axis=1)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test_original, y_pred))

# Generate confusion matrix
print("Confusion Matrix:")
cm = confusion_matrix(y_test_original, y_pred)
print(cm)
