# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmuda-104/Thesis/blob/main/Raw_EEG_BP%2BNormalized_Feature3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
from scipy.io import loadmat

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Data'

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
lowcut = 0.5 
highcut = 50  
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')
for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []
for control_data_path in control_data:
    n_epochs = 35 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    control_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{control_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]

        b, a = signal.butter(4, [lowcut, highcut], fs=fs_original, btype='band')
        filtered_data = signal.filtfilt(b, a, mat_data1, axis=-1)
        
        # Downsampling
        num_samples_original = filtered_data.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(filtered_data, num_samples_new, axis=-1)
        
        control_arr.append(np.array(downsampled_data))
        
    Control30.append(np.array(control_arr))

Control30 = np.array(Control30)
print( Control30[0].shape)
# Out:
# (35, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler
from google.colab import drive
from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_control_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features within the range of the minimum and maximum values of the corresponding channel
for i in range(len(Control30)):
    control_data = Control30[i]
    control_power = []
    for epoch in control_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            # Get the minimum and maximum values within the current channel
            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)

            # Normalize the features within the range of the current channel
            alpha_power_normalized = (alpha_power - channel_min_value) / (2*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value )))
            beta_power_normalized = (beta_power - channel_min_value) /  (2*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value) ))
            delta_power_normalized = (delta_power - channel_min_value) /  (2*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value)))

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)

            concatenated_data = np.concatenate((channel_data, [alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values]))
            #print(alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values)
            epoch_power.append(concatenated_data.tolist())

        control_power.append(np.array(epoch_power))

    all_control_power.append(np.array(control_power))

all_control_power = np.array(all_control_power)
print(all_control_power.shape)
print(len(Control30))
# Out:
# (32, 35, 60, 1004)
# 32

# %%
import os
import scipy.io
import numpy as np
from scipy import signal

lowcut = 0.5 
highcut = 50  
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 35 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    concussed_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        b, a = signal.butter(4, [lowcut, highcut], fs=fs_original, btype='band')
        filtered_data = signal.filtfilt(b, a, mat_data1, axis=-1)
        
        # Downsampling
        num_samples_original = filtered_data.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(filtered_data, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
    Concussed52.append(np.array(concussed_arr))

Concussed52 = np.array(Concussed52)
print( Concussed52[0].shape)
# Out:
# (35, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler
from google.colab import drive
from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_concussed_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features within the range of the minimum and maximum values of the corresponding channel
for i in range(len(Concussed52)):
    concussed_data = Concussed52[i]
    concussed_power = []
    for epoch in concussed_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)
            values=np.array([alpha_power,beta_power,delta_power,entropy_values])

            # Get the minimum and maximum values within the current channel
            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)

            # Normalize the features within the range of the current channel
            # alpha_power_normalized = alpha_power#(alpha_power - channel_min_value)*(channel_max_value-channel_min_value) / (2*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value )))
            # beta_power_normalized = alpha_power#(beta_power - channel_min_value) /  (2*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value) ))
            # delta_power_normalized = alpha_power#(delta_power - channel_min_value) /  (2*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value)))
            rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value
            #print(rescaled_values)
            #print(alpha_power,beta_power,delta_power,channel_min_value,channel_max_value)
            concatenated_data = np.concatenate((channel_data, rescaled_values))
            #print(alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values)
            epoch_power.append(concatenated_data.tolist())

        concussed_power.append(np.array(epoch_power))

    all_concussed_power.append(np.array(concussed_power))

all_concussed_power = np.array(all_concussed_power)
print(all_concussed_power.shape)
print(len(Concussed52))
# Out:
# (52, 35, 60, 1004)
# 52

# %%
#concussed_power=np.array(concussed_power)
print(all_concussed_power.shape)
# Out:
# (52, 35, 60, 1004)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
dataset = np.concatenate((all_concussed_power, all_control_power), axis=0)

#(0 for control, 1 for concussed)
labels = np.concatenate((np.zeros(len(all_control_power)), np.ones(len(all_concussed_power))))

# %%
train_ratio = 0.75  # 80% for training
val_ratio = 0.15   # 10% for validation
test_ratio = 0.15  # 10% for testing

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=test_ratio, stratify=labels, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_ratio/(train_ratio+val_ratio), stratify=y_train, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Normalize the input data
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0
input_shape = X_train.shape[1:]
# Build the CNN model
model = tf.keras.Sequential()
model.add(layers.Conv2D(16, kernel_size=(6, 6), strides=1, activation='relu', padding='same', input_shape=input_shape))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(32, kernel_size=(3, 3), activation='relu', strides=1, padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu', strides=1, padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(2, activation='softmax'))

learning_rate = 0.05
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
val_loss, val_accuracy = model.evaluate(X_val, y_val)

# Print the test accuracy
print("Test Accuracy:", test_accuracy)

# Generate training and testing accuracy
training_accuracy = history.history['accuracy']
testing_accuracy = history.history['val_accuracy']

# Generate learning curve
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plot training and testing accuracy
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(testing_accuracy, label='Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot learning curve
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 2/2 [==============================] - 18s 3s/step - loss: 30176.8555 - accuracy: 0.5254 - val_loss: 13229.6250 - val_accuracy: 0.5833
# Epoch 2/100
# 2/2 [==============================] - 1s 403ms/step - loss: 63874.8281 - accuracy: 0.6271 - val_loss: 0.7637 - val_accuracy: 0.5833
# Epoch 3/100
# 2/2 [==============================] - 1s 334ms/step - loss: 119.0455 - accuracy: 0.6780 - val_loss: 0.7539 - val_accuracy: 0.5833
# Epoch 4/100
# 2/2 [==============================] - 0s 285ms/step - loss: 266.5786 - accuracy: 0.6102 - val_loss: 0.5783 - val_accuracy: 0.5833
# Epoch 5/100
# 2/2 [==============================] - 1s 336ms/step - loss: 11.5560 - accuracy: 0.5424 - val_loss: 0.6091 - val_accuracy: 0.5833
# Epoch 6/100
# 2/2 [==============================] - 1s 338ms/step - loss: 0.5446 - accuracy: 0.6271 - val_loss: 0.6052 - val_accuracy: 0.5833
# Epoch 7/100
# 2/2 [==============================] - 1s 344ms/step - loss: 0.5795 - accuracy: 0.5763 - val_loss: 0.5800 - val_accuracy: 0.5833
# Epoch 8/100
# 2/2 [==============================] - 1s 338ms/step - loss: 9210.4609 - accuracy: 0.6441 - val_loss: 0.5818 - val_accuracy: 0.5833
# Epoch 9/100
# 2/2 [==============================] - 1s 314ms/step - loss: 0.5524 - accuracy: 0.6102 - val_loss: 0.7375 - val_accuracy: 0.4167
# Epoch 10/100
# 2/2 [==============================] - 0s 298ms/step - loss: 235697.2344 - accuracy: 0.5932 - val_loss: 0.7325 - val_accuracy: 0.4167
# Epoch 11/100
# 2/2 [==============================] - 0s 299ms/step - loss: 0.5496 - accuracy: 0.5763 - val_loss: 0.7134 - val_accuracy: 0.4167
# Epoch 12/100
# 2/2 [==============================] - 0s 288ms/step - loss: 0.6467 - accuracy: 0.5085 - val_loss: 0.6831 - val_accuracy: 0.5833
# Epoch 13/100
# 2/2 [==============================] - 0s 291ms/step - loss: 0.6180 - accuracy: 0.6441 - val_loss: 0.6868 - val_accuracy: 0.5833
# Epoch 14/100
# 2/2 [==============================] - 1s 357ms/step - loss: 0.6538 - accuracy: 0.6441 - val_loss: 0.7029 - val_accuracy: 0.5833
# 1/1 [==============================] - 1s 667ms/step - loss: 0.6470 - accuracy: 0.4615
# 1/1 [==============================] - 0s 125ms/step - loss: 0.5783 - accuracy: 0.5833
# Test Accuracy: 0.4615384638309479

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# Split the dataset into training, validation, and test sets
# X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=test_ratio, stratify=labels, random_state=42)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_ratio/(train_ratio+val_ratio), stratify=y_train, random_state=42)

# Normalize the input data (if required)
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0

# Reshape the input data based on the expected input shape of the model
input_shape = X_train.shape[1:]  # Assuming the first dimension is the number of samples
X_train = X_train.reshape((-1,) + input_shape)
X_val = X_val.reshape((-1,) + input_shape)
X_test = X_test.reshape((-1,) + input_shape)

# Build the CNN model
model = tf.keras.Sequential()
model.add(layers.Conv2D(16, kernel_size=(6, 6),strides=1, activation='relu',padding='same', input_shape=input_shape))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(32, kernel_size=(3, 3), strides=1,activation='relu',padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(64, kernel_size=(3, 3),strides=1, activation='relu',padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model with the desired loss function and optimizer
learning_rate = 0.00001  # Specify your desired learning rate
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
val_loss, val_accuracy = model.evaluate(X_val, y_val)

# Print the test accuracy
print("Test Accuracy:", test_accuracy)

training_accuracy = history.history['accuracy']
testing_accuracy = history.history['val_accuracy']

# Generate learning curve
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plot training and testing accuracy
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(testing_accuracy, label='Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot learning curve
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 2/2 [==============================] - 4s 671ms/step - loss: 72.2950 - accuracy: 0.4746 - val_loss: 71.6340 - val_accuracy: 0.4167
# Epoch 2/100
# 2/2 [==============================] - 1s 345ms/step - loss: 81.3724 - accuracy: 0.4407 - val_loss: 67.1485 - val_accuracy: 0.4167
# Epoch 3/100
# 2/2 [==============================] - 0s 310ms/step - loss: 66.8767 - accuracy: 0.3220 - val_loss: 62.5598 - val_accuracy: 0.4167
# Epoch 4/100
# 2/2 [==============================] - 0s 290ms/step - loss: 86.3043 - accuracy: 0.5254 - val_loss: 58.0746 - val_accuracy: 0.4167
# Epoch 5/100
# 2/2 [==============================] - 1s 334ms/step - loss: 73.4169 - accuracy: 0.4237 - val_loss: 54.1582 - val_accuracy: 0.4167
# Epoch 6/100
# 2/2 [==============================] - 1s 329ms/step - loss: 48.9215 - accuracy: 0.4068 - val_loss: 50.5207 - val_accuracy: 0.4167
# Epoch 7/100
# 2/2 [==============================] - 1s 303ms/step - loss: 107.2017 - accuracy: 0.4237 - val_loss: 46.9990 - val_accuracy: 0.4167
# Epoch 8/100
# 2/2 [==============================] - 1s 337ms/step - loss: 108.4009 - accuracy: 0.4407 - val_loss: 43.4532 - val_accuracy: 0.4167
# Epoch 9/100
# 2/2 [==============================] - 1s 346ms/step - loss: 39.3390 - accuracy: 0.4237 - val_loss: 39.9375 - val_accuracy: 0.4167
# Epoch 10/100
# 2/2 [==============================] - 1s 350ms/step - loss: 93.9727 - accuracy: 0.3559 - val_loss: 36.7013 - val_accuracy: 0.4167
# Epoch 11/100
# 2/2 [==============================] - 0s 295ms/step - loss: 40.2129 - accuracy: 0.3559 - val_loss: 33.6811 - val_accuracy: 0.4167
# Epoch 12/100
# 2/2 [==============================] - 1s 341ms/step - loss: 43.6511 - accuracy: 0.4407 - val_loss: 30.6656 - val_accuracy: 0.4167
# Epoch 13/100
# 2/2 [==============================] - 0s 289ms/step - loss: 32.3030 - accuracy: 0.3898 - val_loss: 27.8408 - val_accuracy: 0.4167
# Epoch 14/100
# 2/2 [==============================] - 0s 302ms/step - loss: 54.1117 - accuracy: 0.4746 - val_loss: 25.0331 - val_accuracy: 0.4167
# Epoch 15/100
# 2/2 [==============================] - 1s 347ms/step - loss: 40.3271 - accuracy: 0.4237 - val_loss: 22.0928 - val_accuracy: 0.4167
# Epoch 16/100
# 2/2 [==============================] - 0s 291ms/step - loss: 33.8089 - accuracy: 0.4576 - val_loss: 19.4500 - val_accuracy: 0.4167
# Epoch 17/100
# 2/2 [==============================] - 1s 345ms/step - loss: 32.3023 - accuracy: 0.6610 - val_loss: 17.0203 - val_accuracy: 0.4167
# Epoch 18/100
# 2/2 [==============================] - 0s 288ms/step - loss: 71.3879 - accuracy: 0.4576 - val_loss: 14.5289 - val_accuracy: 0.4167
# Epoch 19/100
# 2/2 [==============================] - 1s 415ms/step - loss: 29.3504 - accuracy: 0.4746 - val_loss: 12.1846 - val_accuracy: 0.4167
# Epoch 20/100
# 2/2 [==============================] - 1s 402ms/step - loss: 30.7352 - accuracy: 0.5424 - val_loss: 9.9696 - val_accuracy: 0.4167
# Epoch 21/100
# 2/2 [==============================] - 1s 443ms/step - loss: 38.0298 - accuracy: 0.4576 - val_loss: 8.0956 - val_accuracy: 0.4167
# Epoch 22/100
# 2/2 [==============================] - 1s 624ms/step - loss: 83.6914 - accuracy: 0.4576 - val_loss: 6.4107 - val_accuracy: 0.4167
# Epoch 23/100
# 2/2 [==============================] - 1s 594ms/step - loss: 42.4204 - accuracy: 0.7288 - val_loss: 4.7177 - val_accuracy: 0.4167
# Epoch 24/100
# 2/2 [==============================] - 1s 349ms/step - loss: 29.4344 - accuracy: 0.5254 - val_loss: 3.1420 - val_accuracy: 0.4167
# Epoch 25/100
# 2/2 [==============================] - 0s 298ms/step - loss: 30.7095 - accuracy: 0.5085 - val_loss: 2.3847 - val_accuracy: 0.5000
# Epoch 26/100
# 2/2 [==============================] - 1s 339ms/step - loss: 45.6831 - accuracy: 0.5254 - val_loss: 2.1601 - val_accuracy: 0.5000
# Epoch 27/100
# 2/2 [==============================] - 1s 346ms/step - loss: 22.3237 - accuracy: 0.4237 - val_loss: 1.8971 - val_accuracy: 0.5000
# Epoch 28/100
# 2/2 [==============================] - 0s 296ms/step - loss: 32.3974 - accuracy: 0.4237 - val_loss: 1.6500 - val_accuracy: 0.5000
# Epoch 29/100
# 2/2 [==============================] - 1s 348ms/step - loss: 17.2346 - accuracy: 0.6441 - val_loss: 1.4501 - val_accuracy: 0.5000
# Epoch 30/100
# 2/2 [==============================] - 1s 333ms/step - loss: 21.5261 - accuracy: 0.5593 - val_loss: 1.2879 - val_accuracy: 0.5000
# Epoch 31/100
# 2/2 [==============================] - 1s 353ms/step - loss: 34.7855 - accuracy: 0.5085 - val_loss: 1.1499 - val_accuracy: 0.5833
# Epoch 32/100
# 2/2 [==============================] - 0s 293ms/step - loss: 28.1723 - accuracy: 0.4746 - val_loss: 1.0430 - val_accuracy: 0.5833
# Epoch 33/100
# 2/2 [==============================] - 1s 345ms/step - loss: 41.5316 - accuracy: 0.5254 - val_loss: 0.9786 - val_accuracy: 0.5833
# Epoch 34/100
# 2/2 [==============================] - 0s 285ms/step - loss: 22.6003 - accuracy: 0.6441 - val_loss: 0.9222 - val_accuracy: 0.5833
# Epoch 35/100
# 2/2 [==============================] - 0s 292ms/step - loss: 38.0098 - accuracy: 0.5254 - val_loss: 0.8788 - val_accuracy: 0.5833
# Epoch 36/100
# 2/2 [==============================] - 1s 334ms/step - loss: 48.4413 - accuracy: 0.5254 - val_loss: 0.8255 - val_accuracy: 0.5833
# Epoch 37/100
# 2/2 [==============================] - 0s 302ms/step - loss: 29.4842 - accuracy: 0.5085 - val_loss: 0.7820 - val_accuracy: 0.5833
# Epoch 38/100
# 2/2 [==============================] - 0s 295ms/step - loss: 80.7049 - accuracy: 0.4915 - val_loss: 0.7371 - val_accuracy: 0.6667
# Epoch 39/100
# 2/2 [==============================] - 0s 298ms/step - loss: 41.7787 - accuracy: 0.5424 - val_loss: 0.6859 - val_accuracy: 0.6667
# Epoch 40/100
# 2/2 [==============================] - 1s 332ms/step - loss: 50.6431 - accuracy: 0.5763 - val_loss: 0.6246 - val_accuracy: 0.7500
# Epoch 41/100
# 2/2 [==============================] - 0s 300ms/step - loss: 51.8239 - accuracy: 0.5254 - val_loss: 0.5621 - val_accuracy: 0.7500
# Epoch 42/100
# 2/2 [==============================] - 1s 306ms/step - loss: 50.5231 - accuracy: 0.4407 - val_loss: 0.5205 - val_accuracy: 0.7500
# Epoch 43/100
# 2/2 [==============================] - 1s 410ms/step - loss: 57.5280 - accuracy: 0.5763 - val_loss: 0.4899 - val_accuracy: 0.6667
# Epoch 44/100
# 2/2 [==============================] - 1s 471ms/step - loss: 31.6995 - accuracy: 0.6610 - val_loss: 0.4644 - val_accuracy: 0.6667
# Epoch 45/100
# 2/2 [==============================] - 1s 447ms/step - loss: 23.3663 - accuracy: 0.5763 - val_loss: 0.4514 - val_accuracy: 0.7500
# Epoch 46/100
# 2/2 [==============================] - 1s 426ms/step - loss: 37.9550 - accuracy: 0.6441 - val_loss: 0.4441 - val_accuracy: 0.7500
# Epoch 47/100
# 2/2 [==============================] - 1s 594ms/step - loss: 51.3068 - accuracy: 0.6441 - val_loss: 0.4336 - val_accuracy: 0.6667
# Epoch 48/100
# 2/2 [==============================] - 1s 297ms/step - loss: 51.0974 - accuracy: 0.5763 - val_loss: 0.4261 - val_accuracy: 0.6667
# Epoch 49/100
# 2/2 [==============================] - 1s 293ms/step - loss: 31.3691 - accuracy: 0.5424 - val_loss: 0.4229 - val_accuracy: 0.6667
# Epoch 50/100
# 2/2 [==============================] - 0s 294ms/step - loss: 37.9869 - accuracy: 0.5254 - val_loss: 0.4215 - val_accuracy: 0.6667
# Epoch 51/100
# 2/2 [==============================] - 1s 354ms/step - loss: 20.0392 - accuracy: 0.4915 - val_loss: 0.4210 - val_accuracy: 0.6667
# Epoch 52/100
# 2/2 [==============================] - 1s 329ms/step - loss: 38.0667 - accuracy: 0.5085 - val_loss: 0.4237 - val_accuracy: 0.6667
# Epoch 53/100
# 2/2 [==============================] - 0s 299ms/step - loss: 68.3794 - accuracy: 0.4068 - val_loss: 0.4271 - val_accuracy: 0.7500
# Epoch 54/100
# 2/2 [==============================] - 1s 328ms/step - loss: 22.5506 - accuracy: 0.4237 - val_loss: 0.4342 - val_accuracy: 0.7500
# Epoch 55/100
# 2/2 [==============================] - 1s 355ms/step - loss: 32.8397 - accuracy: 0.5763 - val_loss: 0.4444 - val_accuracy: 0.7500
# Epoch 56/100
# 2/2 [==============================] - 1s 338ms/step - loss: 31.0268 - accuracy: 0.5424 - val_loss: 0.4577 - val_accuracy: 0.7500
# Epoch 57/100
# 2/2 [==============================] - 1s 345ms/step - loss: 16.7827 - accuracy: 0.5424 - val_loss: 0.4754 - val_accuracy: 0.7500
# Epoch 58/100
# 2/2 [==============================] - 1s 331ms/step - loss: 22.7877 - accuracy: 0.5085 - val_loss: 0.4994 - val_accuracy: 0.8333
# Epoch 59/100
# 2/2 [==============================] - 0s 294ms/step - loss: 20.4506 - accuracy: 0.6271 - val_loss: 0.5210 - val_accuracy: 0.8333
# Epoch 60/100
# 2/2 [==============================] - 1s 341ms/step - loss: 20.2821 - accuracy: 0.5763 - val_loss: 0.5381 - val_accuracy: 0.8333
# Epoch 61/100
# 2/2 [==============================] - 0s 301ms/step - loss: 101.6940 - accuracy: 0.4746 - val_loss: 0.5583 - val_accuracy: 0.8333
# 1/1 [==============================] - 0s 131ms/step - loss: 1.6455 - accuracy: 0.6923
# 1/1 [==============================] - 0s 120ms/step - loss: 0.4210 - accuracy: 0.6667
# Test Accuracy: 0.692307710647583
