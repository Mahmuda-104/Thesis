# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmuda-104/Thesis/blob/main/Raw_EEG%2BFeature2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
from scipy.io import loadmat

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Data'

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')
for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []
for control_data_path in control_data:
    n_epochs = 40 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    control_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{control_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        control_arr.append(np.array(downsampled_data))
        
    Control30.append(np.array(control_arr))

Control30 = np.array(Control30)
print( Control30[0].shape)
# Out:
# (40, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler
from google.colab import drive
from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_control_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

for i in range(0, len(Control30)):
    control_data = Control30[i]
    control_power = []
    for epoch in control_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)

            concatenated_data = np.concatenate((channel_data, [alpha_power, beta_power, delta_power, entropy_values]))
            epoch_power.append(concatenated_data.tolist())
            #print(alpha_power,beta_power,delta_power,entropy_values)

        control_power.append(np.array(epoch_power))

    all_control_power.append(np.array(control_power))
all_control_power=np.array(all_control_power)
print(all_control_power.shape)
print(len(Control30))
# Out:
# (32, 40, 60, 1004)
# 32

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
 
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 40 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    concussed_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
    Concussed52.append(np.array(concussed_arr))

Concussed52 = np.array(Concussed52)
print( Concussed52[0].shape)
# Out:
# (40, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler
from google.colab import drive
from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_concussed_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

for i in range(0, len(Concussed52)):
    concussed_data = Concussed52[i]
    concussed_power = []
    for epoch in concussed_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)

            concatenated_data = np.concatenate((channel_data, [alpha_power, beta_power, delta_power, entropy_values]))
            epoch_power.append(concatenated_data.tolist())

        concussed_power.append(np.array(epoch_power))

    all_concussed_power.append(np.array(concussed_power))

all_concussed_power=np.array(all_concussed_power)
print(len(all_concussed_power))
print(len(Concussed52))
# Out:
# 52
# 52

# %%
#concussed_power=np.array(concussed_power)
print(all_concussed_power.shape)
# Out:
# (52, 40, 60, 1004)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
dataset = np.concatenate((all_concussed_power, all_control_power), axis=0)

#(0 for control, 1 for concussed)
labels = np.concatenate((np.zeros(len(all_control_power)), np.ones(len(all_concussed_power))))

# %%
train_ratio = 0.8  # 80% for training
val_ratio = 0.1   # 10% for validation
test_ratio = 0.1  # 10% for testing

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=test_ratio, stratify=labels, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_ratio/(train_ratio+val_ratio), stratify=y_train, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Normalize the input data
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0
input_shape = X_train.shape[1:]
# Build the CNN model
model = tf.keras.Sequential()
model.add(layers.Conv2D(16, kernel_size=(6, 6), strides=1, activation='relu', padding='same', input_shape=input_shape))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(32, kernel_size=(3, 3), activation='relu', strides=1, padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu', strides=1, padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(2, activation='softmax'))

learning_rate = 0.005
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
val_loss, val_accuracy = model.evaluate(X_val, y_val)

# Print the test accuracy
print("Test Accuracy:", test_accuracy)

# Generate training and testing accuracy
training_accuracy = history.history['accuracy']
testing_accuracy = history.history['val_accuracy']

# Generate learning curve
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plot training and testing accuracy
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(testing_accuracy, label='Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot learning curve
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 3/3 [==============================] - 16s 852ms/step - loss: 3314125.0000 - accuracy: 0.5455 - val_loss: 3026735.0000 - val_accuracy: 0.3333
# Epoch 2/100
# 3/3 [==============================] - 1s 221ms/step - loss: 2309830.5000 - accuracy: 0.4697 - val_loss: 73322.7266 - val_accuracy: 0.6667
# Epoch 3/100
# 3/3 [==============================] - 1s 224ms/step - loss: 745135.1250 - accuracy: 0.6515 - val_loss: 44394.2188 - val_accuracy: 0.6667
# Epoch 4/100
# 3/3 [==============================] - 1s 221ms/step - loss: 363035.7500 - accuracy: 0.6364 - val_loss: 21267.0781 - val_accuracy: 0.6667
# Epoch 5/100
# 3/3 [==============================] - 1s 224ms/step - loss: 159073.6250 - accuracy: 0.6364 - val_loss: 8491.5039 - val_accuracy: 0.6667
# Epoch 6/100
# 3/3 [==============================] - 1s 220ms/step - loss: 98487.0391 - accuracy: 0.6667 - val_loss: 26542.2285 - val_accuracy: 0.5556
# Epoch 7/100
# 3/3 [==============================] - 1s 269ms/step - loss: 114891.2578 - accuracy: 0.5758 - val_loss: 22576.8320 - val_accuracy: 0.5556
# Epoch 8/100
# 3/3 [==============================] - 1s 258ms/step - loss: 61259.2031 - accuracy: 0.5909 - val_loss: 21542.9941 - val_accuracy: 0.4444
# Epoch 9/100
# 3/3 [==============================] - 1s 333ms/step - loss: 47410.9609 - accuracy: 0.5303 - val_loss: 20402.8672 - val_accuracy: 0.4444
# Epoch 10/100
# 3/3 [==============================] - 1s 297ms/step - loss: 36172.1836 - accuracy: 0.6667 - val_loss: 18497.3867 - val_accuracy: 0.4444
# Epoch 11/100
# 3/3 [==============================] - 1s 309ms/step - loss: 57262.0469 - accuracy: 0.5152 - val_loss: 13320.5273 - val_accuracy: 0.4444
# Epoch 12/100
# 3/3 [==============================] - 1s 338ms/step - loss: 33385.0664 - accuracy: 0.6970 - val_loss: 8986.0332 - val_accuracy: 0.5556
# Epoch 13/100
# 3/3 [==============================] - 1s 205ms/step - loss: 74807.2734 - accuracy: 0.5455 - val_loss: 7690.2275 - val_accuracy: 0.5556
# Epoch 14/100
# 3/3 [==============================] - 1s 221ms/step - loss: 52450.8828 - accuracy: 0.6364 - val_loss: 4882.1333 - val_accuracy: 0.6667
# Epoch 15/100
# 3/3 [==============================] - 1s 207ms/step - loss: 56627.4688 - accuracy: 0.4697 - val_loss: 5166.4717 - val_accuracy: 0.5556
# Epoch 16/100
# 3/3 [==============================] - 1s 214ms/step - loss: 26662.6016 - accuracy: 0.6212 - val_loss: 6665.0737 - val_accuracy: 0.5556
# Epoch 17/100
# 3/3 [==============================] - 1s 219ms/step - loss: 18975.1855 - accuracy: 0.6970 - val_loss: 6677.7065 - val_accuracy: 0.5556
# Epoch 18/100
# 3/3 [==============================] - 1s 215ms/step - loss: 51395.6953 - accuracy: 0.6364 - val_loss: 6358.9209 - val_accuracy: 0.4444
# Epoch 19/100
# 3/3 [==============================] - 1s 222ms/step - loss: 38202.3477 - accuracy: 0.6667 - val_loss: 5698.0039 - val_accuracy: 0.5556
# Epoch 20/100
# 3/3 [==============================] - 1s 222ms/step - loss: 50031.9648 - accuracy: 0.6515 - val_loss: 3419.4536 - val_accuracy: 0.3333
# Epoch 21/100
# 3/3 [==============================] - 1s 224ms/step - loss: 31471.3613 - accuracy: 0.6061 - val_loss: 3311.6428 - val_accuracy: 0.2222
# Epoch 22/100
# 3/3 [==============================] - 1s 217ms/step - loss: 42585.0078 - accuracy: 0.6818 - val_loss: 3832.5833 - val_accuracy: 0.3333
# Epoch 23/100
# 3/3 [==============================] - 1s 222ms/step - loss: 16605.0000 - accuracy: 0.6212 - val_loss: 3229.3013 - val_accuracy: 0.4444
# Epoch 24/100
# 3/3 [==============================] - 1s 220ms/step - loss: 30608.1641 - accuracy: 0.6515 - val_loss: 3801.5278 - val_accuracy: 0.4444
# Epoch 25/100
# 3/3 [==============================] - 1s 224ms/step - loss: 48629.7734 - accuracy: 0.6364 - val_loss: 2995.7600 - val_accuracy: 0.4444
# Epoch 26/100
# 3/3 [==============================] - 1s 224ms/step - loss: 18618.5332 - accuracy: 0.5303 - val_loss: 2468.5498 - val_accuracy: 0.5556
# Epoch 27/100
# 3/3 [==============================] - 1s 217ms/step - loss: 15400.7100 - accuracy: 0.6364 - val_loss: 2603.8401 - val_accuracy: 0.6667
# Epoch 28/100
# 3/3 [==============================] - 1s 299ms/step - loss: 24793.5469 - accuracy: 0.7121 - val_loss: 2754.8933 - val_accuracy: 0.6667
# Epoch 29/100
# 3/3 [==============================] - 1s 319ms/step - loss: 24310.7812 - accuracy: 0.5152 - val_loss: 2606.2065 - val_accuracy: 0.6667
# Epoch 30/100
# 3/3 [==============================] - 1s 274ms/step - loss: 23134.6523 - accuracy: 0.6818 - val_loss: 1951.2450 - val_accuracy: 0.6667
# Epoch 31/100
# 3/3 [==============================] - 1s 307ms/step - loss: 26119.9883 - accuracy: 0.6364 - val_loss: 1291.0343 - val_accuracy: 0.6667
# Epoch 32/100
# 3/3 [==============================] - 1s 230ms/step - loss: 8189.4897 - accuracy: 0.7121 - val_loss: 1304.1567 - val_accuracy: 0.6667
# Epoch 33/100
# 3/3 [==============================] - 1s 222ms/step - loss: 31596.4414 - accuracy: 0.6364 - val_loss: 1211.0885 - val_accuracy: 0.6667
# Epoch 34/100
# 3/3 [==============================] - 1s 208ms/step - loss: 30894.3848 - accuracy: 0.6364 - val_loss: 752.7589 - val_accuracy: 0.5556
# Epoch 35/100
# 3/3 [==============================] - 1s 216ms/step - loss: 25826.4668 - accuracy: 0.6364 - val_loss: 1173.3502 - val_accuracy: 0.5556
# Epoch 36/100
# 3/3 [==============================] - 1s 218ms/step - loss: 4820.2173 - accuracy: 0.6212 - val_loss: 1639.7031 - val_accuracy: 0.5556
# Epoch 37/100
# 3/3 [==============================] - 1s 228ms/step - loss: 16440.7832 - accuracy: 0.6061 - val_loss: 1346.3141 - val_accuracy: 0.5556
# Epoch 38/100
# 3/3 [==============================] - 1s 218ms/step - loss: 11771.1777 - accuracy: 0.6970 - val_loss: 987.9172 - val_accuracy: 0.5556
# Epoch 39/100
# 3/3 [==============================] - 1s 225ms/step - loss: 9712.0781 - accuracy: 0.5455 - val_loss: 722.0170 - val_accuracy: 0.5556
# Epoch 40/100
# 3/3 [==============================] - 1s 206ms/step - loss: 16962.6055 - accuracy: 0.4545 - val_loss: 484.7266 - val_accuracy: 0.5556
# Epoch 41/100
# 3/3 [==============================] - 1s 218ms/step - loss: 11754.3965 - accuracy: 0.6364 - val_loss: 557.5292 - val_accuracy: 0.4444
# Epoch 42/100
# 3/3 [==============================] - 1s 221ms/step - loss: 5190.1733 - accuracy: 0.6364 - val_loss: 671.3339 - val_accuracy: 0.4444
# Epoch 43/100
# 3/3 [==============================] - 1s 218ms/step - loss: 24295.4453 - accuracy: 0.6667 - val_loss: 583.0969 - val_accuracy: 0.3333
# Epoch 44/100
# 3/3 [==============================] - 1s 223ms/step - loss: 10109.8740 - accuracy: 0.5909 - val_loss: 446.3186 - val_accuracy: 0.4444
# Epoch 45/100
# 3/3 [==============================] - 1s 227ms/step - loss: 4017.6211 - accuracy: 0.5303 - val_loss: 0.5356 - val_accuracy: 0.6667
# Epoch 46/100
# 3/3 [==============================] - 1s 220ms/step - loss: 2391.6453 - accuracy: 0.6212 - val_loss: 0.5349 - val_accuracy: 0.6667
# Epoch 47/100
# 3/3 [==============================] - 1s 308ms/step - loss: 8553.0029 - accuracy: 0.6061 - val_loss: 0.5340 - val_accuracy: 0.6667
# Epoch 48/100
# 3/3 [==============================] - 1s 279ms/step - loss: 5285.5928 - accuracy: 0.5909 - val_loss: 0.4637 - val_accuracy: 0.6667
# Epoch 49/100
# 3/3 [==============================] - 1s 288ms/step - loss: 4223.4624 - accuracy: 0.6515 - val_loss: 0.4643 - val_accuracy: 0.6667
# Epoch 50/100
# 3/3 [==============================] - 1s 321ms/step - loss: 15024.8213 - accuracy: 0.5909 - val_loss: 41.0310 - val_accuracy: 0.5556
# Epoch 51/100
# 3/3 [==============================] - 1s 235ms/step - loss: 10036.7627 - accuracy: 0.6364 - val_loss: 317.6376 - val_accuracy: 0.5556
# Epoch 52/100
# 3/3 [==============================] - 1s 218ms/step - loss: 6513.3125 - accuracy: 0.5606 - val_loss: 462.8639 - val_accuracy: 0.5556
# Epoch 53/100
# 3/3 [==============================] - 1s 216ms/step - loss: 1873.2764 - accuracy: 0.6364 - val_loss: 527.4557 - val_accuracy: 0.5556
# Epoch 54/100
# 3/3 [==============================] - 1s 226ms/step - loss: 2851.8721 - accuracy: 0.5758 - val_loss: 485.7582 - val_accuracy: 0.5556
# Epoch 55/100
# 3/3 [==============================] - 1s 222ms/step - loss: 5149.9805 - accuracy: 0.6364 - val_loss: 1291.3485 - val_accuracy: 0.5556
# Epoch 56/100
# 3/3 [==============================] - 1s 221ms/step - loss: 5218.2002 - accuracy: 0.5606 - val_loss: 4903.3979 - val_accuracy: 0.4444
# Epoch 57/100
# 3/3 [==============================] - 1s 229ms/step - loss: 12141.2832 - accuracy: 0.5758 - val_loss: 5820.8018 - val_accuracy: 0.4444
# Epoch 58/100
# 3/3 [==============================] - 1s 234ms/step - loss: 17165.1836 - accuracy: 0.4697 - val_loss: 6511.8003 - val_accuracy: 0.6667
# 1/1 [==============================] - 0s 121ms/step - loss: 0.6722 - accuracy: 0.6667
# 1/1 [==============================] - 0s 114ms/step - loss: 0.4637 - accuracy: 0.6667
# Test Accuracy: 0.6666666865348816

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# Split the dataset into training, validation, and test sets
# X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=test_ratio, stratify=labels, random_state=42)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_ratio/(train_ratio+val_ratio), stratify=y_train, random_state=42)

# Normalize the input data (if required)
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0

# Reshape the input data based on the expected input shape of the model
input_shape = X_train.shape[1:]  # Assuming the first dimension is the number of samples
X_train = X_train.reshape((-1,) + input_shape)
X_val = X_val.reshape((-1,) + input_shape)
X_test = X_test.reshape((-1,) + input_shape)

# Build the CNN model
model = tf.keras.Sequential()
model.add(layers.Conv2D(16, kernel_size=(6, 6),strides=1, activation='relu',padding='same', input_shape=input_shape))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(32, kernel_size=(3, 3), strides=1,activation='relu',padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(64, kernel_size=(3, 3),strides=1, activation='relu',padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model with the desired loss function and optimizer
learning_rate = 0.00001  # Specify your desired learning rate
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
val_loss, val_accuracy = model.evaluate(X_val, y_val)

# Print the test accuracy
print("Test Accuracy:", test_accuracy)

training_accuracy = history.history['accuracy']
testing_accuracy = history.history['val_accuracy']

# Generate learning curve
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plot training and testing accuracy
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(testing_accuracy, label='Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot learning curve
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 3/3 [==============================] - 5s 486ms/step - loss: 773605.0000 - accuracy: 0.4697 - val_loss: 588566.4375 - val_accuracy: 0.3333
# Epoch 2/100
# 3/3 [==============================] - 1s 220ms/step - loss: 1132418.6250 - accuracy: 0.5152 - val_loss: 546308.5625 - val_accuracy: 0.3333
# Epoch 3/100
# 3/3 [==============================] - 1s 220ms/step - loss: 875255.8750 - accuracy: 0.3939 - val_loss: 503720.9375 - val_accuracy: 0.3333
# Epoch 4/100
# 3/3 [==============================] - 1s 216ms/step - loss: 457888.7812 - accuracy: 0.5000 - val_loss: 458839.3750 - val_accuracy: 0.3333
# Epoch 5/100
# 3/3 [==============================] - 1s 229ms/step - loss: 939720.4375 - accuracy: 0.5455 - val_loss: 431918.5625 - val_accuracy: 0.4444
# Epoch 6/100
# 3/3 [==============================] - 1s 220ms/step - loss: 910382.3125 - accuracy: 0.5152 - val_loss: 411641.5000 - val_accuracy: 0.4444
# Epoch 7/100
# 3/3 [==============================] - 1s 229ms/step - loss: 775058.1875 - accuracy: 0.4848 - val_loss: 396020.5625 - val_accuracy: 0.4444
# Epoch 8/100
# 3/3 [==============================] - 1s 220ms/step - loss: 781555.7500 - accuracy: 0.4394 - val_loss: 380327.3750 - val_accuracy: 0.4444
# Epoch 9/100
# 3/3 [==============================] - 1s 223ms/step - loss: 1053252.1250 - accuracy: 0.3939 - val_loss: 367423.1250 - val_accuracy: 0.5556
# Epoch 10/100
# 3/3 [==============================] - 1s 223ms/step - loss: 1067737.0000 - accuracy: 0.4091 - val_loss: 356083.6562 - val_accuracy: 0.5556
# Epoch 11/100
# 3/3 [==============================] - 1s 227ms/step - loss: 678824.7500 - accuracy: 0.5758 - val_loss: 345165.0938 - val_accuracy: 0.5556
# Epoch 12/100
# 3/3 [==============================] - 1s 223ms/step - loss: 918076.4375 - accuracy: 0.5000 - val_loss: 334057.1250 - val_accuracy: 0.5556
# Epoch 13/100
# 3/3 [==============================] - 1s 233ms/step - loss: 1404123.3750 - accuracy: 0.4091 - val_loss: 321562.2812 - val_accuracy: 0.5556
# Epoch 14/100
# 3/3 [==============================] - 1s 225ms/step - loss: 1147017.5000 - accuracy: 0.3788 - val_loss: 308789.1562 - val_accuracy: 0.4444
# Epoch 15/100
# 3/3 [==============================] - 1s 230ms/step - loss: 669502.8750 - accuracy: 0.5758 - val_loss: 296297.5312 - val_accuracy: 0.4444
# Epoch 16/100
# 3/3 [==============================] - 1s 313ms/step - loss: 745691.4375 - accuracy: 0.5455 - val_loss: 283290.8750 - val_accuracy: 0.4444
# Epoch 17/100
# 3/3 [==============================] - 1s 360ms/step - loss: 956971.9375 - accuracy: 0.5909 - val_loss: 271819.1250 - val_accuracy: 0.3333
# Epoch 18/100
# 3/3 [==============================] - 1s 288ms/step - loss: 717429.5000 - accuracy: 0.5455 - val_loss: 263912.5625 - val_accuracy: 0.3333
# Epoch 19/100
# 3/3 [==============================] - 1s 365ms/step - loss: 430210.1250 - accuracy: 0.6061 - val_loss: 256324.2188 - val_accuracy: 0.3333
# Epoch 20/100
# 3/3 [==============================] - 1s 224ms/step - loss: 1064424.7500 - accuracy: 0.5303 - val_loss: 249061.7188 - val_accuracy: 0.3333
# Epoch 21/100
# 3/3 [==============================] - 1s 223ms/step - loss: 625545.5000 - accuracy: 0.5758 - val_loss: 240963.8125 - val_accuracy: 0.3333
# Epoch 22/100
# 3/3 [==============================] - 1s 237ms/step - loss: 1017188.7500 - accuracy: 0.4545 - val_loss: 233502.4375 - val_accuracy: 0.3333
# Epoch 23/100
# 3/3 [==============================] - 1s 221ms/step - loss: 470001.9688 - accuracy: 0.4848 - val_loss: 226536.9062 - val_accuracy: 0.3333
# Epoch 24/100
# 3/3 [==============================] - 1s 209ms/step - loss: 1015935.5000 - accuracy: 0.4394 - val_loss: 221830.4219 - val_accuracy: 0.3333
# Epoch 25/100
# 3/3 [==============================] - 1s 208ms/step - loss: 1047759.0000 - accuracy: 0.5606 - val_loss: 219789.8906 - val_accuracy: 0.4444
# Epoch 26/100
# 3/3 [==============================] - 1s 234ms/step - loss: 839221.0625 - accuracy: 0.5000 - val_loss: 219036.5938 - val_accuracy: 0.4444
# Epoch 27/100
# 3/3 [==============================] - 1s 221ms/step - loss: 1543631.1250 - accuracy: 0.4697 - val_loss: 218740.6094 - val_accuracy: 0.4444
# Epoch 28/100
# 3/3 [==============================] - 1s 205ms/step - loss: 1225168.7500 - accuracy: 0.5758 - val_loss: 219200.1406 - val_accuracy: 0.4444
# Epoch 29/100
# 3/3 [==============================] - 1s 218ms/step - loss: 779016.5625 - accuracy: 0.4242 - val_loss: 219854.4688 - val_accuracy: 0.4444
# Epoch 30/100
# 3/3 [==============================] - 1s 205ms/step - loss: 785532.0000 - accuracy: 0.5606 - val_loss: 221014.8906 - val_accuracy: 0.4444
# Epoch 31/100
# 3/3 [==============================] - 1s 230ms/step - loss: 979412.9375 - accuracy: 0.6061 - val_loss: 221988.0781 - val_accuracy: 0.4444
# Epoch 32/100
# 3/3 [==============================] - 1s 223ms/step - loss: 845367.3125 - accuracy: 0.4848 - val_loss: 222905.2969 - val_accuracy: 0.4444
# Epoch 33/100
# 3/3 [==============================] - 1s 222ms/step - loss: 542266.3750 - accuracy: 0.5606 - val_loss: 222860.9844 - val_accuracy: 0.4444
# Epoch 34/100
# 3/3 [==============================] - 1s 307ms/step - loss: 423098.5625 - accuracy: 0.5606 - val_loss: 222973.0312 - val_accuracy: 0.4444
# Epoch 35/100
# 3/3 [==============================] - 1s 379ms/step - loss: 818138.9375 - accuracy: 0.6364 - val_loss: 223209.0625 - val_accuracy: 0.4444
# Epoch 36/100
# 3/3 [==============================] - 1s 296ms/step - loss: 695495.3125 - accuracy: 0.6061 - val_loss: 224042.9844 - val_accuracy: 0.4444
# Epoch 37/100
# 3/3 [==============================] - 1s 318ms/step - loss: 667840.1250 - accuracy: 0.5909 - val_loss: 224956.2344 - val_accuracy: 0.4444
# 1/1 [==============================] - 0s 143ms/step - loss: 132480.7344 - accuracy: 0.3333
# 1/1 [==============================] - 0s 133ms/step - loss: 218740.6094 - accuracy: 0.4444
# Test Accuracy: 0.3333333432674408
