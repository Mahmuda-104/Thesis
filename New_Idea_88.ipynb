# %%
import os
import scipy.io
import numpy as np
from scipy import signal

data_path = "/kaggle/input/control1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')

for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []

for control_data_path in control_data:
    n_epochs = 70 
    start_epoch = 1
    end_epoch = 110

    control_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = os.path.join(control_data_path, f"trial{i}.mat")
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]    
        #print(mat_data1.shape)
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        #print(downsampled_data.shape)
        
        control_arr.append(downsampled_data)
        Control30.append(downsampled_data)

Control30 = np.array(Control30)

print(Control30.shape)
# Out:
# (3300, 60, 1000)

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
data_path = "/kaggle/input/concussed1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 70
    start_epoch = 1
    end_epoch = 110
    concussed_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
        Concussed52.append(downsampled_data)

Concussed52 = np.array(Concussed52)

print( Concussed52.shape)
# Out:
# (5390, 60, 1000)

# %%
dataset = np.concatenate((Control30, Concussed52), axis=0)
labels = np.concatenate((np.zeros(Control30.shape[0]), np.ones(Concussed52.shape[0])))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.2, random_state=42)
mean = np.mean(X_train)
std = np.std(X_train)

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

model = Sequential()
model.add(Conv1D(32, 3, activation='relu', input_shape=(60, 1000)))
model.add(MaxPooling1D(2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 218/218 [==============================] - 6s 24ms/step - loss: 0.6457 - accuracy: 0.6556
# Epoch 2/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.5476 - accuracy: 0.7116
# Epoch 3/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.4699 - accuracy: 0.7655
# Epoch 4/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.3927 - accuracy: 0.8186
# Epoch 5/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.3443 - accuracy: 0.8439
# Epoch 6/100
# 218/218 [==============================] - 5s 25ms/step - loss: 0.3400 - accuracy: 0.8596
# Epoch 7/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.3003 - accuracy: 0.8721
# Epoch 8/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.1957 - accuracy: 0.9205
# Epoch 9/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.1782 - accuracy: 0.9297
# Epoch 10/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.1269 - accuracy: 0.9517
# Epoch 11/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.1834 - accuracy: 0.9435
# Epoch 12/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.1384 - accuracy: 0.9485
# Epoch 13/100
# 218/218 [==============================] - 6s 26ms/step - loss: 0.1625 - accuracy: 0.9377
# Epoch 14/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0684 - accuracy: 0.9778
# Epoch 15/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0339 - accuracy: 0.9930
# Epoch 16/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0557 - accuracy: 0.9817
# Epoch 17/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0347 - accuracy: 0.9909
# Epoch 18/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0180 - accuracy: 0.9970
# Epoch 19/100
# 218/218 [==============================] - 5s 25ms/step - loss: 0.0575 - accuracy: 0.9829
# Epoch 20/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.2344 - accuracy: 0.9334
# Epoch 21/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0801 - accuracy: 0.9717
# Epoch 22/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0529 - accuracy: 0.9833
# Epoch 23/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0141 - accuracy: 0.9976
# Epoch 24/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0132 - accuracy: 0.9970
# Epoch 25/100
# 218/218 [==============================] - 5s 25ms/step - loss: 0.0125 - accuracy: 0.9977
# Epoch 26/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.1198 - accuracy: 0.9640
# Epoch 27/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0488 - accuracy: 0.9859
# Epoch 28/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0243 - accuracy: 0.9934
# Epoch 29/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0541 - accuracy: 0.9840
# Epoch 30/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0341 - accuracy: 0.9902
# Epoch 31/100
# 218/218 [==============================] - 5s 25ms/step - loss: 0.0149 - accuracy: 0.9965
# Epoch 32/100
# 218/218 [==============================] - 5s 23ms/step - loss: 0.0028 - accuracy: 0.9999
# Epoch 33/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 34/100
# 218/218 [==============================] - 5s 24ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 35/100
# 218/218 [==============================] - 5s 24ms/step - loss: 8.3960e-04 - accuracy: 1.0000
# Epoch 36/100
# 218/218 [==============================] - 5s 23ms/step - loss: 6.8861e-04 - accuracy: 1.0000
# Epoch 37/100
# 218/218 [==============================] - 5s 25ms/step - loss: 5.8293e-04 - accuracy: 1.0000
# Epoch 38/100
# 218/218 [==============================] - 5s 24ms/step - loss: 4.9590e-04 - accuracy: 1.0000
# Epoch 39/100
# 218/218 [==============================] - 5s 24ms/step - loss: 4.2464e-04 - accuracy: 1.0000
# Epoch 40/100
# 218/218 [==============================] - 5s 23ms/step - loss: 3.6906e-04 - accuracy: 1.0000
# Epoch 41/100
# 218/218 [==============================] - 7s 33ms/step - loss: 3.2015e-04 - accuracy: 1.0000
# Epoch 42/100
# 218/218 [==============================] - 6s 28ms/step - loss: 2.7755e-04 - accuracy: 1.0000
# Epoch 43/100
# 218/218 [==============================] - 6s 28ms/step - loss: 2.4447e-04 - accuracy: 1.0000
# Epoch 44/100
# 218/218 [==============================] - 5s 23ms/step - loss: 2.1405e-04 - accuracy: 1.0000
# Epoch 45/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.8793e-04 - accuracy: 1.0000
# Epoch 46/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.6540e-04 - accuracy: 1.0000
# Epoch 47/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.4594e-04 - accuracy: 1.0000
# Epoch 48/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.2898e-04 - accuracy: 1.0000
# Epoch 49/100
# 218/218 [==============================] - 5s 25ms/step - loss: 1.1447e-04 - accuracy: 1.0000
# Epoch 50/100
# 218/218 [==============================] - 5s 24ms/step - loss: 1
100
# 218/218 [==============================] - 5s 24ms/step - loss: 1.8963e-06 - accuracy: 1.0000
# Epoch 84/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.6791e-06 - accuracy: 1.0000
# Epoch 85/100
# 218/218 [==============================] - 5s 24ms/step - loss: 1.4917e-06 - accuracy: 1.0000
# Epoch 86/100
# 218/218 [==============================] - 5s 25ms/step - loss: 1.3204e-06 - accuracy: 1.0000
# Epoch 87/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.1748e-06 - accuracy: 1.0000
# Epoch 88/100
# 218/218 [==============================] - 5s 23ms/step - loss: 1.0414e-06 - accuracy: 1.0000
# Epoch 89/100
# 218/218 [==============================] - 5s 23ms/step - loss: 9.2811e-07 - accuracy: 1.0000
# Epoch 90/100
# 218/218 [==============================] - 5s 23ms/step - loss: 8.2038e-07 - accuracy: 1.0000
# Epoch 91/100
# 218/218 [==============================] - 5s 23ms/step - loss: 7.2755e-07 - accuracy: 1.0000
# Epoch 92/100
# 218/218 [==============================] - 5s 25ms/step - loss: 6.4554e-07 - accuracy: 1.0000
# Epoch 93/100
# 218/218 [==============================] - 5s 23ms/step - loss: 5.7883e-07 - accuracy: 1.0000
# Epoch 94/100
# 218/218 [==============================] - 5s 23ms/step - loss: 5.1379e-07 - accuracy: 1.0000
# Epoch 95/100
# 218/218 [==============================] - 5s 24ms/step - loss: 4.5719e-07 - accuracy: 1.0000
# Epoch 96/100
# 218/218 [==============================] - 5s 23ms/step - loss: 4.0656e-07 - accuracy: 1.0000
# Epoch 97/100
# 218/218 [==============================] - 5s 23ms/step - loss: 3.6266e-07 - accuracy: 1.0000
# Epoch 98/100
# 218/218 [==============================] - 5s 23ms/step - loss: 3.2203e-07 - accuracy: 1.0000
# Epoch 99/100
# 218/218 [==============================] - 5s 25ms/step - loss: 2.8721e-07 - accuracy: 1.0000
# Epoch 100/100
# 218/218 [==============================] - 5s 24ms/step - loss: 2.5432e-07 - accuracy: 1.0000

# %%
_, accuracy = model.evaluate(X_test, y_test)
print("Accuracy: %.2f%%" % (accuracy * 100))
# Out:
# 55/55 [==============================] - 1s 9ms/step - loss: 1.4731 - accuracy: 0.8786
# Accuracy: 87.86%

# %%
y_pred = model.predict(X_test)
y_pred = np.round(y_pred).flatten()
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# 55/55 [==============================] - 1s 9ms/step
# Confusion Matrix:
# [[561 123]
#  [ 88 966]]

# %%
from sklearn.metrics import classification_report
target_names = ['Control', 'Concussed']
report = classification_report(y_test, y_pred, target_names=target_names)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      Control       0.86      0.82      0.84       684
#    Concussed       0.89      0.92      0.90      1054
#
#     accuracy                           0.88      1738
#    macro avg       0.88      0.87      0.87      1738
# weighted avg       0.88      0.88      0.88      1738
