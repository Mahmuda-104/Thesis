# %%
import os
import scipy.io
import numpy as np
from scipy import signal

# Set the path to the root directory where the "Control" folder is located
data_path = "/kaggle/input/control1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')

for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []

for control_data_path in control_data:
    n_epochs = 105#len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    control_arr = []
    
    for i in range(1, n_epochs+1):
        epoch_path = os.path.join(control_data_path, f"trial{i}.mat")
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
                # Average referencing
        average_potential = np.mean(mat_data1, axis=0, keepdims=True)
        referenced_data = mat_data1 - average_potential
        
        # Bandpass filtering
        b, a = signal.butter(4, [lowcut, highcut], fs=fs_original, btype='band')
        filtered_data = signal.filtfilt(b, a, referenced_data, axis=-1)
        
        # Apply notch filter
        f0 = 60  # Frequency to be removed (e.g., power line interference)
        Q = 30   # Quality factor
        w0 = f0 / (fs_original / 2)
        b, a = signal.iirnotch(w0, Q)
        filtered_data = signal.filtfilt(b, a, filtered_data, axis=-1)

        
        # Downsampling
        num_samples_original = filtered_data.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(filtered_data, num_samples_new, axis=-1)
        
        control_arr.append(np.array(downsampled_data))
        
    Control30.append(np.array(control_arr))

Control30 = np.array(Control30)
print(Control30[0].shape)
# Out:
# (105, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_control_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features
for i in range(len(Control30)):
    control_data = Control30[i]
    control_power = []
    for epoch in control_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)

            # alpha_power_normalized = (alpha_power - channel_min_value) / (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value )))
            # beta_power_normalized = (beta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value) ))
            # delta_power_normalized = (delta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value)))

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)
            values=np.array([alpha_power,beta_power,delta_power,entropy_values])
            rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value
            concatenated_data = np.concatenate((channel_data, rescaled_values))

            #concatenated_data = np.concatenate((channel_data, [alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values]))
            #print(alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values)
            epoch_power.append(concatenated_data.tolist())

        control_power.append(np.array(epoch_power))

    all_control_power.append(np.array(control_power))

all_control_power = np.array(all_control_power)
print(all_control_power.shape)
print(len(Control30))
# Out:
# (30, 105, 60, 1004)
# 30

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
data_path = "/kaggle/input/concussed1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 105 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    concussed_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        # Average referencing
        average_potential = np.mean(mat_data1, axis=0, keepdims=True)
        referenced_data = mat_data1 - average_potential
        
        # Bandpass filtering
        b, a = signal.butter(4, [lowcut, highcut], fs=fs_original, btype='band')
        filtered_data = signal.filtfilt(b, a, referenced_data, axis=-1)
        
        # Apply notch filter
        f0 = 60  # Frequency to be removed (e.g., power line interference)
        Q = 30   # Quality factor
        w0 = f0 / (fs_original / 2)
        b, a = signal.iirnotch(w0, Q)
        filtered_data = signal.filtfilt(b, a, filtered_data, axis=-1)
        
        # Downsampling
        num_samples_original = filtered_data.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(filtered_data, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
    Concussed52.append(np.array(concussed_arr))

Concussed52 = np.array(Concussed52)
print( Concussed52[0].shape)
# Out:
# (105, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler

from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_concussed_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features within the range of the minimum and maximum values of the corresponding channel
for i in range(len(Concussed52)):
    concussed_data = Concussed52[i]
    concussed_power = []
    for epoch in concussed_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)

            # alpha_power_normalized = (alpha_power - channel_min_value) / (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value )))
            # beta_power_normalized = (beta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value) ))
            # delta_power_normalized = (delta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value)))

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)
            values=np.array([alpha_power,beta_power,delta_power,entropy_values])
            rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value
            concatenated_data = np.concatenate((channel_data, rescaled_values))

            #concatenated_data = np.concatenate((channel_data, [alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values]))
            #print(alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values)
            epoch_power.append(concatenated_data.tolist())

        concussed_power.append(np.array(epoch_power))

    all_concussed_power.append(np.array(concussed_power))

all_concussed_power = np.array(all_concussed_power)
print(all_concussed_power.shape)
print(len(Concussed52))
# Out:
# (49, 105, 60, 1004)
# 49

# %%
dataset = np.concatenate((all_control_power, all_concussed_power), axis=0)
labels = np.concatenate((np.zeros(len(all_control_power)), np.ones(len(all_concussed_power))))

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(dataset, labels, test_size=0.2, random_state=42)
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
# Out:
# X_train shape: (63, 105, 60, 1004)
# y_train shape: (63,)
# X_val shape: (16, 105, 60, 1004)
# y_val shape: (16,)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

input_shape = (105, 60, 1004)  # Input shape of your EEG data

model = tf.keras.Sequential()
model.add(layers.Conv2D(32, kernel_size=(3, 3), strides=2, activation='relu', padding='same', input_shape=input_shape))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.6))
model.add(layers.Conv2D(64, kernel_size=(3, 3), strides=2, activation='relu', padding='same', kernel_regularizer=l2(0.1)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.6))
model.add(layers.Conv2D(128, kernel_size=(3, 3), strides=2, activation='relu', padding='same', kernel_regularizer=l2(0.1)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.6))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.6))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 53, 30, 32)        289184
#
#  batch_normalization (BatchN  (None, 53, 30, 32)       128
#  ormalization)
#
#  dropout (Dropout)           (None, 53, 30, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 27, 15, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 27, 15, 64)       256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 27, 15, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 14, 8, 128)        73856
#
#  batch_normalization_2 (Batc  (None, 14, 8, 128)       512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 14, 8, 128)        0
#
#  flatten (Flatten)           (None, 14336)             0
#
#  dense (Dense)               (None, 256)               3670272
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 4,052,961
# Trainable params: 4,052,513
# Non-trainable params: 448
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
callback_list = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True)

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# %%
from sklearn.model_selection import KFold
X =dataset
y = labels 
Epoch = 100
batchSize = 32

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True)

train_accuracies = []
val_accuracies = []

true_labels = []
predicted_labels = []


# cross-validation
for train_index, val_index in kf.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    history = model.fit(
    X_train,
    y_train,
    epochs=Epoch,
    batch_size=batchSize,
    validation_data=(X_val, y_val),
    callbacks=callback_list,
    verbose=1)

    # Evaluate the model on training and validation data
    train_loss, train_accuracy = model.evaluate(X_train, y_train)
    val_loss, val_accuracy = model.evaluate(X_val, y_val)

    train_accuracies.append(train_accuracy)
    val_accuracies.append(val_accuracy)
    
    val_predictions = model.predict(X_val)
    val_predictions = np.argmax(val_predictions, axis=1)
    true_labels.extend(y_val)
    predicted_labels.extend(val_predictions)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 5s 2s/step - loss: 13.5797 - accuracy: 0.5238 - val_loss: 16.6816 - val_accuracy: 0.6875
# Epoch 2/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.9340 - accuracy: 0.5079 - val_loss: 15.7650 - val_accuracy: 0.6875
# Epoch 3/100
# 2/2 [==============================] - 3s 2s/step - loss: 13.5914 - accuracy: 0.4762 - val_loss: 15.3311 - val_accuracy: 0.5000
# Epoch 4/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.4689 - accuracy: 0.5714 - val_loss: 15.0103 - val_accuracy: 0.5000
# Epoch 5/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.9799 - accuracy: 0.5079 - val_loss: 14.7520 - val_accuracy: 0.5000
# Epoch 6/100
# 2/2 [==============================] - 2s 1s/step - loss: 13.4254 - accuracy: 0.5397 - val_loss: 14.5627 - val_accuracy: 0.4375
# Epoch 7/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.4311 - accuracy: 0.5873 - val_loss: 14.5486 - val_accuracy: 0.5000
# Epoch 8/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.3118 - accuracy: 0.6508 - val_loss: 14.5195 - val_accuracy: 0.5000
# Epoch 9/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.9903 - accuracy: 0.6032 - val_loss: 14.5542 - val_accuracy: 0.4375
# Epoch 10/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.2266 - accuracy: 0.5556 - val_loss: 14.5061 - val_accuracy: 0.5000
# Epoch 11/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.1035 - accuracy: 0.7460 - val_loss: 14.4758 - val_accuracy: 0.5625
# Epoch 12/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.2083 - accuracy: 0.5873 - val_loss: 14.3673 - val_accuracy: 0.5000
# Epoch 13/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.5109 - accuracy: 0.5714 - val_loss: 14.2920 - val_accuracy: 0.4375
# Epoch 14/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.2618 - accuracy: 0.6032 - val_loss: 14.1977 - val_accuracy: 0.4375
# Epoch 15/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.2386 - accuracy: 0.5873 - val_loss: 14.1419 - val_accuracy: 0.5000
# Epoch 16/100
# 2/2 [==============================] - 3s 2s/step - loss: 13.4703 - accuracy: 0.6032 - val_loss: 14.1429 - val_accuracy: 0.5000
# Epoch 17/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.0969 - accuracy: 0.6190 - val_loss: 14.0963 - val_accuracy: 0.4375
# Epoch 18/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.1629 - accuracy: 0.5873 - val_loss: 14.1070 - val_accuracy: 0.3750
# Epoch 19/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.1459 - accuracy: 0.7302 - val_loss: 14.2283 - val_accuracy: 0.4375
# Epoch 20/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.1211 - accuracy: 0.6825 - val_loss: 14.3936 - val_accuracy: 0.5000
# Epoch 21/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.1318 - accuracy: 0.6508 - val_loss: 14.6078 - val_accuracy: 0.5625
# Epoch 22/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.9243 - accuracy: 0.6825 - val_loss: 14.7960 - val_accuracy: 0.5625
# Epoch 23/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.9990 - accuracy: 0.6032 - val_loss: 14.9320 - val_accuracy: 0.5625
# Epoch 24/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.7674 - accuracy: 0.7302 - val_loss: 15.0320 - val_accuracy: 0.5625
# Epoch 25/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.7771 - accuracy: 0.7302 - val_loss: 15.0887 - val_accuracy: 0.5625
# Epoch 26/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.7433 - accuracy: 0.6984 - val_loss: 15.1394 - val_accuracy: 0.5625
# Epoch 27/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.0154 - accuracy: 0.6984 - val_loss: 15.1489 - val_accuracy: 0.5625
# 2/2 [==============================] - 2s 394ms/step - loss: 12.7899 - accuracy: 0.9048
# 1/1 [==============================] - 0s 355ms/step - loss: 14.0963 - accuracy: 0.4375
# 1/1 [==============================] - 1s 619ms/step
# Epoch 1/100
# 2/2 [==============================] - 4s 2s/step - loss: 13.3577 - accuracy: 0.6508 - val_loss: 12.8034 - val_accuracy: 0.8750
# Epoch 2/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.9665 - accuracy: 0.6190 - val_loss: 12.7861 - val_accuracy: 0.8750
# Epoch 3/100
# 2/2 [==============================] - 3s 2s/step - loss: 13.3843 - accuracy: 0.6032 - val_loss: 12.7702 - val_accuracy: 0.8125
# Epoch 4/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.8700 - accuracy: 0.6190 - val_loss: 12.7542 - val_accuracy: 0.8125
# Epoch 5/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.1741 - accuracy: 0.6508 - val_loss: 12.7382 - val_accuracy: 0.8125
# Epoch 6/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.7920 - accuracy: 0.6190 - val_loss: 12.7219 - val_accuracy: 0.7500
# Epoch 7/100
# 2/2 [==============================] - 3s 2s/step - loss: 13.1901 - accuracy: 0.5714 - val_loss: 12.7070 - val_accuracy: 0.6875
# Epoch 8/100
# 2/2 [==============================] - 3s 2s/step - loss: 13.4705 - accuracy: 0.5873 - val_loss: 12.6945 - val_accuracy: 0.6875
# Epoch 9/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.7748 - accuracy: 0.6667 - val_loss: 12.6809 - val_accuracy: 0.6875
# Epoch 10/100
# 2/2 [==============================] - 3s 1s/step - loss: 13.1147 - accuracy: 0.6508 - val_loss: 12.6673 - val_accuracy: 0.5625
# Epoch 11/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.5668 - accuracy: 0.7778 - val_loss: 12.6522 - val_accuracy: 0.5625
# Epoch 12/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.5454 - accuracy: 0.8095 - val_loss: 12.6366 - val_accuracy: 0.5625
# Epoch 13/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.8458 - accuracy: 0.6825 - val_loss: 12.6179 - val_accuracy: 0.5625
# Epoch 14/100
# 2/2 [==============================] - 3s 2s/step - loss: 13.0584 - accuracy: 0.6667 - val_loss: 12.5974 - val_accuracy: 0.5625
# Epoch 15/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.9367 - accuracy: 0.6032 - val_loss: 12.5781 - val_accuracy: 0.5625
# Epoch 16/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.7006 - accuracy: 0.6508 - val_loss: 12.5610 - val_accuracy: 0.5625
# Epoch 17/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.4398 - accuracy: 0.7619 - val_loss: 12.5421 - val_accuracy: 0.5625
# Epoch 18/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.4261 - accuracy: 0.7460 - val_loss: 12.5183 - val_accuracy: 0.5625
# Epoch 19/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.5232 - accuracy: 0.6825 - val_loss: 12.4923 - val_accuracy: 0.5625
# Epoch 20/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.4274 - accuracy: 0.7619 - val_loss: 12.4647 - val_accuracy: 0.5625
# Epoch 21/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.5675 - accuracy: 0.6508 - val_loss: 12.4356 - val_accuracy: 0.5625
# Epoch 22/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.5670 - accuracy: 0.7143 - val_loss: 12.4061 - val_accuracy: 0.5625
# Epoch 23/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.3164 - accuracy: 0.8254 - val_loss: 12.3769 - val_accuracy: 0.5625
# Epoch 24/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.4022 - accuracy: 0.6825 - val_loss: 12.3492 - val_accuracy: 0.6250
# Epoch 25/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.2425 - accuracy: 0.7460 - val_loss: 12.3240 - val_accuracy: 0.6250
# Epoch 26/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.5728 - accuracy: 0.6984 - val_loss: 12.3000 - val_accuracy: 0.6250
# Epoch 27/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.2284 - accuracy: 0.7460 - val_loss: 12.2764 - val_accuracy: 0.6875
# Epoch 28/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.2345 - accuracy: 0.7302 - val_loss: 12.2545 - val_accuracy: 0.6250
# Epoch 29/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.3288 - accuracy: 0.8254 - val_loss: 12.2343 - val_accuracy: 0.6250
# Epoch 30/100
# 2/2 [==============================] - 3s 1s/step - loss: 12.1013 - accuracy: 0.7937 - val_loss: 12.2135 - val_accuracy: 0.5625
# Epoch 31/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.1138 - accuracy: 0.7778 - val_loss: 12.1944 - val_accuracy: 0.5625
# Epoch 32/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.0196 - accuracy: 0.8571 - val_loss: 12.1770 - val_accuracy: 0.5625
# Epoch 33/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.0045 - accuracy: 0.7937 - val_loss: 12.1600 - val_accuracy: 0.5625
# Epoch 34/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.0576 - accuracy: 0.6984 - val_loss: 12.1457 - val_accuracy: 0.5625
# Epoch 35/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.1284 - accuracy: 0.6825 - val_loss: 12.1309 - val_accuracy: 0.5625
# Epoch 36/100
# 2/2 [==============================] - 3s 2s/step - loss: 12.0322 - accuracy: 0.6984 - val_loss: 12.1136 - val_accuracy: 0.5625
# Epoch 37/100
# 2/2 [==============================] - 3s 2s/step - loss: 11.8859 - accuracy: 0.8413 - val_loss: 12.0979 - val_accuracy: 0.5625
# Epoch 38/100
# 2/2 [==============================] - 3s 2s/step - loss: 11.9336 - accuracy: 0.8254 - val_loss: 12.0821 - val_accuracy: 0.5625
# Epoch 39/100
# 2/2 [==============================] - 3s 2s/step - loss: 11.9008 - accuracy: 0.8095 - val_loss: 12.0715 - val_accuracy: 0.5625
# Epoch 40/100
# 2/2 [==============================] - 3s 2s/step - loss: 11.9586 - accuracy: 0.6984 - val_loss: 12.0565 - val_accuracy: 0.5625
# Epoch 41/100
# 2/2 [==============================] - 3s 1s/step - loss: 11.8252 - accuracy: 0.8571 - val_loss: 12.0402 - val_accuracy: 0.5625
# Epoch 42/100
# 2/2 [==============================] - 3s 2s/step - loss: 11.8225 - accuracy: 0.7460 - val_loss: 12.0234 - val_accuracy: 0.5625
# Epoch 43/100
# 2/2 [==============================] - 3s 2s/step - loss: 11.7844 - accuracy: 0.7619 - val_loss: 12.0011 - val_accuracy: 0.5625
# Epoch 44/100
# 2/2 [==============================] - 3s 2s/step - loss: 11.7087 - accuracy: 0.8095 - val_loss: 11.9763 - val_accuracy: 0.5625
# Epoch 45/100
# 2/2 [==============================] - 3s 1s/step - loss: 11.8461 - accuracy: 0.8095 - val_loss: 11.9519 - val_accuracy: 0.5625
# Epoch 46/100
# 2/2 [==============================] - 3s 2s/step - loss: 11
100
# 2/2 [==============================] - 3s 2s/step - loss: 10.8148 - accuracy: 0.8413 - val_loss: 11.1650 - val_accuracy: 0.5625
# Epoch 77/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.8200 - accuracy: 0.8095 - val_loss: 11.1346 - val_accuracy: 0.5625
# Epoch 78/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.8120 - accuracy: 0.8571 - val_loss: 11.1027 - val_accuracy: 0.5625
# Epoch 79/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.7230 - accuracy: 0.8730 - val_loss: 11.0708 - val_accuracy: 0.5625
# Epoch 80/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.7188 - accuracy: 0.8889 - val_loss: 11.0393 - val_accuracy: 0.5625
# Epoch 81/100
# 2/2 [==============================] - 3s 1s/step - loss: 10.6745 - accuracy: 0.8571 - val_loss: 11.0190 - val_accuracy: 0.5625
# Epoch 82/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.6703 - accuracy: 0.8571 - val_loss: 10.9956 - val_accuracy: 0.5625
# Epoch 83/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.6860 - accuracy: 0.7937 - val_loss: 10.9793 - val_accuracy: 0.5625
# Epoch 84/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.6632 - accuracy: 0.8254 - val_loss: 10.9641 - val_accuracy: 0.5625
# Epoch 85/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.5596 - accuracy: 0.8413 - val_loss: 10.9425 - val_accuracy: 0.5625
# Epoch 86/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.5397 - accuracy: 0.8889 - val_loss: 10.9196 - val_accuracy: 0.5625
# Epoch 87/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.5345 - accuracy: 0.8889 - val_loss: 10.8939 - val_accuracy: 0.5625
# Epoch 88/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.4459 - accuracy: 0.9524 - val_loss: 10.8655 - val_accuracy: 0.5625
# Epoch 89/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.4760 - accuracy: 0.8571 - val_loss: 10.8374 - val_accuracy: 0.5625
# Epoch 90/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.3099 - accuracy: 0.9206 - val_loss: 10.8217 - val_accuracy: 0.5625
# Epoch 91/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.3995 - accuracy: 0.8730 - val_loss: 10.8132 - val_accuracy: 0.5625
# Epoch 92/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.3706 - accuracy: 0.8730 - val_loss: 10.7895 - val_accuracy: 0.5625
# Epoch 93/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.3546 - accuracy: 0.8571 - val_loss: 10.7648 - val_accuracy: 0.5625
# Epoch 94/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.2876 - accuracy: 0.9048 - val_loss: 10.7313 - val_accuracy: 0.5625
# Epoch 95/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.4091 - accuracy: 0.8254 - val_loss: 10.6911 - val_accuracy: 0.5625
# Epoch 96/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.2191 - accuracy: 0.8889 - val_loss: 10.6510 - val_accuracy: 0.5625
# Epoch 97/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.2261 - accuracy: 0.8889 - val_loss: 10.6090 - val_accuracy: 0.5625
# Epoch 98/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.1297 - accuracy: 0.9683 - val_loss: 10.5735 - val_accuracy: 0.5625
# Epoch 99/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.1809 - accuracy: 0.8889 - val_loss: 10.5427 - val_accuracy: 0.5625
# Epoch 100/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.2063 - accuracy: 0.8254 - val_loss: 10.5110 - val_accuracy: 0.5625
# 2/2 [==============================] - 1s 360ms/step - loss: 10.0971 - accuracy: 0.9524
# 1/1 [==============================] - 0s 336ms/step - loss: 10.5110 - accuracy: 0.5625
# 1/1 [==============================] - 0s 329ms/step
# Epoch 1/100
# 2/2 [==============================] - 4s 2s/step - loss: 10.2386 - accuracy: 0.8095 - val_loss: 10.0784 - val_accuracy: 1.0000
# Epoch 2/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.1931 - accuracy: 0.8095 - val_loss: 10.0487 - val_accuracy: 1.0000
# Epoch 3/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.1729 - accuracy: 0.8413 - val_loss: 10.0209 - val_accuracy: 1.0000
# Epoch 4/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.2367 - accuracy: 0.8095 - val_loss: 9.9967 - val_accuracy: 1.0000
# Epoch 5/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.1039 - accuracy: 0.8413 - val_loss: 9.9747 - val_accuracy: 1.0000
# Epoch 6/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.0600 - accuracy: 0.8254 - val_loss: 9.9570 - val_accuracy: 1.0000
# Epoch 7/100
# 2/2 [==============================] - 3s 2s/step - loss: 10.1514 - accuracy: 0.7778 - val_loss: 9.9422 - val_accuracy: 1.0000
# Epoch 8/100
# 2/2 [==============================] - 3s 2s/step - loss: 10
- val_accuracy: 1.0000
# Epoch 64/100
# 2/2 [==============================] - 3s 2s/step - loss: 6.0440 - accuracy: 0.9841 - val_loss: 5.9839 - val_accuracy: 1.0000
# Epoch 65/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.9850 - accuracy: 1.0000 - val_loss: 5.9646 - val_accuracy: 1.0000
# Epoch 66/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.9559 - accuracy: 1.0000 - val_loss: 5.9454 - val_accuracy: 1.0000
# Epoch 67/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.9873 - accuracy: 0.9524 - val_loss: 5.9271 - val_accuracy: 1.0000
# Epoch 68/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.9667 - accuracy: 0.9683 - val_loss: 5.9095 - val_accuracy: 1.0000
# Epoch 69/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.9232 - accuracy: 0.9841 - val_loss: 5.8899 - val_accuracy: 1.0000
# Epoch 70/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.8983 - accuracy: 0.9841 - val_loss: 5.8710 - val_accuracy: 1.0000
# Epoch 71/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.9364 - accuracy: 0.9524 - val_loss: 5.8541 - val_accuracy: 1.0000
# Epoch 72/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.8621 - accuracy: 0.9683 - val_loss: 5.8419 - val_accuracy: 1.0000
# Epoch 73/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.8741 - accuracy: 0.9683 - val_loss: 5.8252 - val_accuracy: 1.0000
# Epoch 74/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.8396 - accuracy: 0.9841 - val_loss: 5.8014 - val_accuracy: 1.0000
# Epoch 75/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.8134 - accuracy: 0.9841 - val_loss: 5.7768 - val_accuracy: 1.0000
# Epoch 76/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.7792 - accuracy: 0.9683 - val_loss: 5.7509 - val_accuracy: 1.0000
# Epoch 77/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.7661 - accuracy: 0.9841 - val_loss: 5.7267 - val_accuracy: 1.0000
# Epoch 78/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.7106 - accuracy: 1.0000 - val_loss: 5.7042 - val_accuracy: 1.0000
# Epoch 79/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.7055 - accuracy: 0.9841 - val_loss: 5.6826 - val_accuracy: 1.0000
# Epoch 80/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.6663 - accuracy: 1.0000 - val_loss: 5.6627 - val_accuracy: 1.0000
# Epoch 81/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.6758 - accuracy: 1.0000 - val_loss: 5.6448 - val_accuracy: 1.0000
# Epoch 82/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.6656 - accuracy: 0.9841 - val_loss: 5.6252 - val_accuracy: 1.0000
# Epoch 83/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.6123 - accuracy: 1.0000 - val_loss: 5.6059 - val_accuracy: 1.0000
# Epoch 84/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.6866 - accuracy: 0.9524 - val_loss: 5.5867 - val_accuracy: 1.0000
# Epoch 85/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.6059 - accuracy: 0.9841 - val_loss: 5.5654 - val_accuracy: 1.0000
# Epoch 86/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.5925 - accuracy: 0.9841 - val_loss: 5.5429 - val_accuracy: 1.0000
# Epoch 87/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.5611 - accuracy: 0.9841 - val_loss: 5.5218 - val_accuracy: 1.0000
# Epoch 88/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.5113 - accuracy: 1.0000 - val_loss: 5.5008 - val_accuracy: 1.0000
# Epoch 89/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.5362 - accuracy: 0.9841 - val_loss: 5.4820 - val_accuracy: 1.0000
# Epoch 90/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.4777 - accuracy: 1.0000 - val_loss: 5.4621 - val_accuracy: 1.0000
# Epoch 91/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.4642 - accuracy: 1.0000 - val_loss: 5.4417 - val_accuracy: 1.0000
# Epoch 92/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.4368 - accuracy: 1.0000 - val_loss: 5.4216 - val_accuracy: 1.0000
# Epoch 93/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.4075 - accuracy: 1.0000 - val_loss: 5.4020 - val_accuracy: 1.0000
# Epoch 94/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.3991 - accuracy: 1.0000 - val_loss: 5.3845 - val_accuracy: 1.0000
# Epoch 95/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.3922 - accuracy: 0.9841 - val_loss: 5.3684 - val_accuracy: 1.0000
# Epoch 96/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.3490 - accuracy: 1.0000 - val_loss: 5.3529 - val_accuracy: 1.0000
# Epoch 97/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.3439 - accuracy: 1.0000 - val_loss: 5.3404 - val_accuracy: 1.0000
# Epoch 98/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.3235 - accuracy: 0.9841 - val_loss: 5.3269 - val_accuracy: 1.0000
# Epoch 99/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.3254 - accuracy: 1.0000 - val_loss: 5.3105 - val_accuracy: 1.0000
# Epoch 100/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.2994 - accuracy: 1.0000 - val_loss: 5.2962 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 573ms/step - loss: 5.2661 - accuracy: 1.0000
# 1/1 [==============================] - 0s 441ms/step - loss: 5.2962 - accuracy: 1.0000
# 1/1 [==============================] - 0s 420ms/step
# Epoch 1/100
# 2/2 [==============================] - 4s 2s/step - loss: 5.3161 - accuracy: 0.9375 - val_loss: 5.2451 - val_accuracy: 1.0000
# Epoch 2/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.2560 - accuracy: 0.9844 - val_loss: 5.2285 - val_accuracy: 1.0000
# Epoch 3/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.2589 - accuracy: 0.9688 - val_loss: 5.2124 - val_accuracy: 1.0000
# Epoch 4/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.2230 - accuracy: 1.0000 - val_loss: 5.1949 - val_accuracy: 1.0000
# Epoch 5/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.2459 - accuracy: 0.9688 - val_loss: 5.1749 - val_accuracy: 1.0000
# Epoch 6/100
# 2/2 [==============================] - 3s 1s/step - loss: 5.2026 - accuracy: 0.9844 - val_loss: 5.1569 - val_accuracy: 1.0000
# Epoch 7/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.1795 - accuracy: 0.9688 - val_loss: 5.1383 - val_accuracy: 1.0000
# Epoch 8/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.1998 - accuracy: 0.9531 - val_loss: 5.1228 - val_accuracy: 1.0000
# Epoch 9/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.1546 - accuracy: 0.9688 - val_loss: 5.1044 - val_accuracy: 1.0000
# Epoch 10/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.1292 - accuracy: 0.9688 - val_loss: 5.0817 - val_accuracy: 1.0000
# Epoch 11/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.0798 - accuracy: 0.9844 - val_loss: 5.0581 - val_accuracy: 1.0000
# Epoch 12/100
# 2/2 [==============================] - 3s 2s/step - loss: 5.0684 - accuracy: 0.9844 - val_loss: 5.0345 - val_accuracy: 1.0000
# Epoch 13/100
# 2/2 [==============================] - 3s 2s/step - loss: 5
- val_accuracy: 1.0000
# Epoch 65/100
# 2/2 [==============================] - 3s 2s/step - loss: 4.1445 - accuracy: 0.9844 - val_loss: 4.1394 - val_accuracy: 1.0000
# Epoch 66/100
# 2/2 [==============================] - 3s 2s/step - loss: 4.1051 - accuracy: 1.0000 - val_loss: 4.1202 - val_accuracy: 1.0000
# Epoch 67/100
# 2/2 [==============================] - 3s 2s/step - loss: 4.0897 - accuracy: 1.0000 - val_loss: 4.1019 - val_accuracy: 1.0000
# Epoch 68/100
# 2/2 [==============================] - 3s 2s/step - loss: 4.0757 - accuracy: 1.0000 - val_loss: 4.0832 - val_accuracy: 1.0000
# Epoch 69/100
# 2/2 [==============================] - 3s 2s/step - loss: 4.0673 - accuracy: 1.0000 - val_loss: 4.0663 - val_accuracy: 1.0000
# Epoch 70/100
# 2/2 [==============================] - 4s 2s/step - loss: 4.0478 - accuracy: 1.0000 - val_loss: 4.0504 - val_accuracy: 1.0000
# Epoch 71/100
# 2/2 [==============================] - 4s 2s/step - loss: 4.0427 - accuracy: 0.9844 - val_loss: 4.0351 - val_accuracy: 1.0000
# Epoch 72/100
# 2/2 [==============================] - 3s 2s/step - loss: 4.0112 - accuracy: 1.0000 - val_loss: 4.0203 - val_accuracy: 1.0000
# Epoch 73/100
# 2/2 [==============================] - 4s 2s/step - loss: 4.0085 - accuracy: 1.0000 - val_loss: 4.0050 - val_accuracy: 1.0000
# Epoch 74/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.9827 - accuracy: 1.0000 - val_loss: 3.9913 - val_accuracy: 1.0000
# Epoch 75/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.9666 - accuracy: 1.0000 - val_loss: 3.9775 - val_accuracy: 1.0000
# Epoch 76/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.9629 - accuracy: 0.9844 - val_loss: 3.9618 - val_accuracy: 1.0000
# Epoch 77/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.9575 - accuracy: 0.9844 - val_loss: 3.9460 - val_accuracy: 1.0000
# Epoch 78/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.9493 - accuracy: 0.9844 - val_loss: 3.9319 - val_accuracy: 1.0000
# Epoch 79/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.9052 - accuracy: 1.0000 - val_loss: 3.9197 - val_accuracy: 1.0000
# Epoch 80/100
# 2/2 [==============================] - 3s 2s/step - loss: 4.0762 - accuracy: 0.9844 - val_loss: 3.8972 - val_accuracy: 1.0000
# Epoch 81/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.8745 - accuracy: 1.0000 - val_loss: 3.8779 - val_accuracy: 1.0000
# Epoch 82/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.8711 - accuracy: 0.9844 - val_loss: 3.8610 - val_accuracy: 1.0000
# Epoch 83/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.8485 - accuracy: 1.0000 - val_loss: 3.8450 - val_accuracy: 1.0000
# Epoch 84/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.8441 - accuracy: 1.0000 - val_loss: 3.8290 - val_accuracy: 1.0000
# Epoch 85/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.8126 - accuracy: 1.0000 - val_loss: 3.8121 - val_accuracy: 1.0000
# Epoch 86/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.8050 - accuracy: 1.0000 - val_loss: 3.7954 - val_accuracy: 1.0000
# Epoch 87/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.7804 - accuracy: 1.0000 - val_loss: 3.7795 - val_accuracy: 1.0000
# Epoch 88/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.7751 - accuracy: 1.0000 - val_loss: 3.7628 - val_accuracy: 1.0000
# Epoch 89/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.7651 - accuracy: 1.0000 - val_loss: 3.7472 - val_accuracy: 1.0000
# Epoch 90/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.7580 - accuracy: 0.9844 - val_loss: 3.7326 - val_accuracy: 1.0000
# Epoch 91/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.7400 - accuracy: 0.9844 - val_loss: 3.7187 - val_accuracy: 1.0000
# Epoch 92/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.7236 - accuracy: 1.0000 - val_loss: 3.7056 - val_accuracy: 1.0000
# Epoch 93/100
# 2/2 [==============================] - 3s 1s/step - loss: 3.6976 - accuracy: 1.0000 - val_loss: 3.6929 - val_accuracy: 1.0000
# Epoch 94/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.6840 - accuracy: 1.0000 - val_loss: 3.6799 - val_accuracy: 1.0000
# Epoch 95/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.6672 - accuracy: 1.0000 - val_loss: 3.6683 - val_accuracy: 1.0000
# Epoch 96/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.6746 - accuracy: 0.9844 - val_loss: 3.6643 - val_accuracy: 1.0000
# Epoch 97/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.6884 - accuracy: 0.9844 - val_loss: 3.6688 - val_accuracy: 1.0000
# Epoch 98/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.6430 - accuracy: 0.9844 - val_loss: 3.6759 - val_accuracy: 1.0000
# Epoch 99/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.6035 - accuracy: 1.0000 - val_loss: 3.6836 - val_accuracy: 1.0000
# Epoch 100/100
# 2/2 [==============================] - 3s 2s/step - loss: 3.5962 - accuracy: 1.0000 - val_loss: 3.6906 - val_accuracy: 1.0000
# 2/2 [==============================] - 1s 367ms/step - loss: 3.6079 - accuracy: 0.9844
# 1/1 [==============================] - 0s 324ms/step - loss: 3.6906 - accuracy: 1.0000
# 1/1 [==============================] - 0s 315ms/step

# %%
# Calculate the average accuracies
avg_train_accuracy = np.mean(train_accuracies)
avg_val_accuracy = np.mean(val_accuracies)

print('Average Training Accuracy:', avg_train_accuracy)
print('Average Validation Accuracy:', avg_val_accuracy)
# Out:
# Average Training Accuracy: 0.9683035731315612
# Average Validation Accuracy: 0.8

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

target_names = ['Normal', 'Concussed']
print('Confusion Matrix')
cm = confusion_matrix(true_labels, predicted_labels)
print(cm)
print('\n')

print('Classification Report')
print(classification_report(true_labels, predicted_labels, target_names=target_names))
# Out:
# Confusion Matrix
# [[30  0]
#  [49  0]]
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.38      1.00      0.55        30
#    Concussed       0.00      0.00      0.00        49
#
#     accuracy                           0.38        79
#    macro avg       0.19      0.50      0.28        79
# weighted avg       0.14      0.38      0.21        79
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
