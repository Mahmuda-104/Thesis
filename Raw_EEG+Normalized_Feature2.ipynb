# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmuda-104/Thesis/blob/main/Raw_EEG%2BNormalized_Feature2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
from scipy.io import loadmat

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Data'

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')
for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []
for control_data_path in control_data:
    n_epochs = 35 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    control_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{control_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        control_arr.append(np.array(downsampled_data))
        
    Control30.append(np.array(control_arr))

Control30 = np.array(Control30)
print( Control30[0].shape)
# Out:
# (35, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler
from google.colab import drive
from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_control_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features within the range of the minimum and maximum values of the corresponding channel
for i in range(len(Control30)):
    control_data = Control30[i]
    control_power = []
    for epoch in control_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            # Get the minimum and maximum values within the current channel
            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)

            # Normalize the features within the range of the current channel
            alpha_power_normalized = (alpha_power - channel_min_value) / (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value )))
            beta_power_normalized = (beta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value) ))
            delta_power_normalized = (delta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value)))

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)
            #ic_values = -np.log2(power_spectrum_adjusted / np.sum(power_spectrum_adjusted))
            concatenated_data = np.concatenate((channel_data, [alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values]))
            #print(alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values)
            epoch_power.append(concatenated_data.tolist())

        control_power.append(np.array(epoch_power))

    all_control_power.append(np.array(control_power))

all_control_power = np.array(all_control_power)
print(all_control_power.shape)
print(len(Control30))
# Out:
# (32, 35, 60, 1004)
# 32

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
 
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 35 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    concussed_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
    Concussed52.append(np.array(concussed_arr))

Concussed52 = np.array(Concussed52)
print( Concussed52[0].shape)
# Out:
# (35, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler
from google.colab import drive
from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_concussed_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features within the range of the minimum and maximum values of the corresponding channel
for i in range(len(Concussed52)):
    concussed_data = Concussed52[i]
    concussed_power = []
    for epoch in concussed_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            # Get the minimum and maximum values within the current channel
            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)

            # Normalize the features within the range of the current channel
            alpha_power_normalized = (alpha_power - channel_min_value) / (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value )))
            beta_power_normalized = (beta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value) ))
            delta_power_normalized = (delta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value)))

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)
            #ic_values = -np.log2(power_spectrum_adjusted / np.sum(power_spectrum_adjusted))

            concatenated_data = np.concatenate((channel_data, [alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values]))
            #print(alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values,ic_values)
            epoch_power.append(concatenated_data.tolist())

        concussed_power.append(np.array(epoch_power))

    all_concussed_power.append(np.array(concussed_power))

all_concussed_power = np.array(all_concussed_power)
print(all_concussed_power.shape)
print(len(Concussed52))
# Out:
# (52, 35, 60, 1004)
# 52

# %%
#concussed_power=np.array(concussed_power)
print(all_concussed_power.shape)
# Out:
# (52, 35, 60, 1004)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
dataset = np.concatenate((all_concussed_power, all_control_power), axis=0)

#(0 for control, 1 for concussed)
labels = np.concatenate((np.zeros(len(all_control_power)), np.ones(len(all_concussed_power))))

# %%
train_ratio = 0.7  # 80% for training
val_ratio = 0.15   # 10% for validation
test_ratio = 0.15  # 10% for testing

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=test_ratio, stratify=labels, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_ratio/(train_ratio+val_ratio), stratify=y_train, random_state=42)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Normalize the input data
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0
input_shape = X_train.shape[1:]
# Build the CNN model
model = tf.keras.Sequential()
model.add(layers.Conv2D(16, kernel_size=(6, 6), strides=1, activation='relu', padding='same', input_shape=input_shape))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(32, kernel_size=(3, 3), activation='relu', strides=1, padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu', strides=1, padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(2, activation='softmax'))

learning_rate = 0.005
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
val_loss, val_accuracy = model.evaluate(X_val, y_val)

# Print the test accuracy
print("Test Accuracy:", test_accuracy)

# Generate training and testing accuracy
training_accuracy = history.history['accuracy']
testing_accuracy = history.history['val_accuracy']

# Generate learning curve
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plot training and testing accuracy
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(testing_accuracy, label='Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot learning curve
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 2/2 [==============================] - 20s 4s/step - loss: 1174.9987 - accuracy: 0.5690 - val_loss: 3264.8896 - val_accuracy: 0.3846
# Epoch 2/100
# 2/2 [==============================] - 0s 287ms/step - loss: 3811.7554 - accuracy: 0.3966 - val_loss: 159.1245 - val_accuracy: 0.6154
# Epoch 3/100
# 2/2 [==============================] - 1s 340ms/step - loss: 1217.1097 - accuracy: 0.6034 - val_loss: 83.9678 - val_accuracy: 0.6154
# Epoch 4/100
# 2/2 [==============================] - 0s 282ms/step - loss: 1050.0437 - accuracy: 0.6034 - val_loss: 107.1650 - val_accuracy: 0.6923
# Epoch 5/100
# 2/2 [==============================] - 1s 331ms/step - loss: 376.6043 - accuracy: 0.5000 - val_loss: 252.4640 - val_accuracy: 0.3846
# Epoch 6/100
# 2/2 [==============================] - 1s 336ms/step - loss: 287.3778 - accuracy: 0.5000 - val_loss: 85.7821 - val_accuracy: 0.4615
# Epoch 7/100
# 2/2 [==============================] - 1s 343ms/step - loss: 247.4262 - accuracy: 0.4828 - val_loss: 16.2258 - val_accuracy: 0.6154
# Epoch 8/100
# 2/2 [==============================] - 1s 334ms/step - loss: 107.9588 - accuracy: 0.6207 - val_loss: 17.0683 - val_accuracy: 0.6154
# Epoch 9/100
# 2/2 [==============================] - 0s 299ms/step - loss: 77.1297 - accuracy: 0.6552 - val_loss: 10.8198 - val_accuracy: 0.6154
# Epoch 10/100
# 2/2 [==============================] - 0s 296ms/step - loss: 117.5197 - accuracy: 0.5862 - val_loss: 4.9299 - val_accuracy: 0.5385
# Epoch 11/100
# 2/2 [==============================] - 1s 338ms/step - loss: 46.6911 - accuracy: 0.5345 - val_loss: 9.9548 - val_accuracy: 0.3846
# Epoch 12/100
# 2/2 [==============================] - 1s 633ms/step - loss: 85.3837 - accuracy: 0.6724 - val_loss: 25.7687 - val_accuracy: 0.3846
# Epoch 13/100
# 2/2 [==============================] - 1s 433ms/step - loss: 25.5623 - accuracy: 0.5862 - val_loss: 36.0298 - val_accuracy: 0.4615
# Epoch 14/100
# 2/2 [==============================] - 1s 383ms/step - loss: 43.8311 - accuracy: 0.5690 - val_loss: 25.3723 - val_accuracy: 0.5385
# Epoch 15/100
# 2/2 [==============================] - 1s 588ms/step - loss: 27.2607 - accuracy: 0.6034 - val_loss: 16.6623 - val_accuracy: 0.6923
# Epoch 16/100
# 2/2 [==============================] - 1s 396ms/step - loss: 44.4866 - accuracy: 0.4828 - val_loss: 5.6586 - val_accuracy: 0.6923
# Epoch 17/100
# 2/2 [==============================] - 0s 302ms/step - loss: 611.2426 - accuracy: 0.6207 - val_loss: 0.6623 - val_accuracy: 0.7692
# Epoch 18/100
# 2/2 [==============================] - 1s 330ms/step - loss: 27.1111 - accuracy: 0.6379 - val_loss: 0.6909 - val_accuracy: 0.7692
# Epoch 19/100
# 2/2 [==============================] - 1s 343ms/step - loss: 76.7341 - accuracy: 0.6034 - val_loss: 0.6511 - val_accuracy: 0.6923
# Epoch 20/100
# 2/2 [==============================] - 0s 279ms/step - loss: 45.2081 - accuracy: 0.5517 - val_loss: 1.2418 - val_accuracy: 0.6923
# Epoch 21/100
# 2/2 [==============================] - 0s 302ms/step - loss: 26.0766 - accuracy: 0.6207 - val_loss: 1.6421 - val_accuracy: 0.5385
# Epoch 22/100
# 2/2 [==============================] - 0s 290ms/step - loss: 411.5352 - accuracy: 0.5172 - val_loss: 11.4840 - val_accuracy: 0.5385
# Epoch 23/100
# 2/2 [==============================] - 0s 287ms/step - loss: 31.0696 - accuracy: 0.5862 - val_loss: 12.1034 - val_accuracy: 0.6154
# Epoch 24/100
# 2/2 [==============================] - 1s 335ms/step - loss: 70.7753 - accuracy: 0.5690 - val_loss: 12.3858 - val_accuracy: 0.6923
# Epoch 25/100
# 2/2 [==============================] - 1s 337ms/step - loss: 260.8968 - accuracy: 0.4828 - val_loss: 0.9558 - val_accuracy: 0.7692
# Epoch 26/100
# 2/2 [==============================] - 0s 291ms/step - loss: 299.8398 - accuracy: 0.5517 - val_loss: 0.4654 - val_accuracy: 0.8462
# Epoch 27/100
# 2/2 [==============================] - 0s 300ms/step - loss: 27.3430 - accuracy: 0.5345 - val_loss: 7.0605 - val_accuracy: 0.8462
# Epoch 28/100
# 2/2 [==============================] - 1s 329ms/step - loss: 42.7250 - accuracy: 0.5000 - val_loss: 12.5474 - val_accuracy: 0.8462
# Epoch 29/100
# 2/2 [==============================] - 0s 299ms/step - loss: 41.4117 - accuracy: 0.4828 - val_loss: 9.2599 - val_accuracy: 0.7692
# Epoch 30/100
# 2/2 [==============================] - 1s 340ms/step - loss: 342.0809 - accuracy: 0.5517 - val_loss: 0.4285 - val_accuracy: 0.8462
# Epoch 31/100
# 2/2 [==============================] - 0s 297ms/step - loss: 43.5649 - accuracy: 0.5000 - val_loss: 0.4379 - val_accuracy: 0.7692
# Epoch 32/100
# 2/2 [==============================] - 0s 307ms/step - loss: 31.6790 - accuracy: 0.6207 - val_loss: 1.8529 - val_accuracy: 0.7692
# Epoch 33/100
# 2/2 [==============================] - 1s 325ms/step - loss: 41.6044 - accuracy: 0.6379 - val_loss: 5.5462 - val_accuracy: 0.7692
# Epoch 34/100
# 2/2 [==============================] - 0s 291ms/step - loss: 42.3509 - accuracy: 0.5690 - val_loss: 9.6616 - val_accuracy: 0.6154
# Epoch 35/100
# 2/2 [==============================] - 0s 302ms/step - loss: 49.2881 - accuracy: 0.4828 - val_loss: 13.7963 - val_accuracy: 0.4615
# Epoch 36/100
# 2/2 [==============================] - 1s 352ms/step - loss: 107.7517 - accuracy: 0.5345 - val_loss: 21.0308 - val_accuracy: 0.5385
# Epoch 37/100
# 2/2 [==============================] - 1s 557ms/step - loss: 24.3295 - accuracy: 0.5517 - val_loss: 17.9938 - val_accuracy: 0.5385
# Epoch 38/100
# 2/2 [==============================] - 1s 559ms/step - loss: 66.2593 - accuracy: 0.5000 - val_loss: 26.1745 - val_accuracy: 0.6154
# Epoch 39/100
# 2/2 [==============================] - 1s 484ms/step - loss: 227.1195 - accuracy: 0.6034 - val_loss: 17.4699 - val_accuracy: 0.5385
# Epoch 40/100
# 2/2 [==============================] - 1s 457ms/step - loss: 34.1758 - accuracy: 0.4828 - val_loss: 1.2674 - val_accuracy: 0.5385
# 1/1 [==============================] - 0s 128ms/step - loss: 2.2347 - accuracy: 0.6154
# 1/1 [==============================] - 0s 131ms/step - loss: 0.4285 - accuracy: 0.8462
# Test Accuracy: 0.6153846383094788

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# Split the dataset into training, validation, and test sets
# X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=test_ratio, stratify=labels, random_state=42)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_ratio/(train_ratio+val_ratio), stratify=y_train, random_state=42)

# Normalize the input data (if required)
# X_train = X_train / 255.0
# X_val = X_val / 255.0
# X_test = X_test / 255.0

# Reshape the input data based on the expected input shape of the model
input_shape = X_train.shape[1:]  # Assuming the first dimension is the number of samples
X_train = X_train.reshape((-1,) + input_shape)
X_val = X_val.reshape((-1,) + input_shape)
X_test = X_test.reshape((-1,) + input_shape)

# Build the CNN model
model = tf.keras.Sequential()
model.add(layers.Conv2D(16, kernel_size=(6, 6),strides=1, activation='relu',padding='same', input_shape=input_shape))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(32, kernel_size=(3, 3), strides=1,activation='relu',padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.5))
model.add(layers.Conv2D(64, kernel_size=(3, 3),strides=1, activation='relu',padding='same'))
model.add(layers.MaxPooling2D(pool_size=2))
model.add(layers.Dropout(0.5))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the model with the desired loss function and optimizer
learning_rate = 0.005  # Specify your desired learning rate
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32, callbacks=[early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
val_loss, val_accuracy = model.evaluate(X_val, y_val)

# Print the test accuracy
print("Test Accuracy:", test_accuracy)

training_accuracy = history.history['accuracy']
testing_accuracy = history.history['val_accuracy']

# Generate learning curve
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Plot training and testing accuracy
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(testing_accuracy, label='Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot learning curve
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 2/2 [==============================] - 3s 722ms/step - loss: 6508.8662 - accuracy: 0.5172 - val_loss: 196.9496 - val_accuracy: 0.6154
# Epoch 2/100
# 2/2 [==============================] - 1s 335ms/step - loss: 1048.3456 - accuracy: 0.6034 - val_loss: 9.1732 - val_accuracy: 0.3846
# Epoch 3/100
# 2/2 [==============================] - 1s 341ms/step - loss: 31.4143 - accuracy: 0.5517 - val_loss: 11.0756 - val_accuracy: 0.3846
# Epoch 4/100
# 2/2 [==============================] - 1s 345ms/step - loss: 34.3299 - accuracy: 0.5172 - val_loss: 3.6869 - val_accuracy: 0.3846
# Epoch 5/100
# 2/2 [==============================] - 0s 297ms/step - loss: 65.9877 - accuracy: 0.5345 - val_loss: 0.8176 - val_accuracy: 0.4615
# Epoch 6/100
# 2/2 [==============================] - 0s 287ms/step - loss: 8.4775 - accuracy: 0.3966 - val_loss: 1.3607 - val_accuracy: 0.6154
# Epoch 7/100
# 2/2 [==============================] - 0s 289ms/step - loss: 1.0735 - accuracy: 0.6034 - val_loss: 1.6270 - val_accuracy: 0.6154
# Epoch 8/100
# 2/2 [==============================] - 1s 331ms/step - loss: 16.4699 - accuracy: 0.5517 - val_loss: 1.6977 - val_accuracy: 0.5385
# Epoch 9/100
# 2/2 [==============================] - 1s 533ms/step - loss: 29.7281 - accuracy: 0.6207 - val_loss: 1.1073 - val_accuracy: 0.4615
# Epoch 10/100
# 2/2 [==============================] - 1s 458ms/step - loss: 1.3044 - accuracy: 0.6207 - val_loss: 0.6875 - val_accuracy: 0.6923
# Epoch 11/100
# 2/2 [==============================] - 1s 590ms/step - loss: 0.8145 - accuracy: 0.6207 - val_loss: 0.6891 - val_accuracy: 0.6154
# Epoch 12/100
# 2/2 [==============================] - 1s 429ms/step - loss: 0.6887 - accuracy: 0.6207 - val_loss: 0.6887 - val_accuracy: 0.6154
# Epoch 13/100
# 2/2 [==============================] - 1s 411ms/step - loss: 0.6883 - accuracy: 0.6207 - val_loss: 0.6883 - val_accuracy: 0.6154
# Epoch 14/100
# 2/2 [==============================] - 1s 319ms/step - loss: 0.6879 - accuracy: 0.6207 - val_loss: 0.6879 - val_accuracy: 0.6154
# Epoch 15/100
# 2/2 [==============================] - 1s 335ms/step - loss: 0.6876 - accuracy: 0.6207 - val_loss: 0.6874 - val_accuracy: 0.6154
# Epoch 16/100
# 2/2 [==============================] - 1s 334ms/step - loss: 0.6870 - accuracy: 0.6207 - val_loss: 0.6870 - val_accuracy: 0.6154
# Epoch 17/100
# 2/2 [==============================] - 0s 302ms/step - loss: 2.5899 - accuracy: 0.6207 - val_loss: 0.6866 - val_accuracy: 0.6154
# Epoch 18/100
# 2/2 [==============================] - 1s 353ms/step - loss: 0.6861 - accuracy: 0.6207 - val_loss: 0.6861 - val_accuracy: 0.6154
# Epoch 19/100
# 2/2 [==============================] - 1s 309ms/step - loss: 0.6856 - accuracy: 0.6207 - val_loss: 0.6857 - val_accuracy: 0.6154
# Epoch 20/100
# 2/2 [==============================] - 0s 291ms/step - loss: 0.6853 - accuracy: 0.6207 - val_loss: 0.6852 - val_accuracy: 0.6154
# Epoch 21/100
# 2/2 [==============================] - 1s 345ms/step - loss: 0.6848 - accuracy: 0.6207 - val_loss: 0.6848 - val_accuracy: 0.6154
# Epoch 22/100
# 2/2 [==============================] - 1s 331ms/step - loss: 0.6844 - accuracy: 0.6207 - val_loss: 0.6844 - val_accuracy: 0.6154
# Epoch 23/100
# 2/2 [==============================] - 0s 300ms/step - loss: 0.6839 - accuracy: 0.6207 - val_loss: 0.6839 - val_accuracy: 0.6154
# Epoch 24/100
# 2/2 [==============================] - 1s 329ms/step - loss: 0.6834 - accuracy: 0.6207 - val_loss: 0.6835 - val_accuracy: 0.6154
# Epoch 25/100
# 2/2 [==============================] - 1s 345ms/step - loss: 0.6831 - accuracy: 0.6207 - val_loss: 0.6831 - val_accuracy: 0.6154
# Epoch 26/100
# 2/2 [==============================] - 1s 334ms/step - loss: 0.6824 - accuracy: 0.6207 - val_loss: 0.6827 - val_accuracy: 0.6154
# Epoch 27/100
# 2/2 [==============================] - 1s 332ms/step - loss: 0.6821 - accuracy: 0.6207 - val_loss: 0.6823 - val_accuracy: 0.6154
# Epoch 28/100
# 2/2 [==============================] - 0s 291ms/step - loss: 0.6816 - accuracy: 0.6207 - val_loss: 0.6819 - val_accuracy: 0.6154
# Epoch 29/100
# 2/2 [==============================] - 0s 293ms/step - loss: 0.6812 - accuracy: 0.6207 - val_loss: 0.6815 - val_accuracy: 0.6154
# Epoch 30/100
# 2/2 [==============================] - 1s 333ms/step - loss: 0.6808 - accuracy: 0.6207 - val_loss: 0.6811 - val_accuracy: 0.6154
# Epoch 31/100
# 2/2 [==============================] - 1s 312ms/step - loss: 0.6802 - accuracy: 0.6207 - val_loss: 0.6807 - val_accuracy: 0.6154
# Epoch 32/100
# 2/2 [==============================] - 0s 303ms/step - loss: 0.6800 - accuracy: 0.6207 - val_loss: 0.6803 - val_accuracy: 0.6154
# Epoch 33/100
# 2/2 [==============================] - 1s 502ms/step - loss: 0.6796 - accuracy: 0.6207 - val_loss: 0.6799 - val_accuracy: 0.6154
# Epoch 34/100
# 2/2 [==============================] - 1s 480ms/step - loss: 0.6791 - accuracy: 0.6207 - val_loss: 0.6795 - val_accuracy: 0.6154
# Epoch 35/100
# 2/2 [==============================] - 1s 363ms/step - loss: 0.6788 - accuracy: 0.6207 - val_loss: 0.6791 - val_accuracy: 0.6154
# Epoch 36/100
# 2/2 [==============================] - 1s 602ms/step - loss: 0.6783 - accuracy: 0.6207 - val_loss: 0.6788 - val_accuracy: 0.6154
# Epoch 37/100
# 2/2 [==============================] - 1s 475ms/step - loss: 0.6779 - accuracy: 0.6207 - val_loss: 0.6784 - val_accuracy: 0.6154
# Epoch 38/100
# 2/2 [==============================] - 1s 311ms/step - loss: 0.6776 - accuracy: 0.6207 - val_loss: 0.6781 - val_accuracy: 0.6154
# Epoch 39/100
# 2/2 [==============================] - 1s 312ms/step - loss: 0.6773 - accuracy: 0.6207 - val_loss: 0.6777 - val_accuracy: 0.6154
# Epoch 40/100
# 2/2 [==============================] - 1s 317ms/step - loss: 0.6769 - accuracy: 0.6207 - val_loss: 0.6774 - val_accuracy: 0.6154
# Epoch 41/100
# 2/2 [==============================] - 1s 344ms/step - loss: 0.6765 - accuracy: 0.6207 - val_loss: 0.6771 - val_accuracy: 0.6154
# Epoch 42/100
# 2/2 [==============================] - 0s 292ms/step - loss: 0.6761 - accuracy: 0.6207 - val_loss: 0.6768 - val_accuracy: 0.6154
# Epoch 43/100
# 2/2 [==============================] - 1s 309ms/step - loss: 0.6759 - accuracy: 0.6207 - val_loss: 0.6765 - val_accuracy: 0.6154
# Epoch 44/100
# 2/2 [==============================] - 1s 328ms/step - loss: 0.6754 - accuracy: 0.6207 - val_loss: 0.6762 - val_accuracy: 0.6154
# Epoch 45/100
# 2/2 [==============================] - 0s 305ms/step - loss: 0.6752 - accuracy: 0.6207 - val_loss: 0.6759 - val_accuracy: 0.6154
# Epoch 46/100
# 2/2 [==============================] - 0s 284ms/step - loss: 0.6748 - accuracy: 0.6207 - val_loss: 0.6756 - val_accuracy: 0.6154
# Epoch 47/100
# 2/2 [==============================] - 1s 331ms/step - loss: 0.6745 - accuracy: 0.6207 - val_loss: 0.6753 - val_accuracy: 0.6154
# Epoch 48/100
# 2/2 [==============================] - 0s 300ms/step - loss: 0.6742 - accuracy: 0.6207 - val_loss: 0.6750 - val_accuracy: 0.6154
# Epoch 49/100
# 2/2 [==============================] - 0s 300ms/step - loss: 0.6739 - accuracy: 0.6207 - val_loss: 0.6748 - val_accuracy: 0.6154
# Epoch 50/100
# 2/2 [==============================] - 1s 333ms/step - loss: 0.6735 - accuracy: 0.6207 - val_loss: 0.6745 - val_accuracy: 0.6154
# Epoch 51/100
# 2/2 [==============================] - 0s 301ms/step - loss: 0.6733 - accuracy: 0.6207 - val_loss: 0.6742 - val_accuracy: 0.6154
# Epoch 52/100
# 2/2 [==============================] - 0s 301ms/step - loss: 0.6730 - accuracy: 0.6207 - val_loss: 0.6739 - val_accuracy: 0.6154
# Epoch 53/100
# 2/2 [==============================] - 1s 341ms/step - loss: 0.6728 - accuracy: 0.6207 - val_loss: 0.6737 - val_accuracy: 0.6154
# Epoch 54/100
# 2/2 [==============================] - 0s 297ms/step - loss: 0.6725 - accuracy: 0.6207 - val_loss: 0.6734 - val_accuracy: 0.6154
# Epoch 55/100
# 2/2 [==============================] - 0s 299ms/step - loss: 0.6721 - accuracy: 0.6207 - val_loss: 0.6732 - val_accuracy: 0.6154
# Epoch 56/100
# 2/2 [==============================] - 1s 332ms/step - loss: 0.6719 - accuracy: 0.6207 - val_loss: 0.6729 - val_accuracy: 0.6154
# Epoch 57/100
# 2/2 [==============================] - 1s 321ms/step - loss: 0.6717 - accuracy: 0.6207 - val_loss: 0.6727 - val_accuracy: 0.6154
# Epoch 58/100
# 2/2 [==============================] - 1s 394ms/step - loss: 0.6713 - accuracy: 0.6207 - val_loss: 0.6725 - val_accuracy: 0.6154
# Epoch 59/100
# 2/2 [==============================] - 1s 389ms/step - loss: 0.6711 - accuracy: 0.6207 - val_loss: 0.6723 - val_accuracy: 0.6154
# Epoch 60/100
# 2/2 [==============================] - 1s 463ms/step - loss: 1.1325 - accuracy: 0.6034 - val_loss: 0.6721 - val_accuracy: 0.6154
# Epoch 61/100
# 2/2 [==============================] - 1s 407ms/step - loss: 0.6707 - accuracy: 0.6207 - val_loss: 0.6718 - val_accuracy: 0.6154
# Epoch 62/100
# 2/2 [==============================] - 1s 376ms/step - loss: 0.6703 - accuracy: 0.6207 - val_loss: 0.6716 - val_accuracy: 0.6154
# Epoch 63/100
# 2/2 [==============================] - 1s 372ms/step - loss: 0.6703 - accuracy: 0.6207 - val_loss: 0.6714 - val_accuracy: 0.6154
# Epoch 64/100
# 2/2 [==============================] - 0s 295ms/step - loss: 0.6601 - accuracy: 0.6207 - val_loss: 0.6712 - val_accuracy: 0.6154
# Epoch 65/100
# 2/2 [==============================] - 0s 304ms/step - loss: 0.6697 - accuracy: 0.6207 - val_loss: 0.6710 - val_accuracy: 0.6154
# Epoch 66/100
# 2/2 [==============================] - 1s 307ms/step - loss: 0.6695 - accuracy: 0.6207 - val_loss: 0.6708 - val_accuracy: 0.6154
# Epoch 67/100
# 2/2 [==============================] - 1s 309ms/step - loss: 0.6694 - accuracy: 0.6207 - val_loss: 0.6706 - val_accuracy: 0.6154
# Epoch 68/100
# 2/2 [==============================] - 0s 298ms/step - loss: 0.6691 - accuracy: 0.6207 - val_loss: 0.6705 - val_accuracy: 0.6154
# Epoch 69/100
# 2/2 [==============================] - 0s 306ms/step - loss: 0.6690 - accuracy: 0.6207 - val_loss: 0.6703 - val_accuracy: 0.6154
# Epoch 70/100
# 2/2 [==============================] - 1s 329ms/step - loss: 0.6688 - accuracy: 0.6207 - val_loss: 0.6701 - val_accuracy: 0.6154
# Epoch 71/100
# 2/2 [==============================] - 1s 334ms/step - loss: 0.6685 - accuracy: 0.6207 - val_loss: 0.6700 - val_accuracy: 0.6154
# Epoch 72/100
# 2/2 [==============================] - 1s 304ms/step - loss: 0.6684 - accuracy: 0.6207 - val_loss: 0.6699 - val_accuracy: 0.6154
# Epoch 73/100
# 2/2 [==============================] - 0s 301ms/step - loss: 0.6683 - accuracy: 0.6207 - val_loss: 0.6697 - val_accuracy: 0.6154
# Epoch 74/100
# 2/2 [==============================] - 1s 341ms/step - loss: 0.6681 - accuracy: 0.6207 - val_loss: 0.6696 - val_accuracy: 0.6154
# Epoch 75/100
# 2/2 [==============================] - 1s 339ms/step - loss: 0.6681 - accuracy: 0.6207 - val_loss: 0.6694 - val_accuracy: 0.6154
# Epoch 76/100
# 2/2 [==============================] - 1s 349ms/step - loss: 0.6678 - accuracy: 0.6207 - val_loss: 0.6693 - val_accuracy: 0.6154
# Epoch 77/100
# 2/2 [==============================] - 1s 308ms/step - loss: 0.6677 - accuracy: 0.6207 - val_loss: 0.6692 - val_accuracy: 0.6154
# Epoch 78/100
# 2/2 [==============================] - 1s 336ms/step - loss: 0.6675 - accuracy: 0.6207 - val_loss: 0.6691 - val_accuracy: 0.6154
# Epoch 79/100
# 2/2 [==============================] - 1s 341ms/step - loss: 0.7042 - accuracy: 0.6207 - val_loss: 0.6690 - val_accuracy: 0.6154
# Epoch 80/100
# 2/2 [==============================] - 0s 288ms/step - loss: 0.6674 - accuracy: 0.6207 - val_loss: 0.6689 - val_accuracy: 0.6154
# Epoch 81/100
# 2/2 [==============================] - 0s 302ms/step - loss: 0.6672 - accuracy: 0.6207 - val_loss: 0.6688 - val_accuracy: 0.6154
# Epoch 82/100
# 2/2 [==============================] - 1s 344ms/step - loss: 0.6670 - accuracy: 0.6207 - val_loss: 0.6687 - val_accuracy: 0.6154
# Epoch 83/100
# 2/2 [==============================] - 1s 400ms/step - loss: 0.6670 - accuracy: 0.6207 - val_loss: 0.6686 - val_accuracy: 0.6154
# Epoch 84/100
# 2/2 [==============================] - 1s 417ms/step - loss: 0.6669 - accuracy: 0.6207 - val_loss: 0.6685 - val_accuracy: 0.6154
# Epoch 85/100
# 2/2 [==============================] - 1s 448ms/step - loss: 0.6668 - accuracy: 0.6207 - val_loss: 0.6684 - val_accuracy: 0.6154
# Epoch 86/100
# 2/2 [==============================] - 1s 470ms/step - loss: 0.6666 - accuracy: 0.6207 - val_loss: 0.6684 - val_accuracy: 0.6154
# Epoch 87/100
# 2/2 [==============================] - 1s 603ms/step - loss: 0.6666 - accuracy: 0.6207 - val_loss: 0.6683 - val_accuracy: 0.6154
# Epoch 88/100
# 2/2 [==============================] - 1s 328ms/step - loss: 0.6664 - accuracy: 0.6207 - val_loss: 0.6682 - val_accuracy: 0.6154
# Epoch 89/100
# 2/2 [==============================] - 1s 342ms/step - loss: 0.6664 - accuracy: 0.6207 - val_loss: 0.6681 - val_accuracy: 0.6154
# Epoch 90/100
# 2/2 [==============================] - 1s 340ms/step - loss: 0.6663 - accuracy: 0.6207 - val_loss: 0.6680 - val_accuracy: 0.6154
# Epoch 91/100
# 2/2 [==============================] - 1s 344ms/step - loss: 0.6662 - accuracy: 0.6207 - val_loss: 0.6680 - val_accuracy: 0.6154
# Epoch 92/100
# 2/2 [==============================] - 0s 299ms/step - loss: 0.6662 - accuracy: 0.6207 - val_loss: 0.6679 - val_accuracy: 0.6154
# Epoch 93/100
# 2/2 [==============================] - 1s 336ms/step - loss: 0.6660 - accuracy: 0.6207 - val_loss: 0.6678 - val_accuracy: 0.6154
# Epoch 94/100
# 2/2 [==============================] - 1s 366ms/step - loss: 0.6660 - accuracy: 0.6207 - val_loss: 0.6678 - val_accuracy: 0.6154
# Epoch 95/100
# 2/2 [==============================] - 1s 345ms/step - loss: 0.6658 - accuracy: 0.6207 - val_loss: 0.6677 - val_accuracy: 0.6154
# Epoch 96/100
# 2/2 [==============================] - 0s 291ms/step - loss: 0.6658 - accuracy: 0.6207 - val_loss: 0.6677 - val_accuracy: 0.6154
# Epoch 97/100
# 2/2 [==============================] - 1s 310ms/step - loss: 0.6657 - accuracy: 0.6207 - val_loss: 0.6676 - val_accuracy: 0.6154
# Epoch 98/100
# 2/2 [==============================] - 0s 305ms/step - loss: 0.6657 - accuracy: 0.6207 - val_loss: 0.6676 - val_accuracy: 0.6154
# Epoch 99/100
# 2/2 [==============================] - 1s 314ms/step - loss: 0.6656 - accuracy: 0.6207 - val_loss: 0.6675 - val_accuracy: 0.6154
# Epoch 100/100
# 2/2 [==============================] - 0s 303ms/step - loss: 0.6655 - accuracy: 0.6207 - val_loss: 0.6675 - val_accuracy: 0.6154
# 1/1 [==============================] - 0s 148ms/step - loss: 0.6675 - accuracy: 0.6154
# 1/1 [==============================] - 0s 143ms/step - loss: 0.6675 - accuracy: 0.6154
# Test Accuracy: 0.6153846383094788
