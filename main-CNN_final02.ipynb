# %%
import os
import scipy.io
import numpy as np
from scipy import signal

# Set the path to the root directory where the "Control" folder is located
data_path = "/kaggle/input/control1"

fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')

for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []

for control_data_path in control_data:
    n_epochs = 105#len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    control_arr = []
    
    for i in range(1, n_epochs+1):
        epoch_path = os.path.join(control_data_path, f"trial{i}.mat")
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        control_arr.append(np.array(downsampled_data))
        
    Control30.append(np.array(control_arr))

Control30 = np.array(Control30)
print(Control30[0].shape)
# Out:
# (105, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_control_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features
for i in range(len(Control30)):
    control_data = Control30[i]
    control_power = []
    for epoch in control_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)

            # alpha_power_normalized = (alpha_power - channel_min_value) / (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value )))
            # beta_power_normalized = (beta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value) ))
            # delta_power_normalized = (delta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value)))

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)
            values=np.array([alpha_power,beta_power,delta_power,entropy_values])
            rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value
            concatenated_data = np.concatenate((channel_data, rescaled_values))

            #concatenated_data = np.concatenate((channel_data, [alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values]))
            #print(alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values)
            epoch_power.append(concatenated_data.tolist())

        control_power.append(np.array(epoch_power))

    all_control_power.append(np.array(control_power))

all_control_power = np.array(all_control_power)
print(all_control_power.shape)
print(len(Control30))
# Out:
# (30, 105, 60, 1004)
# 30

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
data_path = "/kaggle/input/concussed1"
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 105 #len([f for f in os.listdir(control_data_path) if f.endswith('.mat')])
    concussed_arr = []
    for i in range(1, n_epochs+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
    Concussed52.append(np.array(concussed_arr))

Concussed52 = np.array(Concussed52)
print( Concussed52[0].shape)
# Out:
# (105, 60, 1000)

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler

from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_concussed_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features within the range of the minimum and maximum values of the corresponding channel
for i in range(len(Concussed52)):
    concussed_data = Concussed52[i]
    concussed_power = []
    for epoch in concussed_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)

            # alpha_power_normalized = (alpha_power - channel_min_value) / (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value )))
            # beta_power_normalized = (beta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value) ))
            # delta_power_normalized = (delta_power - channel_min_value) /  (4*((channel_max_value-channel_min_value) * (channel_max_value-channel_min_value)))

            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)
            values=np.array([alpha_power,beta_power,delta_power,entropy_values])
            rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value
            concatenated_data = np.concatenate((channel_data, rescaled_values))

            #concatenated_data = np.concatenate((channel_data, [alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values]))
            #print(alpha_power_normalized, beta_power_normalized, delta_power_normalized, entropy_values)
            epoch_power.append(concatenated_data.tolist())

        concussed_power.append(np.array(epoch_power))

    all_concussed_power.append(np.array(concussed_power))

all_concussed_power = np.array(all_concussed_power)
print(all_concussed_power.shape)
print(len(Concussed52))
# Out:
# (49, 105, 60, 1004)
# 49

# %%
dataset = np.concatenate((Control30, Concussed52), axis=0)
labels = np.concatenate((np.zeros(len(Control30)), np.ones(len(Concussed52))))

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(dataset, labels, test_size=0.2, random_state=42)
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
# Out:
# X_train shape: (63, 105, 60, 1000)
# y_train shape: (63,)
# X_val shape: (16, 105, 60, 1000)
# y_val shape: (16,)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

input_shape = (105, 60, 1000)  # Input shape of your EEG data

model = tf.keras.Sequential()
model.add(layers.Conv2D(32, kernel_size=(3, 3), strides=2, activation='relu', padding='same', input_shape=input_shape))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.6))
model.add(layers.Conv2D(64, kernel_size=(3, 3), strides=2, activation='relu', padding='same', kernel_regularizer=l2(0.1)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.6))
model.add(layers.Conv2D(128, kernel_size=(3, 3), strides=2, activation='relu', padding='same', kernel_regularizer=l2(0.1)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.6))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.6))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 53, 30, 32)        288032
#
#  batch_normalization (BatchN  (None, 53, 30, 32)       128
#  ormalization)
#
#  dropout (Dropout)           (None, 53, 30, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 27, 15, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 27, 15, 64)       256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 27, 15, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 14, 8, 128)        73856
#
#  batch_normalization_2 (Batc  (None, 14, 8, 128)       512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 14, 8, 128)        0
#
#  flatten (Flatten)           (None, 14336)             0
#
#  dense (Dense)               (None, 256)               3670272
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 4,051,809
# Trainable params: 4,051,361
# Non-trainable params: 448
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
callback_list = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True)

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# %%
from sklearn.model_selection import KFold
X =dataset
y = labels 
Epoch = 100
batchSize = 32

# Define the number of folds for cross-validation
k_folds = 5
kf = KFold(n_splits=k_folds, shuffle=True)

train_accuracies = []
val_accuracies = []

# cross-validation
for train_index, val_index in kf.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    history = model.fit(
    X_train,
    y_train,
    epochs=Epoch,
    batch_size=batchSize,
    validation_data=(X_val, y_val),
    callbacks=callback_list,
    verbose=1)

    # Evaluate the model on training and validation data
    train_loss, train_accuracy = model.evaluate(X_train, y_train)
    val_loss, val_accuracy = model.evaluate(X_val, y_val)

    train_accuracies.append(train_accuracy)
    val_accuracies.append(val_accuracy)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 10s 4s/step - loss: 13.5511 - accuracy: 0.4603 - val_loss: 13.8606 - val_accuracy: 0.5000
# Epoch 2/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.8161 - accuracy: 0.6190 - val_loss: 13.9061 - val_accuracy: 0.5000
# Epoch 3/100
# 2/2 [==============================] - 5s 3s/step - loss: 14.0292 - accuracy: 0.5714 - val_loss: 13.8417 - val_accuracy: 0.5000
# Epoch 4/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.4588 - accuracy: 0.6349 - val_loss: 13.7166 - val_accuracy: 0.5000
# Epoch 5/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.7221 - accuracy: 0.5873 - val_loss: 13.5837 - val_accuracy: 0.5000
# Epoch 6/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.6494 - accuracy: 0.6190 - val_loss: 13.4706 - val_accuracy: 0.5000
# Epoch 7/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.5861 - accuracy: 0.5873 - val_loss: 13.3715 - val_accuracy: 0.5000
# Epoch 8/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.4776 - accuracy: 0.6825 - val_loss: 13.2923 - val_accuracy: 0.5000
# Epoch 9/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.9464 - accuracy: 0.6349 - val_loss: 13.2386 - val_accuracy: 0.6250
# Epoch 10/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.1401 - accuracy: 0.6190 - val_loss: 13.1982 - val_accuracy: 0.6250
# Epoch 11/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.0785 - accuracy: 0.7302 - val_loss: 13.1652 - val_accuracy: 0.7500
# Epoch 12/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.0733 - accuracy: 0.6667 - val_loss: 13.1394 - val_accuracy: 0.6875
# Epoch 13/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.3788 - accuracy: 0.5873 - val_loss: 13.1146 - val_accuracy: 0.6250
# Epoch 14/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.2389 - accuracy: 0.6190 - val_loss: 13.0896 - val_accuracy: 0.5625
# Epoch 15/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.9987 - accuracy: 0.6508 - val_loss: 13.0642 - val_accuracy: 0.5625
# Epoch 16/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.4878 - accuracy: 0.6190 - val_loss: 13.0366 - val_accuracy: 0.5625
# Epoch 17/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.2849 - accuracy: 0.5397 - val_loss: 13.0090 - val_accuracy: 0.5625
# Epoch 18/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.1875 - accuracy: 0.6032 - val_loss: 12.9823 - val_accuracy: 0.5000
# Epoch 19/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.2968 - accuracy: 0.7302 - val_loss: 12.9564 - val_accuracy: 0.5000
# Epoch 20/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.9828 - accuracy: 0.6032 - val_loss: 12.9309 - val_accuracy: 0.3125
# Epoch 21/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.8787 - accuracy: 0.6667 - val_loss: 12.9075 - val_accuracy: 0.3125
# Epoch 22/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.8791 - accuracy: 0.6032 - val_loss: 12.8831 - val_accuracy: 0.3750
# Epoch 23/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.8857 - accuracy: 0.7143 - val_loss: 12.8597 - val_accuracy: 0.4375
# Epoch 24/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.8803 - accuracy: 0.6349 - val_loss: 12.8368 - val_accuracy: 0.4375
# Epoch 25/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.9419 - accuracy: 0.7143 - val_loss: 12.8149 - val_accuracy: 0.5000
# Epoch 26/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.7370 - accuracy: 0.6825 - val_loss: 12.7906 - val_accuracy: 0.5000
# Epoch 27/100
# 2/2 [==============================] - 5s 3s/step - loss: 13.2818 - accuracy: 0.6032 - val_loss: 12.7673 - val_accuracy: 0.5000
# Epoch 28/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.8021 - accuracy: 0.7143 - val_loss: 12.7424 - val_accuracy: 0.5000
# Epoch 29/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.6875 - accuracy: 0.6032 - val_loss: 12.7174 - val_accuracy: 0.5000
# Epoch 30/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.8718 - accuracy: 0.6349 - val_loss: 12.6949 - val_accuracy: 0.5000
# Epoch 31/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.8515 - accuracy: 0.6825 - val_loss: 12.6740 - val_accuracy: 0.5000
# Epoch 32/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.7554 - accuracy: 0.6508 - val_loss: 12.6540 - val_accuracy: 0.5000
# Epoch 33/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.5284 - accuracy: 0.6825 - val_loss: 12.6330 - val_accuracy: 0.5000
# Epoch 34/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.5397 - accuracy: 0.6190 - val_loss: 12.6101 - val_accuracy: 0.5000
# Epoch 35/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.4910 - accuracy: 0.6508 - val_loss: 12.5868 - val_accuracy: 0.5000
# Epoch 36/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.6633 - accuracy: 0.6984 - val_loss: 12.5642 - val_accuracy: 0.5000
# Epoch 37/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.6289 - accuracy: 0.6190 - val_loss: 12.5404 - val_accuracy: 0.5000
# Epoch 38/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.3820 - accuracy: 0.7619 - val_loss: 12.5165 - val_accuracy: 0.5000
# Epoch 39/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.7476 - accuracy: 0.6032 - val_loss: 12.4918 - val_accuracy: 0.5000
# Epoch 40/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.3156 - accuracy: 0.6667 - val_loss: 12.4676 - val_accuracy: 0.5000
# Epoch 41/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.1715 - accuracy: 0.8254 - val_loss: 12.4441 - val_accuracy: 0.5000
# Epoch 42/100
# 2/2 [==============================] - 6s 3s/step - loss: 12.1911 - accuracy: 0.7619 - val_loss: 12.4202 - val_accuracy: 0.5000
# Epoch 43/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.3627 - accuracy: 0.7619 - val_loss: 12.3955 - val_accuracy: 0.5000
# Epoch 44/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.3225 - accuracy: 0.7460 - val_loss: 12.3716 - val_accuracy: 0.5000
# Epoch 45/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.2317 - accuracy: 0.7143 - val_loss: 12.3475 - val_accuracy: 0.5000
# Epoch 46/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.1010 - accuracy: 0.7778 - val_loss: 12.3228 - val_accuracy: 0.5000
# Epoch 47/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.1278 - accuracy: 0.6825 - val_loss: 12.2986 - val_accuracy: 0.5000
# Epoch 48/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.3632 - accuracy: 0.7143 - val_loss: 12.2759 - val_accuracy: 0.5000
# Epoch 49/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.0195 - accuracy: 0.7619 - val_loss: 12.2520 - val_accuracy: 0.5000
# Epoch 50/100
# 2/2 [==============================] - 5s 3s/step - loss: 12.0022 - accuracy: 0.7460 - val_loss: 12.2267 - val_accuracy: 0.5000
# Epoch 51/100
# 2/2 [==============================] - 5s 3s/step - loss: 11
100
# 2/2 [==============================] - 5s 3s/step - loss: 11.0813 - accuracy: 0.8095 - val_loss: 11.4161 - val_accuracy: 0.5000
# Epoch 82/100
# 2/2 [==============================] - 6s 4s/step - loss: 11.0288 - accuracy: 0.8571 - val_loss: 11.4050 - val_accuracy: 0.5000
# Epoch 83/100
# 2/2 [==============================] - 5s 3s/step - loss: 11.0633 - accuracy: 0.7778 - val_loss: 11.3968 - val_accuracy: 0.5000
# Epoch 84/100
# 2/2 [==============================] - 5s 3s/step - loss: 11.1177 - accuracy: 0.6825 - val_loss: 11.3821 - val_accuracy: 0.5000
# Epoch 85/100
# 2/2 [==============================] - 5s 3s/step - loss: 11.0460 - accuracy: 0.7778 - val_loss: 11.3604 - val_accuracy: 0.5000
# Epoch 86/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.9222 - accuracy: 0.8730 - val_loss: 11.3404 - val_accuracy: 0.5000
# Epoch 87/100
# 2/2 [==============================] - 5s 3s/step - loss: 11.0413 - accuracy: 0.8095 - val_loss: 11.3225 - val_accuracy: 0.5000
# Epoch 88/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.8154 - accuracy: 0.8730 - val_loss: 11.3031 - val_accuracy: 0.5000
# Epoch 89/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.8932 - accuracy: 0.7937 - val_loss: 11.2742 - val_accuracy: 0.5000
# Epoch 90/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.8695 - accuracy: 0.8095 - val_loss: 11.2413 - val_accuracy: 0.5000
# Epoch 91/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.8330 - accuracy: 0.8254 - val_loss: 11.1988 - val_accuracy: 0.5000
# Epoch 92/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.9534 - accuracy: 0.7460 - val_loss: 11.1718 - val_accuracy: 0.5000
# Epoch 93/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.7517 - accuracy: 0.8413 - val_loss: 11.1431 - val_accuracy: 0.5000
# Epoch 94/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.6803 - accuracy: 0.8254 - val_loss: 11.1107 - val_accuracy: 0.5000
# Epoch 95/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.6752 - accuracy: 0.8095 - val_loss: 11.0775 - val_accuracy: 0.5000
# Epoch 96/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.6828 - accuracy: 0.8254 - val_loss: 11.0452 - val_accuracy: 0.5000
# Epoch 97/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.6004 - accuracy: 0.8413 - val_loss: 11.0170 - val_accuracy: 0.5000
# Epoch 98/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.8932 - accuracy: 0.7937 - val_loss: 10.9911 - val_accuracy: 0.5000
# Epoch 99/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.6020 - accuracy: 0.8254 - val_loss: 10.9702 - val_accuracy: 0.5000
# Epoch 100/100
# 2/2 [==============================] - 10s 7s/step - loss: 10.7155 - accuracy: 0.8254 - val_loss: 10.9429 - val_accuracy: 0.5000
# 2/2 [==============================] - 4s 674ms/step - loss: 10.4720 - accuracy: 0.9683
# 1/1 [==============================] - 1s 848ms/step - loss: 10.9429 - accuracy: 0.5000
# Epoch 1/100
# 2/2 [==============================] - 8s 3s/step - loss: 10.6773 - accuracy: 0.7619 - val_loss: 10.5576 - val_accuracy: 0.9375
# Epoch 2/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.6168 - accuracy: 0.7937 - val_loss: 10.5374 - val_accuracy: 0.8750
# Epoch 3/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.4458 - accuracy: 0.8730 - val_loss: 10.5130 - val_accuracy: 0.8750
# Epoch 4/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.5706 - accuracy: 0.7937 - val_loss: 10.5031 - val_accuracy: 0.8125
# Epoch 5/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.5552 - accuracy: 0.8095 - val_loss: 10.4938 - val_accuracy: 0.5625
# Epoch 6/100
# 2/2 [==============================] - 4s 2s/step - loss: 10.4503 - accuracy: 0.8095 - val_loss: 10.4901 - val_accuracy: 0.5625
# Epoch 7/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.6153 - accuracy: 0.7937 - val_loss: 10.4773 - val_accuracy: 0.5625
# Epoch 8/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.5288 - accuracy: 0.7302 - val_loss: 10.4698 - val_accuracy: 0.5625
# Epoch 9/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.4234 - accuracy: 0.8413 - val_loss: 10.4492 - val_accuracy: 0.5625
# Epoch 10/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.4265 - accuracy: 0.7778 - val_loss: 10.4158 - val_accuracy: 0.5625
# Epoch 11/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.2478 - accuracy: 0.8095 - val_loss: 10.3972 - val_accuracy: 0.5625
# Epoch 12/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.3015 - accuracy: 0.7937 - val_loss: 10.3853 - val_accuracy: 0.5625
# Epoch 13/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.1759 - accuracy: 0.9048 - val_loss: 10.3869 - val_accuracy: 0.5625
# Epoch 14/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.2659 - accuracy: 0.8254 - val_loss: 10.3832 - val_accuracy: 0.5625
# Epoch 15/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.2253 - accuracy: 0.7937 - val_loss: 10.3767 - val_accuracy: 0.5625
# Epoch 16/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.2516 - accuracy: 0.7937 - val_loss: 10.3553 - val_accuracy: 0.5625
# Epoch 17/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.2233 - accuracy: 0.7460 - val_loss: 10.3377 - val_accuracy: 0.5625
# Epoch 18/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.1549 - accuracy: 0.8095 - val_loss: 10.3226 - val_accuracy: 0.5625
# Epoch 19/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.0510 - accuracy: 0.8254 - val_loss: 10.2943 - val_accuracy: 0.5625
# Epoch 20/100
# 2/2 [==============================] - 4s 3s/step - loss: 10.1089 - accuracy: 0.8254 - val_loss: 10.2811 - val_accuracy: 0.5625
# Epoch 21/100
# 2/2 [==============================] - 5s 3s/step - loss: 10.0411 - accuracy: 0.7778 - val_loss: 10.2651 - val_accuracy: 0.5625
# Epoch 22/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.9852 - accuracy: 0.8254 - val_loss: 10.2588 - val_accuracy: 0.5625
# Epoch 23/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.9867 - accuracy: 0.8571 - val_loss: 10.2618 - val_accuracy: 0.4375
# Epoch 24/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.9986 - accuracy: 0.8095 - val_loss: 10.2417 - val_accuracy: 0.4375
# Epoch 25/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.8814 - accuracy: 0.7937 - val_loss: 10.2156 - val_accuracy: 0.4375
# Epoch 26/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.8861 - accuracy: 0.8413 - val_loss: 10.1891 - val_accuracy: 0.4375
# Epoch 27/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.8137 - accuracy: 0.8254 - val_loss: 10.1597 - val_accuracy: 0.5000
# Epoch 28/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.7282 - accuracy: 0.8889 - val_loss: 10.1325 - val_accuracy: 0.5000
# Epoch 29/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.7133 - accuracy: 0.8571 - val_loss: 10.0769 - val_accuracy: 0.5625
# Epoch 30/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.7361 - accuracy: 0.8730 - val_loss: 10.0364 - val_accuracy: 0.5625
# Epoch 31/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.6919 - accuracy: 0.8889 - val_loss: 10.0009 - val_accuracy: 0.5625
# Epoch 32/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.7422 - accuracy: 0.8254 - val_loss: 9.9920 - val_accuracy: 0.5625
# Epoch 33/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.6462 - accuracy: 0.9048 - val_loss: 9.9654 - val_accuracy: 0.5625
# Epoch 34/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.6147 - accuracy: 0.8571 - val_loss: 9.9385 - val_accuracy: 0.5625
# Epoch 35/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.5814 - accuracy: 0.8571 - val_loss: 9.8996 - val_accuracy: 0.5625
# Epoch 36/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.6326 - accuracy: 0.8095 - val_loss: 9.8503 - val_accuracy: 0.5625
# Epoch 37/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.5519 - accuracy: 0.8730 - val_loss: 9.8139 - val_accuracy: 0.5625
# Epoch 38/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.6038 - accuracy: 0.8889 - val_loss: 9.7848 - val_accuracy: 0.5625
# Epoch 39/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.7621 - accuracy: 0.8413 - val_loss: 9.7922 - val_accuracy: 0.5625
# Epoch 40/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.4915 - accuracy: 0.8413 - val_loss: 9.7871 - val_accuracy: 0.5625
# Epoch 41/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.3976 - accuracy: 0.9365 - val_loss: 9.7925 - val_accuracy: 0.5000
# Epoch 42/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.4283 - accuracy: 0.8254 - val_loss: 9.7896 - val_accuracy: 0.5000
# Epoch 43/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.4199 - accuracy: 0.8889 - val_loss: 9.8068 - val_accuracy: 0.4375
# Epoch 44/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.3837 - accuracy: 0.8730 - val_loss: 9.8119 - val_accuracy: 0.4375
# Epoch 45/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.3278 - accuracy: 0.8889 - val_loss: 9.8040 - val_accuracy: 0.4375
# Epoch 46/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.3022 - accuracy: 0.8730 - val_loss: 9.7718 - val_accuracy: 0.4375
# Epoch 47/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.4429 - accuracy: 0.8095 - val_loss: 9.7322 - val_accuracy: 0.4375
# Epoch 48/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.3253 - accuracy: 0.8095 - val_loss: 9.6786 - val_accuracy: 0.5000
# Epoch 49/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.2762 - accuracy: 0.8254 - val_loss: 9.6273 - val_accuracy: 0.5000
# Epoch 50/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.2497 - accuracy: 0.8413 - val_loss: 9.6096 - val_accuracy: 0.5000
# Epoch 51/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.2215 - accuracy: 0.8254 - val_loss: 9.5792 - val_accuracy: 0.5000
# Epoch 52/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.2039 - accuracy: 0.8571 - val_loss: 9.5502 - val_accuracy: 0.5000
# Epoch 53/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.1382 - accuracy: 0.8413 - val_loss: 9.4957 - val_accuracy: 0.5000
# Epoch 54/100
# 2/2 [==============================] - 4s 3s/step - loss: 9.0519 - accuracy: 0.8730 - val_loss: 9.4622 - val_accuracy: 0.5000
# Epoch 55/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.0899 - accuracy: 0.8730 - val_loss: 9.4390 - val_accuracy: 0.5000
# Epoch 56/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.0088 - accuracy: 0.9048 - val_loss: 9.4369 - val_accuracy: 0.5000
# Epoch 57/100
# 2/2 [==============================] - 5s 3s/step - loss: 9.0265 - accuracy: 0.8571 - val_loss: 9.4318 - val_accuracy: 0.5000
# Epoch 58/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.9607 - accuracy: 0.8571 - val_loss: 9.4100 - val_accuracy: 0.5000
# Epoch 59/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.9586 - accuracy: 0.8254 - val_loss: 9.3979 - val_accuracy: 0.5000
# Epoch 60/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.8846 - accuracy: 0.9048 - val_loss: 9.4012 - val_accuracy: 0.5000
# Epoch 61/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.8603 - accuracy: 0.8889 - val_loss: 9.3891 - val_accuracy: 0.5000
# Epoch 62/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.8054 - accuracy: 0.9206 - val_loss: 9.3863 - val_accuracy: 0.4375
# Epoch 63/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.8975 - accuracy: 0.8413 - val_loss: 9.3746 - val_accuracy: 0.4375
# Epoch 64/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.8501 - accuracy: 0.8413 - val_loss: 9.3253 - val_accuracy: 0.5000
# Epoch 65/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.8609 - accuracy: 0.8571 - val_loss: 9.2738 - val_accuracy: 0.5000
# Epoch 66/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.7143 - accuracy: 0.9206 - val_loss: 9.2124 - val_accuracy: 0.5000
# Epoch 67/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.6377 - accuracy: 0.9524 - val_loss: 9.1595 - val_accuracy: 0.5000
# Epoch 68/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.7050 - accuracy: 0.8889 - val_loss: 9.1126 - val_accuracy: 0.5000
# Epoch 69/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.6907 - accuracy: 0.8730 - val_loss: 9.0742 - val_accuracy: 0.5000
# Epoch 70/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.6629 - accuracy: 0.9206 - val_loss: 9.0728 - val_accuracy: 0.5000
# Epoch 71/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.5829 - accuracy: 0.9365 - val_loss: 9.1009 - val_accuracy: 0.5000
# Epoch 72/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.5722 - accuracy: 0.9048 - val_loss: 9.1115 - val_accuracy: 0.5000
# Epoch 73/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.5640 - accuracy: 0.9048 - val_loss: 9.1434 - val_accuracy: 0.4375
# Epoch 74/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.5709 - accuracy: 0.8889 - val_loss: 9.1570 - val_accuracy: 0.3750
# Epoch 75/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.5568 - accuracy: 0.8571 - val_loss: 9.1890 - val_accuracy: 0.3750
# Epoch 76/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.4788 - accuracy: 0.8571 - val_loss: 9.1896 - val_accuracy: 0.3750
# Epoch 77/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.5030 - accuracy: 0.9048 - val_loss: 9.1560 - val_accuracy: 0.3750
# Epoch 78/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.4089 - accuracy: 0.9206 - val_loss: 9.1189 - val_accuracy: 0.3750
# Epoch 79/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.3533 - accuracy: 0.9524 - val_loss: 9.0689 - val_accuracy: 0.3750
# Epoch 80/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.4742 - accuracy: 0.9365 - val_loss: 9.0051 - val_accuracy: 0.3750
# Epoch 81/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.3469 - accuracy: 0.9048 - val_loss: 8.9182 - val_accuracy: 0.5000
# Epoch 82/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.2712 - accuracy: 0.9365 - val_loss: 8.8121 - val_accuracy: 0.5000
# Epoch 83/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.3237 - accuracy: 0.8889 - val_loss: 8.7339 - val_accuracy: 0.5625
# Epoch 84/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.1761 - accuracy: 0.9841 - val_loss: 8.6812 - val_accuracy: 0.5625
# Epoch 85/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.2102 - accuracy: 0.9365 - val_loss: 8.6389 - val_accuracy: 0.5625
# Epoch 86/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.2618 - accuracy: 0.8889 - val_loss: 8.6397 - val_accuracy: 0.5625
# Epoch 87/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.1851 - accuracy: 0.9206 - val_loss: 8.6782 - val_accuracy: 0.5625
# Epoch 88/100
# 2/2 [==============================] - 4s 3s/step - loss: 8.1477 - accuracy: 0.9524 - val_loss: 8.7446 - val_accuracy: 0.5000
# Epoch 89/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.1229 - accuracy: 0.9206 - val_loss: 8.7708 - val_accuracy: 0.5000
# Epoch 90/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.0721 - accuracy: 0.9365 - val_loss: 8.8083 - val_accuracy: 0.3750
# Epoch 91/100
# 2/2 [==============================] - 5s 3s/step - loss: 8.1168 - accuracy: 0.8889 - val_loss: 8.8720 - val_accuracy: 0.3750
# Epoch 92/100
# 2/2 [==============================] - 5s 3s/step - loss: 8
- val_accuracy: 1.0000
# Epoch 70/100
# 2/2 [==============================] - 7s 4s/step - loss: 3.2263 - accuracy: 1.0000 - val_loss: 3.2024 - val_accuracy: 1.0000
# Epoch 71/100
# 2/2 [==============================] - 8s 4s/step - loss: 3.2134 - accuracy: 1.0000 - val_loss: 3.1902 - val_accuracy: 1.0000
# Epoch 72/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.2632 - accuracy: 0.9844 - val_loss: 3.1780 - val_accuracy: 1.0000
# Epoch 73/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.2234 - accuracy: 0.9844 - val_loss: 3.1659 - val_accuracy: 1.0000
# Epoch 74/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.1761 - accuracy: 1.0000 - val_loss: 3.1538 - val_accuracy: 1.0000
# Epoch 75/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.1674 - accuracy: 1.0000 - val_loss: 3.1417 - val_accuracy: 1.0000
# Epoch 76/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.1516 - accuracy: 1.0000 - val_loss: 3.1297 - val_accuracy: 1.0000
# Epoch 77/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.1479 - accuracy: 1.0000 - val_loss: 3.1177 - val_accuracy: 1.0000
# Epoch 78/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.1338 - accuracy: 1.0000 - val_loss: 3.1057 - val_accuracy: 1.0000
# Epoch 79/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.1832 - accuracy: 0.9844 - val_loss: 3.0941 - val_accuracy: 1.0000
# Epoch 80/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.1062 - accuracy: 1.0000 - val_loss: 3.0826 - val_accuracy: 1.0000
# Epoch 81/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.0942 - accuracy: 1.0000 - val_loss: 3.0711 - val_accuracy: 1.0000
# Epoch 82/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.0910 - accuracy: 1.0000 - val_loss: 3.0597 - val_accuracy: 1.0000
# Epoch 83/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.1316 - accuracy: 0.9688 - val_loss: 3.0483 - val_accuracy: 1.0000
# Epoch 84/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.0965 - accuracy: 0.9844 - val_loss: 3.0370 - val_accuracy: 1.0000
# Epoch 85/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.0603 - accuracy: 0.9844 - val_loss: 3.0258 - val_accuracy: 1.0000
# Epoch 86/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.0355 - accuracy: 1.0000 - val_loss: 3.0145 - val_accuracy: 1.0000
# Epoch 87/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.0204 - accuracy: 1.0000 - val_loss: 3.0033 - val_accuracy: 1.0000
# Epoch 88/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.0278 - accuracy: 0.9844 - val_loss: 2.9921 - val_accuracy: 1.0000
# Epoch 89/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.0343 - accuracy: 0.9844 - val_loss: 2.9809 - val_accuracy: 1.0000
# Epoch 90/100
# 2/2 [==============================] - 5s 3s/step - loss: 2.9929 - accuracy: 1.0000 - val_loss: 2.9697 - val_accuracy: 1.0000
# Epoch 91/100
# 2/2 [==============================] - 5s 3s/step - loss: 3.0062 - accuracy: 0.9844 - val_loss: 2.9586 - val_accuracy: 1.0000
# Epoch 92/100
# 2/2 [==============================] - 5s 3s/step - loss: 2.9926 - accuracy: 1.0000 - val_loss: 2.9474 - val_accuracy: 1.0000
# Epoch 93/100
# 2/2 [==============================] - 5s 3s/step - loss: 2.9780 - accuracy: 0.9844 - val_loss: 2.9363 - val_accuracy: 1.0000
# Epoch 94/100
# 2/2 [==============================] - 5s 3s/step - loss: 2.9537 - accuracy: 1.0000 - val_loss: 2.9252 - val_accuracy: 1.0000
# Epoch 95/100
# 2/2 [==============================] - 5s 3s/step - loss: 2.9336 - accuracy: 1.0000 - val_loss: 2.9142 - val_accuracy: 1.0000
# Epoch 96/100
# 2/2 [==============================] - 5s 3s/step - loss: 2.9801 - accuracy: 0.9844 - val_loss: 2.9032 - val_accuracy: 1.0000
# Epoch 97/100
# 2/2 [==============================] - 5s 3s/step - loss: 2.9219 - accuracy: 0.9844 - val_loss: 2.8922 - val_accuracy: 1.0000
# Epoch 98/100
# 2/2 [==============================] - 5s 3s/step - loss: 2.9186 - accuracy: 0.9844 - val_loss: 2.8812 - val_accuracy: 1.0000
# Epoch 99/100
# 2/2 [==============================] - 4s 2s/step - loss: 2.8855 - accuracy: 1.0000 - val_loss: 2.8704 - val_accuracy: 1.0000
# Epoch 100/100
# 2/2 [==============================] - 4s 2s/step - loss: 2.8770 - accuracy: 1.0000 - val_loss: 2.8595 - val_accuracy: 1.0000
# 2/2 [==============================] - 2s 488ms/step - loss: 2.8603 - accuracy: 1.0000
# 1/1 [==============================] - 1s 617ms/step - loss: 2.8595 - accuracy: 1.0000

# %%
# Calculate the average accuracies
avg_train_accuracy = np.mean(train_accuracies)
avg_val_accuracy = np.mean(val_accuracies)

print('Average Training Accuracy:', avg_train_accuracy)
print('Average Validation Accuracy:', avg_val_accuracy)
# Out:
# Average Training Accuracy: 0.9936507940292358
# Average Validation Accuracy: 0.8125

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Get predicted probabilities for the test set
y_pred_probs = model.predict(X_test)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)

# Convert one-hot encoded labels to their original form
y_test_original = np.argmax(y_test, axis=1)

# Generate classification report
print("Classification Report:")
print(classification_report(y_test_original, y_pred))

# Generate confusion matrix
print("Confusion Matrix:")
cm = confusion_matrix(y_test_original, y_pred)
print(cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 from sklearn.metrics import classification_report, confusion_matrix
#       3 # Get predicted probabilities for the test set
# ----> 4 y_pred_probs = model.predict(X_test)
#       6 # Convert probabilities to class labels
#       7 y_pred = np.argmax(y_pred_probs, axis=1)
#
# NameError: name 'X_test' is not defined
