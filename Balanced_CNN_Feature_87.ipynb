# %%
import os
import scipy.io
import numpy as np
from scipy import signal

data_path = "/kaggle/input/control1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')

for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []

for control_data_path in control_data:
    n_epochs = 70 
    start_epoch = 1
    end_epoch = 110

    control_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = os.path.join(control_data_path, f"trial{i}.mat")
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]    
        #print(mat_data1.shape)
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        #print(downsampled_data.shape)
        
        control_arr.append(downsampled_data)
        Control30.append(downsampled_data)

Control30 = np.array(Control30)

print(Control30.shape)
# Out:
# (3300, 60, 1000)

# %%
import numpy as np
from scipy.stats import entropy
from scipy import signal

epsilon = 1e-8
alpha_band = (8, 12)
beta_band = (12, 30)
delta_band = (0.5, 4)

num_samples = Control30.shape[0]
num_channels = Control30.shape[1]

features_control = np.zeros((num_samples, num_channels, 4))

for sample_idx in range(num_samples):
    for channel_idx in range(num_channels):
        channel_data = Control30[sample_idx, channel_idx, :]

        freq_spectrum = np.fft.fft(channel_data)
        power_spectrum = np.abs(freq_spectrum) ** 2

        alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
        beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
        delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

        channel_min_value = np.min(channel_data)
        channel_max_value = np.max(channel_data)

        power_spectrum_adjusted = power_spectrum + epsilon
        entropy_values = entropy(power_spectrum_adjusted)

        values = np.array([alpha_power, beta_power, delta_power, entropy_values])
        rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value

        features_control[sample_idx, channel_idx, :] = rescaled_values

print(features_control.shape)
# Out:
# (3300, 60, 4)

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
data_path = "/kaggle/input/concussed1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)
    
concussed_data = concussed_data[:30]

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 70
    start_epoch = 1
    end_epoch = 110
    concussed_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        f0 = 60 
        Q = 30  
        w0 = f0 / (fs_original / 2)
        b, a = signal.iirnotch(w0, Q)
        filtered_data = signal.lfilter(b, a, mat_data1)
        
        # Downsampling
        num_samples_original = filtered_data.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(filtered_data, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
        Concussed52.append(downsampled_data)

Concussed52 = np.array(Concussed52)

print( Concussed52.shape)
# Out:
# (3300, 60, 1000)

# %%
import numpy as np
from scipy.stats import entropy
from scipy import signal

epsilon = 1e-8
alpha_band = (8, 12)
beta_band = (12, 30)
delta_band = (0.5, 4)

num_samples = Concussed52.shape[0]
num_channels = Concussed52.shape[1]
features_concussed = np.zeros((num_samples, num_channels, 4))

for sample_idx in range(num_samples):
    for channel_idx in range(num_channels):
        channel_data = Concussed52[sample_idx, channel_idx, :]

        freq_spectrum = np.fft.fft(channel_data)
        power_spectrum = np.abs(freq_spectrum) ** 2

        alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
        beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
        delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

        channel_min_value = np.min(channel_data)
        channel_max_value = np.max(channel_data)

        power_spectrum_adjusted = power_spectrum + epsilon
        entropy_values = entropy(power_spectrum_adjusted)

        values = np.array([alpha_power, beta_power, delta_power, entropy_values])
        rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value

        features_concussed[sample_idx, channel_idx, :] = rescaled_values

print(features_concussed.shape)
# Out:
# (3300, 60, 4)

# %%
dataset = np.concatenate((Control30, Concussed52), axis=0)
labels = np.concatenate((np.zeros(Control30.shape[0]), np.ones(Concussed52.shape[0])))

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, Dense, concatenate, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping

X_train_control, X_test_control, y_train_control, y_test_control = train_test_split(Control30, np.zeros(Control30.shape[0]), test_size=0.2, random_state=42)
X_train_concussed, X_test_concussed, y_train_concussed, y_test_concussed = train_test_split(Concussed52, np.ones(Concussed52.shape[0]), test_size=0.2, random_state=42)

X_train_features_control, X_test_features_control, _, _ = train_test_split(features_control, np.zeros(features_control.shape[0]), test_size=0.2, random_state=42)
X_train_features_concussed, X_test_features_concussed, _, _ = train_test_split(features_concussed, np.ones(features_concussed.shape[0]), test_size=0.2, random_state=42)
X_train_eeg = np.concatenate((X_train_control, X_train_concussed))
X_test_eeg = np.concatenate((X_test_control, X_test_concussed))
X_train_features = np.concatenate((X_train_features_control, X_train_features_concussed))
X_test_features = np.concatenate((X_test_features_control, X_test_features_concussed))
y_train = np.concatenate((y_train_control, y_train_concussed))
y_test = np.concatenate((y_test_control, y_test_concussed))

eeg_input = Input(shape=(60, 1000))
conv1 = Conv1D(64, 3, activation='relu')(eeg_input)
maxpool1 = MaxPooling1D(2)(conv1)
flatten1 = Flatten()(maxpool1)
dropout1 = Dropout(0.5)(flatten1)

feature_input = Input(shape=(60, 4))
flatten2 = Flatten()(feature_input)

concatenated = concatenate([dropout1, flatten2])
batchnorm1 = BatchNormalization()(concatenated)

dense1 = Dense(128, activation='relu')(batchnorm1)
dropout2 = Dropout(0.5)(dense1)

output = Dense(1, activation='sigmoid')(dropout2)

model = Model(inputs=[eeg_input, feature_input], outputs=output)
model.compile(optimizer=Adam(learning_rate=0.003), loss='binary_crossentropy', metrics=['accuracy'])

def lr_scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch > 0:
        return lr * 0.5
    return lr

lr_callback = LearningRateScheduler(lr_scheduler)

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
history = model.fit([X_train_eeg, X_train_features], y_train, epochs=100, batch_size=256, validation_data=([X_test_eeg, X_test_features], y_test), callbacks=[lr_callback, early_stopping])
test_loss, test_accuracy = model.evaluate([X_test_eeg, X_test_features], y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Epoch 1/100
# 21/21 [==============================] - 8s 285ms/step - loss: 0.8630 - accuracy: 0.5805 - val_loss: 1.2305 - val_accuracy: 0.5742 - lr: 0.0030
# Epoch 2/100
# 21/21 [==============================] - 5s 231ms/step - loss: 0.6560 - accuracy: 0.6583 - val_loss: 0.7293 - val_accuracy: 0.6220 - lr: 0.0030
# Epoch 3/100
# 21/21 [==============================] - 5s 247ms/step - loss: 0.5904 - accuracy: 0.7076 - val_loss: 0.6816 - val_accuracy: 0.6205 - lr: 0.0030
# Epoch 4/100
# 21/21 [==============================] - 5s 233ms/step - loss: 0.5229 - accuracy: 0.7373 - val_loss: 0.5349 - val_accuracy: 0.7318 - lr: 0.0030
# Epoch 5/100
# 21/21 [==============================] - 5s 227ms/step - loss: 0.5024 - accuracy: 0.7581 - val_loss: 0.5153 - val_accuracy: 0.7561 - lr: 0.0030
# Epoch 6/100
# 21/21 [==============================] - 5s 230ms/step - loss: 0.4614 - accuracy: 0.7754 - val_loss: 0.5626 - val_accuracy: 0.7189 - lr: 0.0030
# Epoch 7/100
# 21/21 [==============================] - 5s 226ms/step - loss: 0.4386 - accuracy: 0.7926 - val_loss: 0.4999 - val_accuracy: 0.7712 - lr: 0.0030
# Epoch 8/100
# 21/21 [==============================] - 5s 229ms/step - loss: 0.4363 - accuracy: 0.8080 - val_loss: 0.4803 - val_accuracy: 0.7803 - lr: 0.0030
# Epoch 9/100
# 21/21 [==============================] - 5s 246ms/step - loss: 0.3991 - accuracy: 0.8225 - val_loss: 0.4741 - val_accuracy: 0.7826 - lr: 0.0030
# Epoch 10/100
# 21/21 [==============================] - 5s 234ms/step - loss: 0.3726 - accuracy: 0.8322 - val_loss: 0.4815 - val_accuracy: 0.7409 - lr: 0.0030
# Epoch 11/100
# 21/21 [==============================] - 5s 227ms/step - loss: 0.3632 - accuracy: 0.8428 - val_loss: 0.4396 - val_accuracy: 0.8076 - lr: 0.0015
# Epoch 12/100
# 21/21 [==============================] - 5s 231ms/step - loss: 0.3350 - accuracy: 0.8570 - val_loss: 0.4340 - val_accuracy: 0.8182 - lr: 0.0015
# Epoch 13/100
# 21/21 [==============================] - 5s 229ms/step - loss: 0.3203 - accuracy: 0.8610 - val_loss: 0.4520 - val_accuracy: 0.7682 - lr: 0.0015
# Epoch 14/100
# 21/21 [==============================] - 5s 230ms/step - loss: 0.3221 - accuracy: 0.8608 - val_loss: 0.4316 - val_accuracy: 0.8061 - lr: 0.0015
# Epoch 15/100
# 21/21 [==============================] - 5s 229ms/step - loss: 0.3087 - accuracy: 0.8706 - val_loss: 0.3909 - val_accuracy: 0.8492 - lr: 0.0015
# Epoch 16/100
# 21/21 [==============================] - 5s 249ms/step - loss: 0.2928 - accuracy: 0.8805 - val_loss: 0.3999 - val_accuracy: 0.8417 - lr: 0.0015
# Epoch 17/100
# 21/21 [==============================] - 5s 232ms/step - loss: 0.2729 - accuracy: 0.8902 - val_loss: 0.4185 - val_accuracy: 0.8076 - lr: 0.0015
# Epoch 18/100
# 21/21 [==============================] - 5s 230ms/step - loss: 0.2670 - accuracy: 0.8930 - val_loss: 0.4019 - val_accuracy: 0.8197 - lr: 0.0015
# Epoch 19/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2661 - accuracy: 0.8902 - val_loss: 0.4243 - val_accuracy: 0.7962 - lr: 0.0015
# Epoch 20/100
# 21/21 [==============================] - 5s 229ms/step - loss: 0.2727 - accuracy: 0.8905 - val_loss: 0.4052 - val_accuracy: 0.8053 - lr: 0.0015
# Epoch 21/100
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2529 - accuracy: 0.9011 - val_loss: 0.3915 - val_accuracy: 0.8265 - lr: 7.5000e-04
# Epoch 22/100
# 21/21 [==============================] - 5s 246ms/step - loss: 0.2390 - accuracy: 0.8994 - val_loss: 0.3905 - val_accuracy: 0.8386 - lr: 7.5000e-04
# Epoch 23/100
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2285 - accuracy: 0.9074 - val_loss: 0.3649 - val_accuracy: 0.8667 - lr: 7.5000e-04
# Epoch 24/100
# 21/21 [==============================] - 5s 231ms/step - loss: 0.2222 - accuracy: 0.9112 - val_loss: 0.3702 - val_accuracy: 0.8508 - lr: 7.5000e-04
# Epoch 25/100
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2198 - accuracy: 0.9127 - val_loss: 0.3616 - val_accuracy: 0.8515 - lr: 7.5000e-04
# Epoch 26/100
# 21/21 [==============================] - 5s 231ms/step - loss: 0.2068 - accuracy: 0.9180 - val_loss: 0.3485 - val_accuracy: 0.8621 - lr: 7.5000e-04
# Epoch 27/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2094 - accuracy: 0.9193 - val_loss: 0.3545 - val_accuracy: 0.8545 - lr: 7.5000e-04
# Epoch 28/100
# 21/21 [==============================] - 5s 231ms/step - loss: 0.2045 - accuracy: 0.9187 - val_loss: 0.3427 - val_accuracy: 0.8636 - lr: 7.5000e-04
# Epoch 29/100
# 21/21 [==============================] - 5s 254ms/step - loss: 0.1974 - accuracy: 0.9212 - val_loss: 0.3577 - val_accuracy: 0.8530 - lr: 7.5000e-04
# Epoch 30/100
# 21/21 [==============================] - 5s 231ms/step - loss: 0.1934 - accuracy: 0.9256 - val_loss: 0.3545 - val_accuracy: 0.8583 - lr: 7.5000e-04
# Epoch 31/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1886 - accuracy: 0.9284 - val_loss: 0.3539 - val_accuracy: 0.8538 - lr: 3.7500e-04
# Epoch 32/100
# 21/21 [==============================] - 5s 231ms/step - loss: 0.1849 - accuracy: 0.9256 - val_loss: 0.3469 - val_accuracy: 0.8568 - lr: 3.7500e-04
# Epoch 33/100
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1879 - accuracy: 0.9339 - val_loss: 0.3601 - val_accuracy: 0.8409 - lr: 3.7500e-04
# Epoch 34/100
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1741 - accuracy: 0.9350 - val_loss: 0.3543 - val_accuracy: 0.8508 - lr: 3.7500e-04
# Epoch 35/100
# 21/21 [==============================] - 5s 253ms/step - loss: 0.1813 - accuracy: 0.9335 - val_loss: 0.3309 - val_accuracy: 0.8758 - lr: 3.7500e-04
# Epoch 36/100
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1854 - accuracy: 0.9275 - val_loss: 0.3423 - val_accuracy: 0.8621 - lr: 3.7500e-04
# Epoch 37/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1748 - accuracy: 0.9356 - val_loss: 0.3569 - val_accuracy: 0.8417 - lr: 3.7500e-04
# Epoch 38/100
# 21/21 [==============================] - 5s 231ms/step - loss: 0.1684 - accuracy: 0.9350 - val_loss: 0.3493 - val_accuracy: 0.8515 - lr: 3.7500e-04
# Epoch 39/100
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1730 - accuracy: 0.9339 - val_loss: 0.3413 - val_accuracy: 0.8561 - lr: 3.7500e-04
# Epoch 40/100
# 21/21 [==============================] - 5s 231ms/step - loss: 0.1693 - accuracy: 0.9383 - val_loss: 0.3321 - val_accuracy: 0.8674 - lr: 3.7500e-04
# Epoch 41/100
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1489 - accuracy: 0.9449 - val_loss: 0.3496 - val_accuracy: 0.8470 - lr: 1.8750e-04
# Epoch 42/100
# 21/21 [==============================] - 5s 254ms/step - loss: 0.1605 - accuracy: 0.9394 - val_loss: 0.3460 - val_accuracy: 0.8492 - lr: 1.8750e-04
# Epoch 43/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1636 - accuracy: 0.9403 - val_loss: 0.3457 - val_accuracy: 0.8523 - lr: 1.8750e-04
# Epoch 44/100
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1637 - accuracy: 0.9375 - val_loss: 0.3387 - val_accuracy: 0.8614 - lr: 1.8750e-04
# Epoch 45/100
# 21/21 [==============================] - 5s 242ms/step - loss: 0.1587 - accuracy: 0.9402 - val_loss: 0.3371 - val_accuracy: 0.8591 - lr: 1.8750e-04
# Epoch 46/100
# 21/21 [==============================] - 5s 232ms/step - loss: 0.1511 - accuracy: 0.9443 - val_loss: 0.3385 - val_accuracy: 0.8576 - lr: 1.8750e-04
# Epoch 47/100
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1543 - accuracy: 0.9439 - val_loss: 0.3379 - val_accuracy: 0.8576 - lr: 1.8750e-04
# Epoch 48/100
# 21/21 [==============================] - 5s 255ms/step - loss: 0.1559 - accuracy: 0.9436 - val_loss: 0.3321 - val_accuracy: 0.8591 - lr: 1.8750e-04
# Epoch 49/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1542 - accuracy: 0.9453 - val_loss: 0.3350 - val_accuracy: 0.8576 - lr: 1.8750e-04
# Epoch 50/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1447 - accuracy: 0.9470 - val_loss: 0.3264 - val_accuracy: 0.8629 - lr: 1.8750e-04
# Epoch 51/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1513 - accuracy: 0.9438 - val_loss: 0.3295 - val_accuracy: 0.8583 - lr: 9.3750e-05
# Epoch 52/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1420 - accuracy: 0.9502 - val_loss: 0.3310 - val_accuracy: 0.8576 - lr: 9.3750e-05
# Epoch 53/100
# 21/21 [==============================] - 5s 238ms/step - loss: 0.1514 - accuracy: 0.9411 - val_loss: 0.3273 - val_accuracy: 0.8568 - lr: 9.3750e-05
# Epoch 54/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1453 - accuracy: 0.9460 - val_loss: 0.3338 - val_accuracy: 0.8523 - lr: 9.3750e-05
# Epoch 55/100
# 21/21 [==============================] - 5s 255ms/step - loss: 0.1514 - accuracy: 0.9439 - val_loss: 0.3289 - val_accuracy: 0.8576 - lr: 9.3750e-05
# Epoch 56/100
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1460 - accuracy: 0.9472 - val_loss: 0.3384 - val_accuracy: 0.8523 - lr: 9.3750e-05
# Epoch 57/100
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1445 - accuracy: 0.9481 - val_loss: 0.3345 - val_accuracy: 0.8591 - lr: 9.3750e-05
# Epoch 58/100
# 21/21 [==============================] - 5s 232ms/step - loss: 0.1442 - accuracy: 0.9487 - val_loss: 0.3331 - val_accuracy: 0.8591 - lr: 9.3750e-05
# Epoch 59/100
# 21/21 [==============================] - 5s 238ms/step - loss: 0.1408 - accuracy: 0.9481 - val_loss: 0.3353 - val_accuracy: 0.8568 - lr: 9.3750e-05
# Epoch 60/100
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1451 - accuracy: 0.9485 - val_loss: 0.3291 - val_accuracy: 0.8598 - lr: 9.3750e-05
# Epoch 61/100
# 21/21 [==============================] - 5s 257ms/step - loss: 0.1397 - accuracy: 0.9504 - val_loss: 0.3307 - val_accuracy: 0.8583 - lr: 4.6875e-05
# Epoch 62/100
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1413 - accuracy: 0.9494 - val_loss: 0.3317 - val_accuracy: 0.8553 - lr: 4.6875e-05
# Epoch 63/100
# 21/21 [==============================] - 5s 237ms/step - loss: 0.1341 - accuracy: 0.9502 - val_loss: 0.3327 - val_accuracy: 0.8553 - lr: 4.6875e-05
# Epoch 64/100
# 21/21 [==============================] - 5s 238ms/step - loss: 0.1350 - accuracy: 0.9538 - val_loss: 0.3248 - val_accuracy: 0.8606 - lr: 4.6875e-05
# Epoch 65/100
# 21/21 [==============================] - 5s 239ms/step - loss: 0.1429 - accuracy: 0.9487 - val_loss: 0.3282 - val_accuracy: 0.8576 - lr: 4.6875e-05
# Epoch 66/100
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1439 - accuracy: 0.9523 - val_loss: 0.3304 - val_accuracy: 0.8568 - lr: 4.6875e-05
# Epoch 67/100
# 21/21 [==============================] - 6s 278ms/step - loss: 0.1445 - accuracy: 0.9494 - val_loss: 0.3361 - val_accuracy: 0.8568 - lr: 4.6875e-05
# Epoch 68/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1356 - accuracy: 0.9513 - val_loss: 0.3312 - val_accuracy: 0.8591 - lr: 4.6875e-05
# Epoch 69/100
# 21/21 [==============================] - 5s 240ms/step - loss: 0.1451 - accuracy: 0.9447 - val_loss: 0.3269 - val_accuracy: 0.8598 - lr: 4.6875e-05
# Epoch 70/100
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1297 - accuracy: 0.9549 - val_loss: 0.3304 - val_accuracy: 0.8591 - lr: 4.6875e-05
# Epoch 71/100
# 21/21 [==============================] - 5s 239ms/step - loss: 0.1414 - accuracy: 0.9449 - val_loss: 0.3303 - val_accuracy: 0.8583 - lr: 2.3438e-05
# Epoch 72/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1475 - accuracy: 0.9470 - val_loss: 0.3293 - val_accuracy: 0.8576 - lr: 2.3438e-05
# Epoch 73/100
# 21/21 [==============================] - 5s 238ms/step - loss: 0.1350 - accuracy: 0.9527 - val_loss: 0.3293 - val_accuracy: 0.8583 - lr: 2.3438e-05
# Epoch 74/100
# 21/21 [==============================] - 5s 257ms/step - loss: 0.1419 - accuracy: 0.9489 - val_loss: 0.3314 - val_accuracy: 0.8583 - lr: 2.3438e-05
# Epoch 75/100
# 21/21 [==============================] - 5s 239ms/step - loss: 0.1341 - accuracy: 0.9547 - val_loss: 0.3315 - val_accuracy: 0.8583 - lr: 2.3438e-05
# Epoch 76/100
# 21/21 [==============================] - 5s 237ms/step - loss: 0.1402 - accuracy: 0.9498 - val_loss: 0.3283 - val_accuracy: 0.8598 - lr: 2.3438e-05
# Epoch 77/100
# 21/21 [==============================] - 5s 239ms/step - loss: 0.1299 - accuracy: 0.9581 - val_loss: 0.3284 - val_accuracy: 0.8606 - lr: 2.3438e-05
# Epoch 78/100
# 21/21 [==============================] - 5s 239ms/step - loss: 0.1300 - accuracy: 0.9578 - val_loss: 0.3283 - val_accuracy: 0.8606 - lr: 2.3438e-05
# Epoch 79/100
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1349 - accuracy: 0.9540 - val_loss: 0.3258 - val_accuracy: 0.8621 - lr: 2.3438e-05
# Epoch 80/100
# 21/21 [==============================] - 5s 257ms/step - loss: 0.1305 - accuracy: 0.9530 - val_loss: 0.3268 - val_accuracy: 0.8598 - lr: 2.3438e-05
# Epoch 81/100
# 21/21 [==============================] - 5s 239ms/step - loss: 0.1429 - accuracy: 0.9506 - val_loss: 0.3240 - val_accuracy: 0.8621 - lr: 1.1719e-05
# Epoch 82/100
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1361 - accuracy: 0.9500 - val_loss: 0.3248 - val_accuracy: 0.8614 - lr: 1.1719e-05
# Epoch 83/100
# 21/21 [==============================] - 5s 243ms/step - loss: 0.1496 - accuracy: 0.9458 - val_loss: 0.3249 - val_accuracy: 0.8598 - lr: 1.1719e-05
# Epoch 84/100
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1310 - accuracy: 0.9532 - val_loss: 0.3252 - val_accuracy: 0.8591 - lr: 1.1719e-05
# Epoch 85/100
# 21/21 [==============================] - 5s 245ms/step - loss: 0.1274 - accuracy: 0.9538 - val_loss: 0.3237 - val_accuracy: 0.8606 - lr: 1.1719e-05
# Epoch 86/100
# 21/21 [==============================] - 5s 258ms/step - loss: 0.1320 - accuracy: 0.9534 - val_loss: 0.3246 - val_accuracy: 0.8614 - lr: 1.1719e-05
# Epoch 87/100
# 21/21 [==============================] - 12s 611ms/step - loss: 0.1357 - accuracy: 0.9511 - val_loss: 0.3246 - val_accuracy: 0.8606 - lr: 1.1719e-05
# Epoch 88/100
# 21/21 [==============================] - 11s 510ms/step - loss: 0.1357 - accuracy: 0.9515 - val_loss: 0.3251 - val_accuracy: 0.8614 - lr: 1.1719e-05
# Epoch 89/100
# 21/21 [==============================] - 10s 456ms/step - loss: 0.1384 - accuracy: 0.9504 - val_loss: 0.3261 - val_accuracy: 0.8614 - lr: 1.1719e-05
# Epoch 90/100
# 21/21 [==============================] - 5s 238ms/step - loss: 0.1324 - accuracy: 0.9483 - val_loss: 0.3265 - val_accuracy: 0.8606 - lr: 1.1719e-05
# Epoch 91/100
# 21/21 [==============================] - 5s 242ms/step - loss: 0.1271 - accuracy: 0.9580 - val_loss: 0.3275 - val_accuracy: 0.8598 - lr: 5.8594e-06
# Epoch 92/100
# 21/21 [==============================] - 5s 238ms/step - loss: 0.1328 - accuracy: 0.9553 - val_loss: 0.3274 - val_accuracy: 0.8614 - lr: 5.8594e-06
# Epoch 93/100
# 21/21 [==============================] - 5s 242ms/step - loss: 0.1333 - accuracy: 0.9551 - val_loss: 0.3274 - val_accuracy: 0.8606 - lr: 5.8594e-06
# Epoch 94/100
# 21/21 [==============================] - 5s 238ms/step - loss: 0.1383 - accuracy: 0.9500 - val_loss: 0.3271 - val_accuracy: 0.8621 - lr: 5.8594e-06
# Epoch 95/100
# 21/21 [==============================] - 5s 243ms/step - loss: 0.1412 - accuracy: 0.9523 - val_loss: 0.3270 - val_accuracy: 0.8614 - lr: 5.8594e-06
# Epoch 96/100
# 21/21 [==============================] - 5s 252ms/step - loss: 0.1236 - accuracy: 0.9570 - val_loss: 0.3276 - val_accuracy: 0.8606 - lr: 5.8594e-06
# Epoch 97/100
# 21/21 [==============================] - 5s 237ms/step - loss: 0.1400 - accuracy: 0.9508 - val_loss: 0.3263 - val_accuracy: 0.8606 - lr: 5.8594e-06
# Epoch 98/100
# 21/21 [==============================] - 5s 239ms/step - loss: 0.1240 - accuracy: 0.9583 - val_loss: 0.3269 - val_accuracy: 0.8621 - lr: 5.8594e-06
# Epoch 99/100
# 21/21 [==============================] - 5s 248ms/step - loss: 0.1264 - accuracy: 0.9555 - val_loss: 0.3272 - val_accuracy: 0.8621 - lr: 5.8594e-06
# Epoch 100/100
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1326 - accuracy: 0.9515 - val_loss: 0.3259 - val_accuracy: 0.8606 - lr: 5.8594e-06
# 42/42 [==============================] - 1s 13ms/step - loss: 0.3259 - accuracy: 0.8606
# Test Loss: 0.32594984769821167
# Test Accuracy: 0.8606060743331909

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

plt.figure(figsize=(5, 4))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
y_pred = model.predict([X_test_eeg, X_test_features])
y_pred_binary = np.round(y_pred).flatten()

#confusion matrix
cm = confusion_matrix(y_test, y_pred_binary)

#classification report
target_names = ['Control', 'Concussed']
report = classification_report(y_test, y_pred_binary, target_names=target_names)
print("\n\nClassification Report:")
print(report)
cr = classification_report(y_test, y_pred_binary)

print("\n\nConfusion Matrix:")
print(cm)
# Out:
# 42/42 [==============================] - 1s 12ms/step
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Control       0.81      0.94      0.87       660
#    Concussed       0.93      0.78      0.85       660
#
#     accuracy                           0.86      1320
#    macro avg       0.87      0.86      0.86      1320
# weighted avg       0.87      0.86      0.86      1320
#
#
#
# Confusion Matrix:
# [[619  41]
#  [143 517]]

# %%
#loss curve
plt.figure(figsize=(5, 4))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

y_pred_binary = (y_pred >= 0.5).astype(int)
cm = confusion_matrix(y_test, y_pred_binary)

group_percentages = ["{0:.2%}".format(value) for value in cm.flatten() / np.sum(cm)]
group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]

labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2, 2)

plt.figure(figsize=(5, 4))
ax = sns.heatmap(cm, fmt='', annot=labels, cmap='Greens')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('\nActual Values\n')
ax.xaxis.set_ticklabels(target_names)
ax.yaxis.set_ticklabels(target_names)

plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # sample_index = 1
#
# input_sample_eeg = X_test_eeg[sample_index]
# input_sample_features = X_test_features[sample_index]
# true_label = y_test[sample_index]
# input_sample_eeg = np.expand_dims(input_sample_eeg, axis=0)
# input_sample_features = np.expand_dims(input_sample_features, axis=0)
# prediction = model.predict([input_sample_eeg, input_sample_features])
# binary_prediction = 1 if prediction > 0.5 else 0
# is_correct = binary_prediction == true_label
# print("Input EEG shape:", input_sample_eeg.shape)
# print("Input features shape:", input_sample_features.shape)
# print("True Label:", true_label)
# print("Predicted Label:", binary_prediction)
# print("Prediction is Correct:", is_correct)

# %%
TP = 558
FN = 102
FP = 72
TN = 1006

Precision = TP / (TP + FP)
Sensitivity = TP / (TP + FN)
Specificity = TN /(TN + FP)
False_Pos_Rate = FP / (TN + FP)
False_Neg_Rate = FN / (FN + TP)
F1_Score = (2*Precision*Sensitivity) / (Precision + Sensitivity)
Accuracy = (TP+TN) / (TP+FP+TN+FN)

precision = "{:.2f}".format(Precision)
sensitivity = "{:.2f}".format(Sensitivity)
specificity = "{:.2f}".format(Specificity)
false_pos_rate = "{:.2f}".format(False_Pos_Rate)
false_neg_rate = "{:.2f}".format(False_Neg_Rate)
f1_score = "{:.2f}".format(F1_Score)
accuracy = "{:.2f}".format(Accuracy)

print("Precision          :", precision)
print("Sensitivity        :", sensitivity)
print("Specificity        :", specificity)
print("F1-Score           :", f1_score)
print("False Positive Rate:", false_pos_rate)
print("False Negative Rate:", false_neg_rate)
print("Accuraccy          :", accuracy)
