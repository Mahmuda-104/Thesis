# %%
import os
import scipy.io
import numpy as np
from scipy import signal

data_path = "/kaggle/input/control1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250

control_data = []
control_path = os.path.join(data_path, 'Control')

for foldername in os.listdir(control_path):
    subfolder_path = os.path.join(control_path, foldername)
    control_data.append(subfolder_path)

Control30 = []

for control_data_path in control_data:
    n_epochs = 70 
    start_epoch = 1
    end_epoch = 110

    control_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = os.path.join(control_data_path, f"trial{i}.mat")
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]    
        #print(mat_data1.shape)
        # Downsampling
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        #print(downsampled_data.shape)
        
        control_arr.append(downsampled_data)
        Control30.append(downsampled_data)

Control30 = np.array(Control30)

print(Control30.shape)
# Out:
# (3300, 60, 1000)

# %%
import os
import scipy.io
import numpy as np
from scipy import signal
data_path = "/kaggle/input/concussed1"
lowcut = 0.4 
highcut = 100 
fs_original = 500
fs_new = 250  

concussed_data = []
concussed_path = os.path.join(data_path, 'Concussed')
for foldername in os.listdir(concussed_path):
    subfolder_path = os.path.join(concussed_path, foldername)
    concussed_data.append(subfolder_path)

Concussed52 = []
for concussed_data_path in concussed_data:
    n_epochs = 70
    start_epoch = 1
    end_epoch = 110
    concussed_arr = []

    for i in range(start_epoch, end_epoch+1):
        epoch_path = f"{concussed_data_path}/trial{i}.mat"
        mat_data = scipy.io.loadmat(epoch_path)
        mat_data1 = mat_data["trialData_i"]
        num_samples_original = mat_data1.shape[-1]
        num_samples_new = int(num_samples_original * fs_new / fs_original)
        downsampled_data = signal.resample(mat_data1, num_samples_new, axis=-1)
        
        concussed_arr.append(np.array(downsampled_data))
        
        Concussed52.append(downsampled_data)

Concussed52 = np.array(Concussed52)

print( Concussed52.shape)
# Out:
# (5390, 60, 1000)

# %%
dataset = np.concatenate((Control30, Concussed52), axis=0)
labels = np.concatenate((np.zeros(Control30.shape[0]), np.ones(Concussed52.shape[0])))

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from sklearn.model_selection import train_test_split

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.2, random_state=42)

mean = np.mean(X_train)
std = np.std(X_train)

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

k = 5  
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

train_losses = []  
val_losses = []  
train_accs = []  
val_accs = []  
cm_sum = np.zeros((2, 2))

for train_index, val_index in skf.split(dataset, labels):
    X_train_fold, X_val = dataset[train_index], dataset[val_index]
    y_train_fold, y_val = labels[train_index], labels[val_index]

    X_train_fold_norm = (X_train_fold - mean) / std
    X_val_norm = (X_val - mean) / std

    model = Sequential()
    model.add(Conv1D(32, 3, activation='relu', input_shape=(60, 1000)))
    model.add(MaxPooling1D(2))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    history = model.fit(X_train_fold_norm, y_train_fold, validation_data=(X_val_norm, y_val), epochs=100, batch_size=64, callbacks=[early_stopping])

    loss, accuracy = model.evaluate(X_val_norm, y_val)
    print(f'Fold Loss: {loss:.4f}')
    print(f'Fold Accuracy: {accuracy:.4f}')

    train_losses.append(history.history['loss'])
    val_losses.append(history.history['val_loss'])
    train_accs.append(history.history['accuracy'])
    val_accs.append(history.history['val_accuracy'])

    X_test_norm = (X_test - mean) / std
    y_pred = model.predict(X_test_norm)
    y_pred_classes = (y_pred > 0.5).astype(int)
    cm = confusion_matrix(y_test, y_pred_classes)
    cm_sum += cm

train_losses = np.concatenate(train_losses)
val_losses = np.concatenate(val_losses)
train_accs = np.concatenate(train_accs)
val_accs = np.concatenate(val_accs)
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Epoch 1/100
# 109/109 [==============================] - 7s 55ms/step - loss: 0.6455 - accuracy: 0.6441 - val_loss: 0.6109 - val_accuracy: 0.6703
# Epoch 2/100
# 109/109 [==============================] - 5s 48ms/step - loss: 0.5455 - accuracy: 0.7152 - val_loss: 0.5406 - val_accuracy: 0.7094
# Epoch 3/100
# 109/109 [==============================] - 5s 45ms/step - loss: 0.4566 - accuracy: 0.7776 - val_loss: 0.5283 - val_accuracy: 0.7468
# Epoch 4/100
# 109/109 [==============================] - 5s 44ms/step - loss: 0.3885 - accuracy: 0.8232 - val_loss: 0.6070 - val_accuracy: 0.7330
# Epoch 5/100
# 109/109 [==============================] - 5s 44ms/step - loss: 0.3384 - accuracy: 0.8477 - val_loss: 0.5203 - val_accuracy: 0.7842
# Epoch 6/100
# 109/109 [==============================] - 5s 42ms/step - loss: 0.3157 - accuracy: 0.8678 - val_loss: 0.4730 - val_accuracy: 0.8090
# Epoch 7/100
# 109/109 [==============================] - 5s 43ms/step - loss: 0.2375 - accuracy: 0.9022 - val_loss: 0.4714 - val_accuracy: 0.8170
# Epoch 8/100
# 109/109 [==============================] - 5s 42ms/step - loss: 0.1791 - accuracy: 0.9301 - val_loss: 0.3964 - val_accuracy: 0.8285
# Epoch 9/100
# 109/109 [==============================] - 5s 45ms/step - loss: 0.1223 - accuracy: 0.9580 - val_loss: 0.4441 - val_accuracy: 0.8354
# Epoch 10/100
# 109/109 [==============================] - 5s 42ms/step - loss: 0.1472 - accuracy: 0.9494 - val_loss: 0.4812 - val_accuracy: 0.8343
# Epoch 11/100
# 109/109 [==============================] - 5s 42ms/step - loss: 0.1008 - accuracy: 0.9662 - val_loss: 0.5787 - val_accuracy: 0.8165
# Epoch 12/100
# 109/109 [==============================] - 5s 43ms/step - loss: 0.1199 - accuracy: 0.9594 - val_loss: 0.6078 - val_accuracy: 0.8331
# Epoch 13/100
# 109/109 [==============================] - 4s 41ms/step - loss: 0.1473 - accuracy: 0.9507 - val_loss: 0.5464 - val_accuracy: 0.8400
# 55/55 [==============================] - 1s 9ms/step - loss: 0.3964 - accuracy: 0.8285
# Fold Loss: 0.3964
# Fold Accuracy: 0.8285
# 55/55 [==============================] - 1s 9ms/step
# Epoch 1/100
# 109/109 [==============================] - 6s 50ms/step - loss: 0.6607 - accuracy: 0.6425 - val_loss: 0.6018 - val_accuracy: 0.6640
# Epoch 2/100
# 109/109 [==============================] - 5s 44ms/step - loss: 0.5423 - accuracy: 0.7237 - val_loss: 0.5489 - val_accuracy: 0.7140
# Epoch 3/100
# 109/109 [==============================] - 5s 44ms/step - loss: 0.4628 - accuracy: 0.7778 - val_loss: 0.4741 - val_accuracy: 0.7819
# Epoch 4/100
# 109/109 [==============================] - 5s 46ms/step - loss: 0.4466 - accuracy: 0.7960 - val_loss: 0.5712 - val_accuracy: 0.7474
# Epoch 5/100
# 109/109 [==============================] - 5s 45ms/step - loss: 0.3829 - accuracy: 0.8280 - val_loss: 0.4601 - val_accuracy: 0.8055
# Epoch 6/100
# 109/109 [==============================] - 5s 45ms/step - loss: 0.3126 - accuracy: 0.8711 - val_loss: 0.4571 - val_accuracy: 0.8061
# Epoch 7/100
# 109/109 [==============================] - 5s 45ms/step - loss: 0.2420 - accuracy: 0.9061 - val_loss: 0.4619 - val_accuracy: 0.7929
# Epoch 8/100
# 109/109 [==============================] - 5s 45ms/step - loss: 0.1796 - accuracy: 0.9356 - val_loss: 0.4492 - val_accuracy: 0.8216
# Epoch 9/100
# 109/109 [==============================] - 5s 45ms/step - loss: 0.2718 - accuracy: 0.9196 - val_loss: 1.5197 - val_accuracy: 0.7146
# Epoch 10/100
# 109/109 [==============================] - 5s 49ms/step - loss: 0.2948 - accuracy: 0.8851 - val_loss: 0.4905 - val_accuracy: 0.8239
# Epoch 11/100
# 109/109 [==============================] - 6s 53ms/step - loss: 0.1872 - accuracy: 0.9275 - val_loss: 0.4860 - val_accuracy: 0.8314
# Epoch 12/100
# 109/109 [==============================] - 5s 46ms/step - loss: 0.1120 - accuracy: 0.9629 - val_loss: 0.4745 - val_accuracy: 0.8366
# Epoch 13/100
# 109/109 [==============================] - 5s 45ms/step - loss: 0.0893 - accuracy: 0.9761 - val_loss: 0.5243 - val_accuracy: 0.8222
# 55/55 [==============================] - 1s 9ms/step - loss: 0.4492 - accuracy: 0.8216
# Fold Loss: 0.4492
# Fold Accuracy: 0.8216
# 55/55 [==============================] - 1s 9ms/step
# Epoch 1/100
# 109/109 [==============================] - 6s 48ms/step - loss: 0.6433 - accuracy: 0.6591 - val_loss: 0.6399 - val_accuracy: 0.6513
# Epoch 2/100
# 109/109 [==============================] - 5s 47ms/step - loss: 0.5093 - accuracy: 0.7476 - val_loss: 0.5302 - val_accuracy: 0.7440
# Epoch 3/100
# 109/109 [==============================] - 5s 45ms/step - loss: 0.4709 - accuracy: 0.7779 - val_loss: 0.5212 - val_accuracy: 0.7514
# Epoch 4/100
# 109/109 [==============================] - 5s 46ms/step - loss: 0.3801 - accuracy: 0.8272 - val_loss: 0.4963 - val_accuracy: 0.7733
# Epoch 5/100
# 109/109 [==============================] - 5s 44ms/step - loss: 0.3396 - accuracy: 0.8495 - val_loss: 0.6669 - val_accuracy: 0.7468
# Epoch 6/100
# 109/109 [==============================] - 5s 45ms/step - loss: 0.3557 - accuracy: 0.8436 - val_loss: 0.5164 - val_accuracy: 0.8021
# Epoch 7/100
# 109/109 [==============================] - 5s 44ms/step - loss: 0.2329 - accuracy: 0.9056 - val_loss: 0.5177 - val_accuracy: 0.8096
# Epoch 8/100
# 109/109 [==============================] - 5s 47ms/step - loss: 0.2014 - accuracy: 0.9268 - val_loss: 0.5777 - val_accuracy: 0.8021
# Epoch 9/100
# 109/109 [==============================] - 5s 44ms/step - loss: 0.1926 - accuracy: 0.9305 - val_loss: 0.5155 - val_accuracy: 0.8199
# 55/55 [==============================] - 1s 9ms/step - loss: 0.4963 - accuracy: 0.7733
# Fold Loss: 0.4963
# Fold Accuracy: 0.7733
# 55/55 [==============================] - 1s 9ms/step
# Epoch 1/100
# 109/109 [==============================] - 6s 46ms/step - loss: 0.6614 - accuracy: 0.6457 - val_loss: 0.6007 - val_accuracy: 0.6674
# Epoch 2/100
# 109/109 [==============================] - 6s 53ms/step - loss: 0.5438 - accuracy: 0.7129 - val_loss: 0.5172 - val_accuracy: 0.7278
# Epoch 3/100
# 109/109 [==============================] - 7s 63ms/step - loss: 0.4733 - accuracy: 0.7750 - val_loss: 0.4873 - val_accuracy: 0.7583
# Epoch 4/100
# 109/109 [==============================] - 5s 44ms/step - loss: 0.3954 - accuracy: 0.8215 - val_loss: 0.4703 - val_accuracy: 0.7785
# Epoch 5/100
# 109/109 [==============================] - 5s 44ms/step - loss: 0.3367 - accuracy: 0.8580 - val_loss: 0.4770 - val_accuracy: 0.7842
# Epoch 6/100
# 109/109 [==============================] - 5s 48ms/step - loss: 0.2772 - accuracy: 0.8862 - val_loss: 0.4532 - val_accuracy: 0.8078
# Epoch 7/100
# 109/109 [==============================] - 5s 42ms/step - loss: 0.2402 - accuracy: 0.9028 - val_loss: 0.4620 - val_accuracy: 0.8049
# Epoch 8/100
# 109/109 [==============================] - 4s 41ms/step - loss: 0.1836 - accuracy: 0.9304 - val_loss: 0.4337 - val_accuracy: 0.8326
# Epoch 9/100
# 109/109 [==============================] - 4s 41ms/step - loss: 0.2291 - accuracy: 0.9192 - val_loss: 0.5702 - val_accuracy: 0.7733
# Epoch 10/100
# 109/109 [==============================] - 5s 42ms/step - loss: 0.1603 - accuracy: 0.9409 - val_loss: 0.4706 - val_accuracy: 0.8268
# Epoch 11/100
# 109/109 [==============================] - 5s 43ms/step - loss: 0.1035 - accuracy: 0.9679 - val_loss: 0.4804 - val_accuracy: 0.8291
# Epoch 12/100
# 109/109 [==============================] - 6s 43ms/step - loss: 0.6627 - accuracy: 0.6359 - val_loss: 0.5837 - val_accuracy: 0.6841
# Epoch 2/100
# 109/109 [==============================] - 4s 39ms/step - loss: 0.5495 - accuracy: 0.7130 - val_loss: 0.5547 - val_accuracy: 0.7221
# Epoch 3/100
# 109/109 [==============================] - 4s 40ms/step - loss: 0.4741 - accuracy: 0.7709 - val_loss: 0.5768 - val_accuracy: 0.7434
# Epoch 4/100
# 109/109 [==============================] - 4s 40ms/step - loss: 0.4321 - accuracy: 0.8005 - val_loss: 0.5377 - val_accuracy: 0.7618
# Epoch 5/100
# 109/109 [==============================] - 4s 41ms/step - loss: 0.3502 - accuracy: 0.8464 - val_loss: 0.5676 - val_accuracy: 0.7716
# Epoch 6/100
# 109/109 [==============================] - 4s 41ms/step - loss: 0.2926 - accuracy: 0.8767 - val_loss: 0.5046 - val_accuracy: 0.7854
# Epoch 7/100
# 109/109 [==============================] - 4s 40ms/step - loss: 0.2343 - accuracy: 0.9075 - val_loss: 0.4712 - val_accuracy: 0.8084
# Epoch 8/100
# 109/109 [==============================] - 4s 41ms/step - loss: 0.2123 - accuracy: 0.9223 - val_loss: 0.5328 - val_accuracy: 0.8090
# Epoch 9/100
# 109/109 [==============================] - 4s 41ms/step - loss: 0.1842 - accuracy: 0.9353 - val_loss: 0.5358 - val_accuracy: 0.7957
# Epoch 10/100
# 109/109 [==============================] - 5s 42ms/step - loss: 0.1418 - accuracy: 0.9492 - val_loss: 0.5947 - val_accuracy: 0.8205
# Epoch 11/100
# 109/109 [==============================] - 4s 41ms/step - loss: 0.0874 - accuracy: 0.9727 - val_loss: 0.5502 - val_accuracy: 0.8285
# Epoch 12/100
# 109/109 [==============================] - 4s 41ms/step - loss: 0.0601 - accuracy: 0.9837 - val_loss: 0.6395 - val_accuracy: 0.8274
# 55/55 [==============================] - 0s 8ms/step - loss: 0.4712 - accuracy: 0.8084
# Fold Loss: 0.4712
# Fold Accuracy: 0.8084
# 55/55 [==============================] - 1s 8ms/step

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
plt.plot(train_accs, label='Training Accuracy')
plt.plot(val_accs, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
target_names = ['Control', 'Concussed']
from sklearn.metrics import classification_report, confusion_matrix

threshold = 0.5
y_pred_binary = (y_pred > threshold).astype(int)

print(classification_report(y_test, y_pred_binary, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Control       0.89      0.46      0.61       684
#    Concussed       0.73      0.96      0.83      1054
#
#     accuracy                           0.77      1738
#    macro avg       0.81      0.71      0.72      1738
# weighted avg       0.80      0.77      0.75      1738

# %%
import seaborn as sns

cm_avg = cm_sum / k
plt.figure(figsize=(6, 5))
sns.heatmap(cm_avg, annot=True, cmap='Blues', fmt='g', cbar=False, square=True,
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
import numpy as np
import json
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import entropy

delta_band = (0.5, 4)
alpha_band = (8, 12)
beta_band = (12, 35)

all_control_power = []
scaler = MinMaxScaler()
epsilon = 1e-10

# Normalizing the features
for i in range(len(Control30)):
    control_data = Control30[i]
    control_power = []
    for epoch in control_data:
        epoch_power = []
        for channel_data in epoch:
            freq_spectrum = np.fft.fft(channel_data)
            power_spectrum = np.abs(freq_spectrum) ** 2

            alpha_power = np.sum(power_spectrum[(alpha_band[0] <= freq_spectrum) & (freq_spectrum <= alpha_band[1])])
            beta_power = np.sum(power_spectrum[(beta_band[0] <= freq_spectrum) & (freq_spectrum <= beta_band[1])])
            delta_power = np.sum(power_spectrum[(delta_band[0] <= freq_spectrum) & (freq_spectrum <= delta_band[1])])

            channel_min_value = np.min(channel_data)
            channel_max_value = np.max(channel_data)
            power_spectrum_adjusted = power_spectrum + epsilon
            entropy_values = entropy(power_spectrum_adjusted)
            values=np.array([alpha_power,beta_power,delta_power,entropy_values])
            rescaled_values = (values - values.min()) * (channel_max_value - channel_min_value) / (values.max() - values.min()) + channel_min_value
            concatenated_data = np.concatenate((channel_data, rescaled_values))
            epoch_power.append(concatenated_data.tolist())

        control_power.append(np.array(epoch_power))

    all_control_power.append(np.array(control_power))

all_control_power = np.array(all_control_power)
print(all_control_power.shape)
print(len(Control30))
